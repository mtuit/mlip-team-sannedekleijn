# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from tqdm.auto import tqdm
from glob import glob
import time, gc
import cv2

from tensorflow import keras
import matplotlib.image as mpimg
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model
from keras.models import clone_model
from keras.layers import Dense,Conv2D,Flatten,MaxPool2D,Dropout,BatchNormalization,Input,GlobalMaxPooling2D
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import PIL.Image as Image, PIL.ImageDraw as ImageDraw, PIL.ImageFont as ImageFont
from matplotlib import pyplot as plt
import seaborn as sns

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# Using TensorFlow backend.
# /kaggle/input/bengaliai-cv19/test_image_data_2.parquet
# /kaggle/input/bengaliai-cv19/test_image_data_3.parquet
# /kaggle/input/bengaliai-cv19/test_image_data_0.parquet
# /kaggle/input/bengaliai-cv19/train.csv
# /kaggle/input/bengaliai-cv19/class_map_corrected.csv
# /kaggle/input/bengaliai-cv19/test_image_data_1.parquet
# /kaggle/input/bengaliai-cv19/train_multi_diacritics.csv
# /kaggle/input/bengaliai-cv19/class_map.csv
# /kaggle/input/bengaliai-cv19/train_image_data_3.parquet
# /kaggle/input/bengaliai-cv19/train_image_data_2.parquet
# /kaggle/input/bengaliai-cv19/test.csv
# /kaggle/input/bengaliai-cv19/sample_submission.csv
# /kaggle/input/bengaliai-cv19/train_image_data_1.parquet
# /kaggle/input/bengaliai-cv19/train_image_data_0.parquet

# %%
train_df_ = pd.read_csv('/kaggle/input/bengaliai-cv19/train.csv')
test_df_ = pd.read_csv('/kaggle/input/bengaliai-cv19/test.csv')
class_map_df = pd.read_csv('/kaggle/input/bengaliai-cv19/class_map.csv')
sample_sub_df = pd.read_csv('/kaggle/input/bengaliai-cv19/sample_submission.csv')

# %%
train_df_.head()
# Out:
#   image_id  grapheme_root  vowel_diacritic  consonant_diacritic grapheme
# 0  Train_0             15                9                    5   ক্ট্রো
# 1  Train_1            159                0                    0        হ
# 2  Train_2             22                3                    5     খ্রী
# 3  Train_3             53                2                    2     র্টি
# 4  Train_4             71                9                    5     থ্রো

# %%
test_df_.head()
# Out:
#                        row_id image_id            component
# 0  Test_0_consonant_diacritic   Test_0  consonant_diacritic
# 1        Test_0_grapheme_root   Test_0        grapheme_root
# 2      Test_0_vowel_diacritic   Test_0      vowel_diacritic
# 3  Test_1_consonant_diacritic   Test_1  consonant_diacritic
# 4        Test_1_grapheme_root   Test_1        grapheme_root

# %%
sample_sub_df.head()
# Out:
#                        row_id  target
# 0  Test_0_consonant_diacritic       0
# 1        Test_0_grapheme_root       0
# 2      Test_0_vowel_diacritic       0
# 3  Test_1_consonant_diacritic       0
# 4        Test_1_grapheme_root       0

# %%
class_map_df.head()
# Out:
#   component_type  label component
# 0  grapheme_root      0         ং
# 1  grapheme_root      1         ঃ
# 2  grapheme_root      2         অ
# 3  grapheme_root      3         আ
# 4  grapheme_root      4         ই

# %%
print(f'Size of training data: {train_df_.shape}')
print(f'Size of test data: {test_df_.shape}')
print(f'Size of class map: {class_map_df.shape}')
# Out:
# Size of training data: (200840, 5)
# Size of test data: (36, 3)
# Size of class map: (186, 3)

# %% [markdown]
# ## Exploratory Data Analysis
# Exploratory data analysis (EDA) is an approach to analyzing data sets to summarize their main characteristics, often with visual methods.

# %%
HEIGHT = 236
WIDTH = 236

def get_n(df, field, n, top=True):
    top_graphemes = df.groupby([field]).size().reset_index(name='counts')['counts'].sort_values(ascending=not top)[:n]
    top_grapheme_roots = top_graphemes.index
    top_grapheme_counts = top_graphemes.values
    top_graphemes = class_map_df[class_map_df['component_type'] == field].reset_index().iloc[top_grapheme_roots]
    top_graphemes.drop(['component_type', 'label'], axis=1, inplace=True)
    top_graphemes.loc[:, 'count'] = top_grapheme_counts
    return top_graphemes

def image_from_char(char):
    image = Image.new('RGB', (WIDTH, HEIGHT))
    draw = ImageDraw.Draw(image)
    myfont = ImageFont.truetype('/kaggle/input/kalpurush-fonts/kalpurush-2.ttf', 120)
    w, h = draw.textsize(char, font=myfont)
    draw.text(((WIDTH - w) / 2,(HEIGHT - h) / 3), char, font=myfont)

    return image

# %% [markdown]
# ### Number of unique values

# %%
print(f'Number of unique grapheme roots: {train_df_["grapheme_root"].nunique()}')
print(f'Number of unique vowel diacritic: {train_df_["vowel_diacritic"].nunique()}')
print(f'Number of unique consonant diacritic: {train_df_["consonant_diacritic"].nunique()}')
# Out:
# Number of unique grapheme roots: 168
# Number of unique vowel diacritic: 11
# Number of unique consonant diacritic: 7

# %% [markdown]
# ### Most used top 10 Grapheme Roots in training set

# %%
top_10_roots = get_n(train_df_, 'grapheme_root', 10)
top_10_roots
# Out:
#      index component  count
# 72      72         দ   5736
# 64      64         ত   5596
# 13      13         ক   5420
# 107    107         ব   5321
# 23      23         গ   5149
# 96      96         প   4926
# 113    113         ভ   4395
# 147    147         স   4392
# 133    133         শ   4374
# 115    115         ম   4015

# %%
train_df_ = train_df_.drop(['grapheme'], axis=1, inplace=False)

# %%
train_df_[['grapheme_root', 'vowel_diacritic', 'consonant_diacritic']] = train_df_[['grapheme_root', 'vowel_diacritic', 'consonant_diacritic']].astype('uint8')

# %%
IMG_SIZE=64
N_CHANNELS=1

# %% [markdown]
# Let's apply some image processing (credits: [this kernel](https://www.kaggle.com/shawon10/bangla-graphemes-image-processing-deep-cnn)) while resizing the images, which will center crop the region of interest from the original images.

# %%
def resize(df, size=64, need_progress_bar=True):
    resized = {}
    resize_size=64
    if need_progress_bar:
        for i in tqdm(range(df.shape[0])):
            image=df.loc[df.index[i]].values.reshape(137,236)
            _, thresh = cv2.threshold(image, 30, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
            contours, _ = cv2.findContours(thresh,cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)[-2:]

            idx = 0 
            ls_xmin = []
            ls_ymin = []
            ls_xmax = []
            ls_ymax = []
            for cnt in contours:
                idx += 1
                x,y,w,h = cv2.boundingRect(cnt)
                ls_xmin.append(x)
                ls_ymin.append(y)
                ls_xmax.append(x + w)
                ls_ymax.append(y + h)
            xmin = min(ls_xmin)
            ymin = min(ls_ymin)
            xmax = max(ls_xmax)
            ymax = max(ls_ymax)

            roi = image[ymin:ymax,xmin:xmax]
            resized_roi = cv2.resize(roi, (resize_size, resize_size),interpolation=cv2.INTER_AREA)
            resized[df.index[i]] = resized_roi.reshape(-1)
    else:
        for i in range(df.shape[0]):
            #image = cv2.resize(df.loc[df.index[i]].values.reshape(137,236),(size,size),None,fx=0.5,fy=0.5,interpolation=cv2.INTER_AREA)
            image=df.loc[df.index[i]].values.reshape(137,236)
            _, thresh = cv2.threshold(image, 30, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
            contours, _ = cv2.findContours(thresh,cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)[-2:]

            idx = 0 
            ls_xmin = []
            ls_ymin = []
            ls_xmax = []
            ls_ymax = []
            for cnt in contours:
                idx += 1
                x,y,w,h = cv2.boundingRect(cnt)
                ls_xmin.append(x)
                ls_ymin.append(y)
                ls_xmax.append(x + w)
                ls_ymax.append(y + h)
            xmin = min(ls_xmin)
            ymin = min(ls_ymin)
            xmax = max(ls_xmax)
            ymax = max(ls_ymax)

            roi = image[ymin:ymax,xmin:xmax]
            resized_roi = cv2.resize(roi, (resize_size, resize_size),interpolation=cv2.INTER_AREA)
            resized[df.index[i]] = resized_roi.reshape(-1)
    resized = pd.DataFrame(resized).T
    return resized

# %%
def get_dummies(df):
    cols = []
    for col in df:
        cols.append(pd.get_dummies(df[col].astype(str)))
    return pd.concat(cols, axis=1)

# %% [markdown]
# ## Basic Model

# %%
inputs = Input(shape = (IMG_SIZE, IMG_SIZE, 1))

model = Conv2D(filters=32, kernel_size=(3, 3), padding='SAME', activation='relu', input_shape=(IMG_SIZE, IMG_SIZE, 1))(inputs)
model = Conv2D(filters=32, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=32, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=32, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Conv2D(filters=32, kernel_size=(5, 5), padding='SAME', activation='relu')(model)
model = Dropout(rate=0.3)(model)

model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Conv2D(filters=64, kernel_size=(5, 5), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = Dropout(rate=0.3)(model)

model = Conv2D(filters=128, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=128, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=128, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=128, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Conv2D(filters=128, kernel_size=(5, 5), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = Dropout(rate=0.3)(model)

model = Conv2D(filters=256, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=256, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=256, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=256, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Conv2D(filters=256, kernel_size=(5, 5), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = Dropout(rate=0.3)(model)

#model = Flatten()(model)
model = GlobalMaxPooling2D(data_format=None)(model)
model = Dense(1024, activation = "relu")(model)
model = Dropout(rate=0.3)(model)
dense = Dense(512, activation = "relu")(model)

head_root = Dense(168, activation = 'softmax')(dense)
head_vowel = Dense(11, activation = 'softmax')(dense)
head_consonant = Dense(7, activation = 'softmax')(dense)

model = Model(inputs=inputs, outputs=[head_root, head_vowel, head_consonant])

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 64, 64, 1)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 32)   320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 32)   9248        conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 32)   9248        conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 32)   9248        conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 64, 64, 32)   128         conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 32)   25632       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 32, 32, 32)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 64)   18496       dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 64)   36928       conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 64)   36928       conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 64)   36928       conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 64)   256         conv2d_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 64)   102464      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 16, 16, 64)   256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 16, 16, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 128)  73856       dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 128)  147584      conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 128)  147584      conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 128)  147584      conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 128)  512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 128)    0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 128)    409728      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 8, 8, 128)    512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 8, 8, 128)    0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 256)    295168      dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 8, 256)    590080      conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 8, 8, 256)    590080      conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 8, 8, 256)    590080      conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 8, 8, 256)    1024        conv2d_19[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 4, 4, 256)    0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 4, 4, 256)    1638656     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 4, 4, 256)    1024        conv2d_20[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 4, 4, 256)    0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_1 (GlobalM (None, 256)          0           dropout_4[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         263168      global_max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 1024)         0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512)          524800      dropout_5[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 168)          86184       dense_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 11)           5643        dense_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 7)            3591        dense_2[0][0]
# ==================================================================================================
# Total params: 5,802,938
# Trainable params: 5,801,082
# Non-trainable params: 1,856
# __________________________________________________________________________________________________

# %% [markdown]
# Let's visualize the 3-tailed (3 output) CNN by plotting it.

# %%
from keras.utils import plot_model
plot_model(model, to_file='model.png')

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Set a learning rate annealer. Learning rate will be half after 3 epochs if accuracy is not increased
learning_rate_reduction_root = ReduceLROnPlateau(monitor='dense_3_accuracy', 
                                            patience=3, 
                                            verbose=1,
                                            factor=0.5, 
                                            min_lr=0.00001)
learning_rate_reduction_vowel = ReduceLROnPlateau(monitor='dense_4_accuracy', 
                                            patience=3, 
                                            verbose=1,
                                            factor=0.5, 
                                            min_lr=0.00001)
learning_rate_reduction_consonant = ReduceLROnPlateau(monitor='dense_5_accuracy', 
                                            patience=3, 
                                            verbose=1,
                                            factor=0.5, 
                                            min_lr=0.00001)

# %%
batch_size = 256
epochs = 40

# %%
class MultiOutputDataGenerator(keras.preprocessing.image.ImageDataGenerator):

    def flow(self,
             x,
             y=None,
             batch_size=32,
             shuffle=True,
             sample_weight=None,
             seed=None,
             save_to_dir=None,
             save_prefix='',
             save_format='png',
             subset=None):

        targets = None
        target_lengths = {}
        ordered_outputs = []
        for output, target in y.items():
            if targets is None:
                targets = target
            else:
                targets = np.concatenate((targets, target), axis=1)
            target_lengths[output] = target.shape[1]
            ordered_outputs.append(output)


        for flowx, flowy in super().flow(x, targets, batch_size=batch_size,
                                         shuffle=shuffle):
            target_dict = {}
            i = 0
            for output in ordered_outputs:
                target_length = target_lengths[output]
                target_dict[output] = flowy[:, i: i + target_length]
                i += target_length

            yield flowx, target_dict

# %%
HEIGHT = 137
WIDTH = 236

# %% [markdown]
# ### Training loop

# %%
histories = []
for i in range(4):
    train_df = pd.merge(pd.read_parquet(f'/kaggle/input/bengaliai-cv19/train_image_data_{i}.parquet'), train_df_, on='image_id').drop(['image_id'], axis=1)
    
    # Visualize few samples of current training dataset
    fig, ax = plt.subplots(nrows=3, ncols=4, figsize=(16, 8))
    count=0
    for row in ax:
        for col in row:
            col.imshow(resize(train_df.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic'], axis=1).iloc[[count]], need_progress_bar=False).values.reshape(-1).reshape(IMG_SIZE, IMG_SIZE).astype(np.float64))
            count += 1
    plt.show()
    
    X_train = train_df.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic'], axis=1)
    X_train = resize(X_train)/255
    
    # CNN takes images in shape `(batch_size, h, w, channels)`, so reshape the images
    X_train = X_train.values.reshape(-1, IMG_SIZE, IMG_SIZE, N_CHANNELS)
    
    Y_train_root = pd.get_dummies(train_df['grapheme_root']).values
    Y_train_vowel = pd.get_dummies(train_df['vowel_diacritic']).values
    Y_train_consonant = pd.get_dummies(train_df['consonant_diacritic']).values

    print(f'Training images: {X_train.shape}')
    print(f'Training labels root: {Y_train_root.shape}')
    print(f'Training labels vowel: {Y_train_vowel.shape}')
    print(f'Training labels consonants: {Y_train_consonant.shape}')

    # Divide the data into training and validation set
    x_train, x_test, y_train_root, y_test_root, y_train_vowel, y_test_vowel, y_train_consonant, y_test_consonant = train_test_split(X_train, Y_train_root, Y_train_vowel, Y_train_consonant, test_size=0.08, random_state=666)
    del train_df
    del X_train
    del Y_train_root, Y_train_vowel, Y_train_consonant

    # Data augmentation for creating more training data
    datagen = MultiOutputDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=8,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.15, # Randomly zoom image 
        width_shift_range=0.15,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.15,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images


    # This will just calculate parameters required to augment the given data. This won't perform any augmentations
    datagen.fit(x_train)

    # Fit the model
    history = model.fit_generator(datagen.flow(x_train, {'dense_3': y_train_root, 'dense_4': y_train_vowel, 'dense_5': y_train_consonant}, batch_size=batch_size),
                              epochs = epochs, validation_data = (x_test, [y_test_root, y_test_vowel, y_test_consonant]), 
                              steps_per_epoch=x_train.shape[0] // batch_size, 
                              callbacks=[learning_rate_reduction_root, learning_rate_reduction_vowel, learning_rate_reduction_consonant])

    histories.append(history)
    
    # Delete to reduce memory usage
    del x_train
    del x_test
    del y_train_root
    del y_test_root
    del y_train_vowel
    del y_test_vowel
    del y_train_consonant
    del y_test_consonant
    gc.collect()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=50210.0), HTML(value='')))
# Training images: (50210, 64, 64, 1)
# Training labels root: (50210, 168)
# Training labels vowel: (50210, 11)
# Training labels consonants: (50210, 7)
# Epoch 1/40
# 180/180 [==============================] - 45s 252ms/step - loss: 7.8168 - dense_3_loss: 4.7438 - dense_4_loss: 1.9010 - dense_5_loss: 1.1720 - dense_3_accuracy: 0.0308 - dense_4_accuracy: 0.3213 - dense_5_accuracy: 0.6214 - val_loss: 9.1257 - val_dense_3_loss: 5.0555 - val_dense_4_loss: 2.6130 - val_dense_5_loss: 1.4639 - val_dense_3_accuracy: 0.0316 - val_dense_4_accuracy: 0.3480 - val_dense_5_accuracy: 0.5970
# Epoch 2/40
# 180/180 [==============================] - 36s 202ms/step - loss: 6.4089 - dense_3_loss: 4.3348 - dense_4_loss: 1.1510 - dense_5_loss: 0.9231 - dense_3_accuracy: 0.0540 - dense_4_accuracy: 0.5960 - dense_5_accuracy: 0.6713 - val_loss: 5.5169 - val_dense_3_loss: 3.9507 - val_dense_4_loss: 0.8479 - val_dense_5_loss: 0.7221 - val_dense_3_accuracy: 0.0929 - val_dense_4_accuracy: 0.7309 - val_dense_5_accuracy: 0.7391
# Epoch 3/40
# 180/180 [==============================] - 35s 197ms/step - loss: 5.2185 - dense_3_loss: 3.7044 - dense_4_loss: 0.8485 - dense_5_loss: 0.6655 - dense_3_accuracy: 0.1112 - dense_4_accuracy: 0.7116 - dense_5_accuracy: 0.7635 - val_loss: 4.4424 - val_dense_3_loss: 3.3334 - val_dense_4_loss: 0.6294 - val_dense_5_loss: 0.4825 - val_dense_3_accuracy: 0.1613 - val_dense_4_accuracy: 0.7934 - val_dense_5_accuracy: 0.8350
# Epoch 4/40
# 180/180 [==============================] - 36s 200ms/step - loss: 4.1526 - dense_3_loss: 2.9326 - dense_4_loss: 0.7048 - dense_5_loss: 0.5152 - dense_3_accuracy: 0.2261 - dense_4_accuracy: 0.7681 - dense_5_accuracy: 0.8292 - val_loss: 3.1061 - val_dense_3_loss: 2.2561 - val_dense_4_loss: 0.5197 - val_dense_5_loss: 0.3324 - val_dense_3_accuracy: 0.3547 - val_dense_4_accuracy: 0.8322 - val_dense_5_accuracy: 0.8944
# Epoch 5/40
# 180/180 [==============================] - 36s 198ms/step - loss: 3.1695 - dense_3_loss: 2.1579 - dense_4_loss: 0.5926 - dense_5_loss: 0.4190 - dense_3_accuracy: 0.3895 - dense_4_accuracy: 0.8076 - dense_5_accuracy: 0.8626 - val_loss: 2.1089 - val_dense_3_loss: 1.5389 - val_dense_4_loss: 0.3200 - val_dense_5_loss: 0.2515 - val_dense_3_accuracy: 0.5604 - val_dense_4_accuracy: 0.9079 - val_dense_5_accuracy: 0.9186
# Epoch 6/40
# 180/180 [==============================] - 35s 195ms/step - loss: 2.4662 - dense_3_loss: 1.6239 - dense_4_loss: 0.4967 - dense_5_loss: 0.3456 - dense_3_accuracy: 0.5318 - dense_4_accuracy: 0.8432 - dense_5_accuracy: 0.8872 - val_loss: 1.6314 - val_dense_3_loss: 1.1317 - val_dense_4_loss: 0.2634 - val_dense_5_loss: 0.2361 - val_dense_3_accuracy: 0.6697 - val_dense_4_accuracy: 0.9238 - val_dense_5_accuracy: 0.9291
# Epoch 7/40
# 180/180 [==============================] - 36s 199ms/step - loss: 2.0243 - dense_3_loss: 1.2994 - dense_4_loss: 0.4272 - dense_5_loss: 0.2976 - dense_3_accuracy: 0.6231 - dense_4_accuracy: 0.8644 - dense_5_accuracy: 0.9038 - val_loss: 1.3750 - val_dense_3_loss: 0.9310 - val_dense_4_loss: 0.2488 - val_dense_5_loss: 0.1977 - val_dense_3_accuracy: 0.7306 - val_dense_4_accuracy: 0.9281 - val_dense_5_accuracy: 0.9400
# Epoch 8/40
# 180/180 [==============================] - 35s 195ms/step - loss: 1.7538 - dense_3_loss: 1.0974 - dense_4_loss: 0.3842 - dense_5_loss: 0.2722 - dense_3_accuracy: 0.6855 - dense_4_accuracy: 0.8817 - dense_5_accuracy: 0.9143 - val_loss: 1.1504 - val_dense_3_loss: 0.7548 - val_dense_4_loss: 0.2301 - val_dense_5_loss: 0.1663 - val_dense_3_accuracy: 0.7879 - val_dense_4_accuracy: 0.9370 - val_dense_5_accuracy: 0.9525
# Epoch 9/40
# 180/180 [==============================] - 36s 201ms/step - loss: 1.5244 - dense_3_loss: 0.9335 - dense_4_loss: 0.3450 - dense_5_loss: 0.2459 - dense_3_accuracy: 0.7294 - dense_4_accuracy: 0.8930 - dense_5_accuracy: 0.9220 - val_loss: 0.9512 - val_dense_3_loss: 0.6469 - val_dense_4_loss: 0.1607 - val_dense_5_loss: 0.1412 - val_dense_3_accuracy: 0.8153 - val_dense_4_accuracy: 0.9559 - val_dense_5_accuracy: 0.9592
# Epoch 10/40
# 180/180 [==============================] - 36s 198ms/step - loss: 1.3900 - dense_3_loss: 0.8440 - dense_4_loss: 0.3235 - dense_5_loss: 0.2225 - dense_3_accuracy: 0.7556 - dense_4_accuracy: 0.9011 - dense_5_accuracy: 0.9289 - val_loss: 0.9215 - val_dense_3_loss: 0.6186 - val_dense_4_loss: 0.1645 - val_dense_5_loss: 0.1351 - val_dense_3_accuracy: 0.8272 - val_dense_4_accuracy: 0.9554 - val_dense_5_accuracy: 0.9622
# Epoch 11/40
# 180/180 [==============================] - 35s 197ms/step - loss: 1.2705 - dense_3_loss: 0.7537 - dense_4_loss: 0.3037 - dense_5_loss: 0.2131 - dense_3_accuracy: 0.7826 - dense_4_accuracy: 0.9074 - dense_5_accuracy: 0.9327 - val_loss: 0.8715 - val_dense_3_loss: 0.5880 - val_dense_4_loss: 0.1536 - val_dense_5_loss: 0.1302 - val_dense_3_accuracy: 0.8434 - val_dense_4_accuracy: 0.9569 - val_dense_5_accuracy: 0.9602
# Epoch 12/40
# 180/180 [==============================] - 36s 199ms/step - loss: 1.1979 - dense_3_loss: 0.7061 - dense_4_loss: 0.2914 - dense_5_loss: 0.2004 - dense_3_accuracy: 0.7970 - dense_4_accuracy: 0.9114 - dense_5_accuracy: 0.9362 - val_loss: 0.7808 - val_dense_3_loss: 0.5124 - val_dense_4_loss: 0.1546 - val_dense_5_loss: 0.1129 - val_dense_3_accuracy: 0.8653 - val_dense_4_accuracy: 0.9592 - val_dense_5_accuracy: 0.9669
# Epoch 13/40
# 180/180 [==============================] - 35s 195ms/step - loss: 1.1200 - dense_3_loss: 0.6541 - dense_4_loss: 0.2754 - dense_5_loss: 0.1905 - dense_3_accuracy: 0.8105 - dense_4_accuracy: 0.9170 - dense_5_accuracy: 0.9398 - val_loss: 0.7570 - val_dense_3_loss: 0.5021 - val_dense_4_loss: 0.1471 - val_dense_5_loss: 0.1068 - val_dense_3_accuracy: 0.8628 - val_dense_4_accuracy: 0.9604 - val_dense_5_accuracy: 0.9671
# Epoch 14/40
# 180/180 [==============================] - 36s 200ms/step - loss: 1.0615 - dense_3_loss: 0.6099 - dense_4_loss: 0.2641 - dense_5_loss: 0.1875 - dense_3_accuracy: 0.8241 - dense_4_accuracy: 0.9207 - dense_5_accuracy: 0.9421 - val_loss: 0.6784 - val_dense_3_loss: 0.4683 - val_dense_4_loss: 0.1162 - val_dense_5_loss: 0.0961 - val_dense_3_accuracy: 0.8743 - val_dense_4_accuracy: 0.9701 - val_dense_5_accuracy: 0.9711
# Epoch 15/40
# 180/180 [==============================] - 36s 198ms/step - loss: 1.0091 - dense_3_loss: 0.5784 - dense_4_loss: 0.2565 - dense_5_loss: 0.1741 - dense_3_accuracy: 0.8311 - dense_4_accuracy: 0.9236 - dense_5_accuracy: 0.9453 - val_loss: 0.7237 - val_dense_3_loss: 0.4800 - val_dense_4_loss: 0.1374 - val_dense_5_loss: 0.1068 - val_dense_3_accuracy: 0.8720 - val_dense_4_accuracy: 0.9659 - val_dense_5_accuracy: 0.9674
# Epoch 16/40
# 180/180 [==============================] - 36s 198ms/step - loss: 0.9666 - dense_3_loss: 0.5494 - dense_4_loss: 0.2498 - dense_5_loss: 0.1673 - dense_3_accuracy: 0.8402 - dense_4_accuracy: 0.9264 - dense_5_accuracy: 0.9477 - val_loss: 0.6874 - val_dense_3_loss: 0.4479 - val_dense_4_loss: 0.1361 - val_dense_5_loss: 0.1017 - val_dense_3_accuracy: 0.8855 - val_dense_4_accuracy: 0.9671 - val_dense_5_accuracy: 0.9681
# Epoch 17/40
# 180/180 [==============================] - 36s 200ms/step - loss: 0.9024 - dense_3_loss: 0.5171 - dense_4_loss: 0.2288 - dense_5_loss: 0.1565 - dense_3_accuracy: 0.8504 - dense_4_accuracy: 0.9321 - dense_5_accuracy: 0.9513 - val_loss: 0.6453 - val_dense_3_loss: 0.4239 - val_dense_4_loss: 0.1226 - val_dense_5_loss: 0.0974 - val_dense_3_accuracy: 0.8840 - val_dense_4_accuracy: 0.9681 - val_dense_5_accuracy: 0.9721
# Epoch 18/40
# 180/180 [==============================] - 35s 197ms/step - loss: 0.8624 - dense_3_loss: 0.4935 - dense_4_loss: 0.2214 - dense_5_loss: 0.1475 - dense_3_accuracy: 0.8561 - dense_4_accuracy: 0.9329 - dense_5_accuracy: 0.9542 - val_loss: 0.7549 - val_dense_3_loss: 0.4129 - val_dense_4_loss: 0.2403 - val_dense_5_loss: 0.1052 - val_dense_3_accuracy: 0.8964 - val_dense_4_accuracy: 0.9497 - val_dense_5_accuracy: 0.9681
# Epoch 19/40
# 180/180 [==============================] - 36s 202ms/step - loss: 0.8451 - dense_3_loss: 0.4749 - dense_4_loss: 0.2217 - dense_5_loss: 0.1484 - dense_3_accuracy: 0.8614 - dense_4_accuracy: 0.9330 - dense_5_accuracy: 0.9542 - val_loss: 0.6104 - val_dense_3_loss: 0.4014 - val_dense_4_loss: 0.1193 - val_dense_5_loss: 0.0893 - val_dense_3_accuracy: 0.8930 - val_dense_4_accuracy: 0.9719 - val_dense_5_accuracy: 0.9761
# Epoch 20/40
# 180/180 [==============================] - 36s 199ms/step - loss: 0.8105 - dense_3_loss: 0.4559 - dense_4_loss: 0.2125 - dense_5_loss: 0.1421 - dense_3_accuracy: 0.8644 - dense_4_accuracy: 0.9369 - dense_5_accuracy: 0.9561 - val_loss: 0.6435 - val_dense_3_loss: 0.4281 - val_dense_4_loss: 0.1215 - val_dense_5_loss: 0.0956 - val_dense_3_accuracy: 0.8912 - val_dense_4_accuracy: 0.9716 - val_dense_5_accuracy: 0.9744
# Epoch 21/40
# 180/180 [==============================] - 36s 198ms/step - loss: 0.7924 - dense_3_loss: 0.4402 - dense_4_loss: 0.2087 - dense_5_loss: 0.1436 - dense_3_accuracy: 0.8691 - dense_4_accuracy: 0.9379 - dense_5_accuracy: 0.9550 - val_loss: 0.6412 - val_dense_3_loss: 0.4042 - val_dense_4_loss: 0.1234 - val_dense_5_loss: 0.1126 - val_dense_3_accuracy: 0.9007 - val_dense_4_accuracy: 0.9669 - val_dense_5_accuracy: 0.9681
# Epoch 22/40
# 180/180 [==============================] - 36s 202ms/step - loss: 0.7690 - dense_3_loss: 0.4268 - dense_4_loss: 0.2042 - dense_5_loss: 0.1381 - dense_3_accuracy: 0.8735 - dense_4_accuracy: 0.9397 - dense_5_accuracy: 0.9575 - val_loss: 0.6339 - val_dense_3_loss: 0.4296 - val_dense_4_loss: 0.1127 - val_dense_5_loss: 0.0928 - val_dense_3_accuracy: 0.8927 - val_dense_4_accuracy: 0.9734 - val_dense_5_accuracy: 0.9744
# Epoch 23/40
# 180/180 [==============================] - 36s 198ms/step - loss: 0.7447 - dense_3_loss: 0.4117 - dense_4_loss: 0.2011 - dense_5_loss: 0.1320 - dense_3_accuracy: 0.8779 - dense_4_accuracy: 0.9405 - dense_5_accuracy: 0.9587 - val_loss: 0.5949 - val_dense_3_loss: 0.3983 - val_dense_4_loss: 0.1105 - val_dense_5_loss: 0.0870 - val_dense_3_accuracy: 0.9029 - val_dense_4_accuracy: 0.9746 - val_dense_5_accuracy: 0.9746
# Epoch 24/40
# 180/180 [==============================] - 36s 201ms/step - loss: 0.7012 - dense_3_loss: 0.3837 - dense_4_loss: 0.1905 - dense_5_loss: 0.1270 - dense_3_accuracy: 0.8874 - dense_4_accuracy: 0.9440 - dense_5_accuracy: 0.9612 - val_loss: 0.6330 - val_dense_3_loss: 0.4083 - val_dense_4_loss: 0.1291 - val_dense_5_loss: 0.0960 - val_dense_3_accuracy: 0.9017 - val_dense_4_accuracy: 0.9729 - val_dense_5_accuracy: 0.9724
# Epoch 25/40
# 180/180 [==============================] - 36s 201ms/step - loss: 0.7062 - dense_3_loss: 0.3845 - dense_4_loss: 0.1906 - dense_5_loss: 0.1311 - dense_3_accuracy: 0.8877 - dense_4_accuracy: 0.9435 - dense_5_accuracy: 0.9574 - val_loss: 0.6103 - val_dense_3_loss: 0.3996 - val_dense_4_loss: 0.1138 - val_dense_5_loss: 0.0951 - val_dense_3_accuracy: 0.9019 - val_dense_4_accuracy: 0.9726 - val_dense_5_accuracy: 0.9761
# Epoch 26/40
# 180/180 [==============================] - 36s 198ms/step - loss: 0.6861 - dense_3_loss: 0.3751 - dense_4_loss: 0.1860 - dense_5_loss: 0.1250 - dense_3_accuracy: 0.8881 - dense_4_accuracy: 0.9445 - dense_5_accuracy: 0.9610 - val_loss: 0.5720 - val_dense_3_loss: 0.3559 - val_dense_4_loss: 0.1276 - val_dense_5_loss: 0.0870 - val_dense_3_accuracy: 0.9126 - val_dense_4_accuracy: 0.9669 - val_dense_5_accuracy: 0.9759
# Epoch 27/40
# 180/180 [==============================] - 36s 200ms/step - loss: 0.6775 - dense_3_loss: 0.3706 - dense_4_loss: 0.1824 - dense_5_loss: 0.1245 - dense_3_accuracy: 0.8905 - dense_4_accuracy: 0.9464 - dense_5_accuracy: 0.9625 - val_loss: 0.6239 - val_dense_3_loss: 0.4088 - val_dense_4_loss: 0.1223 - val_dense_5_loss: 0.0931 - val_dense_3_accuracy: 0.9052 - val_dense_4_accuracy: 0.9734 - val_dense_5_accuracy: 0.9739
# Epoch 28/40
# 180/180 [==============================] - 36s 197ms/step - loss: 0.6468 - dense_3_loss: 0.3521 - dense_4_loss: 0.1752 - dense_5_loss: 0.1195 - dense_3_accuracy: 0.8954 - dense_4_accuracy: 0.9491 - dense_5_accuracy: 0.9640 - val_loss: 0.6238 - val_dense_3_loss: 0.4111 - val_dense_4_loss: 0.1179 - val_dense_5_loss: 0.0953 - val_dense_3_accuracy: 0.9069 - val_dense_4_accuracy: 0.9729 - val_dense_5_accuracy: 0.9739
# Epoch 29/40
# 180/180 [==============================] - 36s 201ms/step - loss: 0.6355 - dense_3_loss: 0.3443 - dense_4_loss: 0.1771 - dense_5_loss: 0.1142 - dense_3_accuracy: 0.8989 - dense_4_accuracy: 0.9475 - dense_5_accuracy: 0.9648 - val_loss: 0.5916 - val_dense_3_loss: 0.3882 - val_dense_4_loss: 0.1102 - val_dense_5_loss: 0.0966 - val_dense_3_accuracy: 0.9111 - val_dense_4_accuracy: 0.9741 - val_dense_5_accuracy: 0.9724
# Epoch 30/40
# 180/180 [==============================] - 36s 198ms/step - loss: 0.6366 - dense_3_loss: 0.3491 - dense_4_loss: 0.1704 - dense_5_loss: 0.1171 - dense_3_accuracy: 0.8973 - dense_4_accuracy: 0.9490 - dense_5_accuracy: 0.9628 - val_loss: 0.6295 - val_dense_3_loss: 0.4161 - val_dense_4_loss: 0.1217 - val_dense_5_loss: 0.0919 - val_dense_3_accuracy: 0.9096 - val_dense_4_accuracy: 0.9719 - val_dense_5_accuracy: 0.9761
# Epoch 31/40
# 180/180 [==============================] - 36s 198ms/step - loss: 0.6145 - dense_3_loss: 0.3286 - dense_4_loss: 0.1701 - dense_5_loss: 0.1158 - dense_3_accuracy: 0.9025 - dense_4_accuracy: 0.9499 - dense_5_accuracy: 0.9655 - val_loss: 0.6026 - val_dense_3_loss: 0.4064 - val_dense_4_loss: 0.1117 - val_dense_5_loss: 0.0843 - val_dense_3_accuracy: 0.9091 - val_dense_4_accuracy: 0.9761 - val_dense_5_accuracy: 0.9776
# Epoch 32/40
# 180/180 [==============================] - 36s 202ms/step - loss: 0.6274 - dense_3_loss: 0.3349 - dense_4_loss: 0.1773 - dense_5_loss: 0.1152 - dense_3_accuracy: 0.9031 - dense_4_accuracy: 0.9472 - dense_5_accuracy: 0.9652 - val_loss: 0.6344 - val_dense_3_loss: 0.4225 - val_dense_4_loss: 0.1196 - val_dense_5_loss: 0.0917 - val_dense_3_accuracy: 0.9061 - val_dense_4_accuracy: 0.9741 - val_dense_5_accuracy: 0.9749
# Epoch 33/40
# 180/180 [==============================] - 35s 195ms/step - loss: 0.5982 - dense_3_loss: 0.3165 - dense_4_loss: 0.1687 - dense_5_loss: 0.1130 - dense_3_accuracy: 0.9049 - dense_4_accuracy: 0.9499 - dense_5_accuracy: 0.9658 - val_loss: 0.7014 - val_dense_3_loss: 0.4837 - val_dense_4_loss: 0.1275 - val_dense_5_loss: 0.0905 - val_dense_3_accuracy: 0.9012 - val_dense_4_accuracy: 0.9754 - val_dense_5_accuracy: 0.9781
# Epoch 34/40
# 180/180 [==============================] - 36s 200ms/step - loss: 0.5748 - dense_3_loss: 0.3026 - dense_4_loss: 0.1632 - dense_5_loss: 0.1091 - dense_3_accuracy: 0.9097 - dense_4_accuracy: 0.9516 - dense_5_accuracy: 0.9665 - val_loss: 0.5751 - val_dense_3_loss: 0.3677 - val_dense_4_loss: 0.1187 - val_dense_5_loss: 0.0872 - val_dense_3_accuracy: 0.9181 - val_dense_4_accuracy: 0.9746 - val_dense_5_accuracy: 0.9756
# Epoch 35/40
# 180/180 [==============================] - 35s 197ms/step - loss: 0.5684 - dense_3_loss: 0.2983 - dense_4_loss: 0.1646 - dense_5_loss: 0.1055 - dense_3_accuracy: 0.9113 - dense_4_accuracy: 0.9533 - dense_5_accuracy: 0.9676 - val_loss: 0.6110 - val_dense_3_loss: 0.4238 - val_dense_4_loss: 0.1106 - val_dense_5_loss: 0.0767 - val_dense_3_accuracy: 0.9159 - val_dense_4_accuracy: 0.9761 - val_dense_5_accuracy: 0.9791
# Epoch 36/40
# 180/180 [==============================] - 36s 198ms/step - loss: 0.5429 - dense_3_loss: 0.2861 - dense_4_loss: 0.1542 - dense_5_loss: 0.1026 - dense_3_accuracy: 0.9153 - dense_4_accuracy: 0.9546 - dense_5_accuracy: 0.9678 - val_loss: 0.6066 - val_dense_3_loss: 0.4007 - val_dense_4_loss: 0.1145 - val_dense_5_loss: 0.0876 - val_dense_3_accuracy: 0.9134 - val_dense_4_accuracy: 0.9749 - val_dense_5_accuracy: 0.9778
# Epoch 37/40
# 180/180 [==============================] - 36s 202ms/step - loss: 0.5615 - dense_3_loss: 0.2953 - dense_4_loss: 0.1592 - dense_5_loss: 0.1070 - dense_3_accuracy: 0.9118 - dense_4_accuracy: 0.9533 - dense_5_accuracy: 0.9661 - val_loss: 0.6360 - val_dense_3_loss: 0.4219 - val_dense_4_loss: 0.1251 - val_dense_5_loss: 0.0901 - val_dense_3_accuracy: 0.9101 - val_dense_4_accuracy: 0.9761 - val_dense_5_accuracy: 0.9773
# Epoch 38/40
# 180/180 [==============================] - 35s 195ms/step - loss: 0.5495 - dense_3_loss: 0.2840 - dense_4_loss: 0.1585 - dense_5_loss: 0.1070 - dense_3_accuracy: 0.9160 - dense_4_accuracy: 0.9542 - dense_5_accuracy: 0.9677 - val_loss: 0.6810 - val_dense_3_loss: 0.4472 - val_dense_4_loss: 0.1425 - val_dense_5_loss: 0.0950 - val_dense_3_accuracy: 0.9086 - val_dense_4_accuracy: 0.9731 - val_dense_5_accuracy: 0.9771
# Epoch 39/40
# 180/180 [==============================] - 36s 201ms/step - loss: 0.5397 - dense_3_loss: 0.2830 - dense_4_loss: 0.1526 - dense_5_loss: 0.1041 - dense_3_accuracy: 0.9152 - dense_4_accuracy: 0.9558 - dense_5_accuracy: 0.9682 - val_loss: 0.6373 - val_dense_3_loss: 0.4271 - val_dense_4_loss: 0.1159 - val_dense_5_loss: 0.0952 - val_dense_3_accuracy: 0.9096 - val_dense_4_accuracy: 0.9749 - val_dense_5_accuracy: 0.9759
# Epoch 40/40
# 180/180 [==============================] - 35s 195ms/step - loss: 0.5240 - dense_3_loss: 0.2696 - dense_4_loss: 0.1523 - dense_5_loss: 0.1021 - dense_3_accuracy: 0.9199 - dense_4_accuracy: 0.9558 - dense_5_accuracy: 0.9685 - val_loss: 0.6173 - val_dense_3_loss: 0.4022 - val_dense_4_loss: 0.1218 - val_dense_5_loss: 0.0930 - val_dense_3_accuracy: 0.9156 - val_dense_4_accuracy: 0.9773 - val_dense_5_accuracy: 0.9739
# HBox(children=(FloatProgress(value=0.0, max=50210.0), HTML(value='')))
# Training images: (50210, 64, 64, 1)
# Training labels root: (50210, 168)
# Training labels vowel: (50210, 11)
# Training labels consonants: (50210, 7)
# Epoch 1/40
# 180/180 [==============================] - 37s 206ms/step - loss: 0.8489 - dense_3_loss: 0.4909 - dense_4_loss: 0.2021 - dense_5_loss: 0.1559 - dense_3_accuracy: 0.8685 - dense_4_accuracy: 0.9431 - dense_5_accuracy: 0.9540 - val_loss: 0.6476 - val_dense_3_loss: 0.4018 - val_dense_4_loss: 0.1325 - val_dense_5_loss: 0.1125 - val_dense_3_accuracy: 0.9161 - val_dense_4_accuracy: 0.9701 - val_dense_5_accuracy: 0.9739
# Epoch 2/40
# 180/180 [==============================] - 37s 204ms/step - loss: 0.7444 - dense_3_loss: 0.4167 - dense_4_loss: 0.1928 - dense_5_loss: 0.1349 - dense_3_accuracy: 0.8837 - dense_4_accuracy: 0.9454 - dense_5_accuracy: 0.9598 - val_loss: 0.7370 - val_dense_3_loss: 0.4262 - val_dense_4_loss: 0.2059 - val_dense_5_loss: 0.1025 - val_dense_3_accuracy: 0.9144 - val_dense_4_accuracy: 0.9435 - val_dense_5_accuracy: 0.9771
# Epoch 3/40
# 180/180 [==============================] - 36s 202ms/step - loss: 0.6935 - dense_3_loss: 0.3815 - dense_4_loss: 0.1860 - dense_5_loss: 0.1260 - dense_3_accuracy: 0.8919 - dense_4_accuracy: 0.9469 - dense_5_accuracy: 0.9623 - val_loss: 0.5797 - val_dense_3_loss: 0.3665 - val_dense_4_loss: 0.1168 - val_dense_5_loss: 0.0950 - val_dense_3_accuracy: 0.9213 - val_dense_4_accuracy: 0.9721 - val_dense_5_accuracy: 0.9776
# Epoch 4/40
# 180/180 [==============================] - 36s 199ms/step - loss: 0.6670 - dense_3_loss: 0.3661 - dense_4_loss: 0.1800 - dense_5_loss: 0.1209 - dense_3_accuracy: 0.8957 - dense_4_accuracy: 0.9478 - dense_5_accuracy: 0.9644 - val_loss: 0.7191 - val_dense_3_loss: 0.4692 - val_dense_4_loss: 0.1436 - val_dense_5_loss: 0.1044 - val_dense_3_accuracy: 0.9096 - val_dense_4_accuracy: 0.9699 - val_dense_5_accuracy: 0.9768
# Epoch 5/40
# 180/180 [==============================] - 36s 198ms/step - loss: 0.6385 - dense_3_loss: 0.3474 - dense_4_loss: 0.1698 - dense_5_loss: 0.1213 - dense_3_accuracy: 0.8996 - dense_4_accuracy: 0.9513 - dense_5_accuracy: 0.9635 - val_loss: 0.6527 - val_dense_3_loss: 0.4154 - val_dense_4_loss: 0.1305 - val_dense_5_loss: 0.1035 - val_dense_3_accuracy: 0.9181 - val_dense_4_accuracy: 0.9719 - val_dense_5_accuracy: 0.9771
# Epoch 6/40
# 180/180 [==============================] - 36s 201ms/step - loss: 0.6019 - dense_3_loss: 0.3271 - dense_4_loss: 0.1649 - dense_5_loss: 0.1099 - dense_3_accuracy: 0.9048 - dense_4_accuracy: 0.9525 - dense_5_accuracy: 0.9672 - val_loss: 0.6291 - val_dense_3_loss: 0.3940 - val_dense_4_loss: 0.1153 - val_dense_5_loss: 0.1163 - val_dense_3_accuracy: 0.9196 - val_dense_4_accuracy: 0.9749 - val_dense_5_accuracy: 0.9764
# Epoch 7/40
# 180/180 [==============================] - 35s 196ms/step - loss: 0.2083 - dense_3_loss: 0.0940 - dense_4_loss: 0.0695 - dense_5_loss: 0.0448 - dense_3_accuracy: 0.9697 - dense_4_accuracy: 0.9792 - dense_5_accuracy: 0.9864 - val_loss: 0.6147 - val_dense_3_loss: 0.3821 - val_dense_4_loss: 0.1184 - val_dense_5_loss: 0.1123 - val_dense_3_accuracy: 0.9425 - val_dense_4_accuracy: 0.9806 - val_dense_5_accuracy: 0.9841
# Epoch 38/40
# 180/180 [==============================] - 36s 198ms/step - loss: 0.2097 - dense_3_loss: 0.0953 - dense_4_loss: 0.0705 - dense_5_loss: 0.0439 - dense_3_accuracy: 0.9700 - dense_4_accuracy: 0.9790 - dense_5_accuracy: 0.9864 - val_loss: 0.6469 - val_dense_3_loss: 0.4064 - val_dense_4_loss: 0.1180 - val_dense_5_loss: 0.1205 - val_dense_3_accuracy: 0.9368 - val_dense_4_accuracy: 0.9791 - val_dense_5_accuracy: 0.9833
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 39/40
# 180/180 [==============================] - 35s 194ms/step - loss: 0.2008 - dense_3_loss: 0.0902 - dense_4_loss: 0.0670 - dense_5_loss: 0.0437 - dense_3_accuracy: 0.9715 - dense_4_accuracy: 0.9795 - dense_5_accuracy: 0.9867 - val_loss: 0.6346 - val_dense_3_loss: 0.4076 - val_dense_4_loss: 0.1047 - val_dense_5_loss: 0.1200 - val_dense_3_accuracy: 0.9393 - val_dense_4_accuracy: 0.9821 - val_dense_5_accuracy: 0.9811
# Epoch 40/40
# 180/180 [==============================] - 36s 198ms/step - loss: 0.2031 - dense_3_loss: 0.0882 - dense_4_loss: 0.0722 - dense_5_loss: 0.0427 - dense_3_accuracy: 0.9719 - dense_4_accuracy: 0.9784 - dense_5_accuracy: 0.9873 - val_loss: 0.6589 - val_dense_3_loss: 0.4075 - val_dense_4_loss: 0.1185 - val_dense_5_loss: 0.1309 - val_dense_3_accuracy: 0.9412 - val_dense_4_accuracy: 0.9781 - val_dense_5_accuracy: 0.9801
# HBox(children=(FloatProgress(value=0.0, max=50210.0), HTML(value='')))
# Training images: (50210, 64, 64, 1)
# Training labels root: (50210, 168)
# Training labels vowel: (50210, 11)
# Training labels consonants: (50210, 7)
# Epoch 1/40
# 180/180 [==============================] - 35s 197ms/step - loss: 0.3940 - dense_3_loss: 0.2141 - dense_4_loss: 0.1038 - dense_5_loss: 0.0761 - dense_3_accuracy: 0.9380 - dense_4_accuracy: 0.9701 - dense_5_accuracy: 0.9779 - val_loss: 0.5261 - val_dense_3_loss: 0.3485 - val_dense_4_loss: 0.0939 - val_dense_5_loss: 0.0924 - val_dense_3_accuracy: 0.9440 - val_dense_4_accuracy: 0.9811 - val_dense_5_accuracy: 0.9811
# Epoch 24/40
# 180/180 [==============================] - 36s 199ms/step - loss: 0.3944 - dense_3_loss: 0.2121 - dense_4_loss: 0.1059 - dense_5_loss: 0.0764 - dense_3_accuracy: 0.9384 - dense_4_accuracy: 0.9699 - dense_5_accuracy: 0.9775 - val_loss: 0.5855 - val_dense_3_loss: 0.3835 - val_dense_4_loss: 0.1123 - val_dense_5_loss: 0.0984 - val_dense_3_accuracy: 0.9412 - val_dense_4_accuracy: 0.9793 - val_dense_5_accuracy: 0.9808
# Epoch 25/40
# 180/180 [==============================] - 35s 195ms/step - loss: 0.3897 - dense_3_loss: 0.2112 - dense_4_loss: 0.1050 - dense_5_loss: 0.0735 - dense_3_accuracy: 0.9377 - dense_4_accuracy: 0.9704 - dense_5_accuracy: 0.9777 - val_loss: 0.5407 - val_dense_3_loss: 0.3560 - val_dense_4_loss: 0.0979 - val_dense_5_loss: 0.0954 - val_dense_3_accuracy: 0.9432 - val_dense_4_accuracy: 0.9816 - val_dense_5_accuracy: 0.9793
# Epoch 26/40
# 180/180 [==============================] - 36s 199ms/step - loss: 0.3898 - dense_3_loss: 0.2119 - dense_4_loss: 0.1041 - dense_5_loss: 0.0738 - dense_3_accuracy: 0.9387 - dense_4_accuracy: 0.9705 - dense_5_accuracy: 0.9774 - val_loss: 0.5911 - val_dense_3_loss: 0.3842 - val_dense_4_loss: 0.1104 - val_dense_5_loss: 0.1049 - val_dense_3_accuracy: 0.9408 - val_dense_4_accuracy: 0.9806 - val_dense_5_accuracy: 0.9786
# Epoch 27/40
# 180/180 [==============================] - 35s 196ms/step - loss: 0.3919 - dense_3_loss: 0.2107 - dense_4_loss: 0.1066 - dense_5_loss: 0.0746 - dense_3_accuracy: 0.9389 - dense_4_accuracy: 0.9693 - dense_5_accuracy: 0.9777 - val_loss: 0.5341 - val_dense_3_loss: 0.3486 - val_dense_4_loss: 0.1015 - val_dense_5_loss: 0.0930 - val_dense_3_accuracy: 0.9430 - val_dense_4_accuracy: 0.9796 - val_dense_5_accuracy: 0.9803
# Epoch 28/40
# 180/180 [==============================] - 36s 198ms/step - loss: 0.3859 - dense_3_loss: 0.2108 - dense_4_loss: 0.1012 - dense_5_loss: 0.0739 - dense_3_accuracy: 0.9385 - dense_4_accuracy: 0.9704 - dense_5_accuracy: 0.9761 - val_loss: 0.5421 - val_dense_3_loss: 0.3589 - val_dense_4_loss: 0.0931 - val_dense_5_loss: 0.0985 - val_dense_3_accuracy: 0.9422 - val_dense_4_accuracy: 0.9836 - val_dense_5_accuracy: 0.9798
# Epoch 29/40
# 180/180 [==============================] - 36s 199ms/step - loss: 0.3983 - dense_3_loss: 0.2168 - dense_4_loss: 0.1068 - dense_5_loss: 0.0747 - dense_3_accuracy: 0.9371 - dense_4_accuracy: 0.9691 - dense_5_accuracy: 0.9777 - val_loss: 0.5570 - val_dense_3_loss: 0.3550 - val_dense_4_loss: 0.1124 - val_dense_5_loss: 0.0990 - val_dense_3_accuracy: 0.9422 - val_dense_4_accuracy: 0.9796 - val_dense_5_accuracy: 0.9791
# Epoch 30/40
# 180/180 [==============================] - 35s 195ms/step - loss: 0.3931 - dense_3_loss: 0.2115 - dense_4_loss: 0.1071 - dense_5_loss: 0.0744 - dense_3_accuracy: 0.9386 - dense_4_accuracy: 0.9691 - dense_5_accuracy: 0.9777 - val_loss: 0.5350 - val_dense_3_loss: 0.3483 - val_dense_4_loss: 0.0886 - val_dense_5_loss: 0.1072 - val_dense_3_accuracy: 0.9437 - val_dense_4_accuracy: 0.9813 - val_dense_5_accuracy: 0.9773
# Epoch 31/40
# 180/180 [==============================] - 36s 199ms/step - loss: 0.4704 - dense_3_loss: 0.2648 - dense_4_loss: 0.1200 - dense_5_loss: 0.0856 - dense_3_accuracy: 0.9271 - dense_4_accuracy: 0.9666 - dense_5_accuracy: 0.9750 - val_loss: 0.5575 - val_dense_3_loss: 0.3528 - val_dense_4_loss: 0.1261 - val_dense_5_loss: 0.0775 - val_dense_3_accuracy: 0.9425 - val_dense_4_accuracy: 0.9808 - val_dense_5_accuracy: 0.9846
# Epoch 9/40
# 180/180 [==============================] - 35s 194ms/step - loss: 0.4634 - dense_3_loss: 0.2622 - dense_4_loss: 0.1174 - dense_5_loss: 0.0838 - dense_3_accuracy: 0.9281 - dense_4_accuracy: 0.9668 - dense_5_accuracy: 0.9754 - val_loss: 0.5512 - val_dense_3_loss: 0.3417 - val_dense_4_loss: 0.1278 - val_dense_5_loss: 0.0810 - val_dense_3_accuracy: 0.9410 - val_dense_4_accuracy: 0.9806 - val_dense_5_accuracy: 0.9843
# Epoch 10/40
# 180/180 [==============================] - 36s 200ms/step - loss: 0.4585 - dense_3_loss: 0.2617 - dense_4_loss: 0.1132 - dense_5_loss: 0.0837 - dense_3_accuracy: 0.9272 - dense_4_accuracy: 0.9681 - dense_5_accuracy: 0.9750 - val_loss: 0.5694 - val_dense_3_loss: 0.3583 - val_dense_4_loss: 0.1298 - val_dense_5_loss: 0.0809 - val_dense_3_accuracy: 0.9427 - val_dense_4_accuracy: 0.9796 - val_dense_5_accuracy: 0.9846
# Epoch 11/40
# 180/180 [==============================] - 36s 199ms/step - loss: 0.4455 - dense_3_loss: 0.2486 - dense_4_loss: 0.1157 - dense_5_loss: 0.0812 - dense_3_accuracy: 0.9321 - dense_4_accuracy: 0.9670 - dense_5_accuracy: 0.9764 - val_loss: 0.5574 - val_dense_3_loss: 0.3515 - val_dense_4_loss: 0.1266 - val_dense_5_loss: 0.0781 - val_dense_3_accuracy: 0.9408 - val_dense_4_accuracy: 0.9808 - val_dense_5_accuracy: 0.9848
# Epoch 23/40
# 180/180 [==============================] - 35s 193ms/step - loss: 0.4375 - dense_3_loss: 0.2463 - dense_4_loss: 0.1135 - dense_5_loss: 0.0777 - dense_3_accuracy: 0.9318 - dense_4_accuracy: 0.9672 - dense_5_accuracy: 0.9768 - val_loss: 0.5071 - val_dense_3_loss: 0.3181 - val_dense_4_loss: 0.1151 - val_dense_5_loss: 0.0734 - val_dense_3_accuracy: 0.9457 - val_dense_4_accuracy: 0.9813 - val_dense_5_accuracy: 0.9848
# Epoch 24/40
# 180/180 [==============================] - 36s 199ms/step - loss: 0.4355 - dense_3_loss: 0.2426 - dense_4_loss: 0.1130 - dense_5_loss: 0.0800 - dense_3_accuracy: 0.9308 - dense_4_accuracy: 0.9682 - dense_5_accuracy: 0.9760 - val_loss: 0.5264 - val_dense_3_loss: 0.3258 - val_dense_4_loss: 0.1189 - val_dense_5_loss: 0.0808 - val_dense_3_accuracy: 0.9455 - val_dense_4_accuracy: 0.9811 - val_dense_5_accuracy: 0.9833
# Epoch 25/40
# 180/180 [==============================] - 36s 198ms/step - loss: 0.4144 - dense_3_loss: 0.2291 - dense_4_loss: 0.1078 - dense_5_loss: 0.0774 - dense_3_accuracy: 0.9355 - dense_4_accuracy: 0.9692 - dense_5_accuracy: 0.9778 - val_loss: 0.5329 - val_dense_3_loss: 0.3410 - val_dense_4_loss: 0.1178 - val_dense_5_loss: 0.0721 - val_dense_3_accuracy: 0.9420 - val_dense_4_accuracy: 0.9806 - val_dense_5_accuracy: 0.9851
# Epoch 38/40
# 180/180 [==============================] - 35s 194ms/step - loss: 0.4042 - dense_3_loss: 0.2243 - dense_4_loss: 0.1042 - dense_5_loss: 0.0756 - dense_3_accuracy: 0.9360 - dense_4_accuracy: 0.9698 - dense_5_accuracy: 0.9779 - val_loss: 0.5438 - val_dense_3_loss: 0.3367 - val_dense_4_loss: 0.1233 - val_dense_5_loss: 0.0829 - val_dense_3_accuracy: 0.9447 - val_dense_4_accuracy: 0.9811 - val_dense_5_accuracy: 0.9831
# Epoch 39/40
# 165/180 [==========================>...] - ETA: 2s - loss: 0.4134 - dense_3_loss: 0.2310 - dense_4_loss: 0.1084 - dense_5_loss: 0.0740 - dense_3_accuracy: 0.9343 - dense_4_accuracy: 0.9690 - dense_5_accuracy: 0.9783

# %%
# %matplotlib inline
def plot_loss(his, epoch, title):
    plt.style.use('ggplot')
    plt.figure()
    plt.plot(np.arange(0, epoch), his.history['loss'], label='train_loss')
    plt.plot(np.arange(0, epoch), his.history['dense_3_loss'], label='train_root_loss')
    plt.plot(np.arange(0, epoch), his.history['dense_4_loss'], label='train_vowel_loss')
    plt.plot(np.arange(0, epoch), his.history['dense_5_loss'], label='train_consonant_loss')
    
    plt.plot(np.arange(0, epoch), his.history['val_dense_3_loss'], label='val_train_root_loss')
    plt.plot(np.arange(0, epoch), his.history['val_dense_4_loss'], label='val_train_vowel_loss')
    plt.plot(np.arange(0, epoch), his.history['val_dense_5_loss'], label='val_train_consonant_loss')
    
    plt.title(title)
    plt.xlabel('Epoch #')
    plt.ylabel('Loss')
    plt.legend(loc='upper right')
    plt.show()

def plot_acc(his, epoch, title):
    plt.style.use('ggplot')
    plt.figure()
    plt.plot(np.arange(0, epoch), his.history['dense_3_accuracy'], label='train_root_acc')
    plt.plot(np.arange(0, epoch), his.history['dense_4_accuracy'], label='train_vowel_accuracy')
    plt.plot(np.arange(0, epoch), his.history['dense_5_accuracy'], label='train_consonant_accuracy')
    
    plt.plot(np.arange(0, epoch), his.history['val_dense_3_accuracy'], label='val_root_acc')
    plt.plot(np.arange(0, epoch), his.history['val_dense_4_accuracy'], label='val_vowel_accuracy')
    plt.plot(np.arange(0, epoch), his.history['val_dense_5_accuracy'], label='val_consonant_accuracy')
    plt.title(title)
    plt.xlabel('Epoch #')
    plt.ylabel('Accuracy')
    plt.legend(loc='upper right')
    plt.show()

# %%
for dataset in range(4):
    plot_loss(histories[dataset], epochs, f'Training Dataset: {dataset}')
    plot_acc(histories[dataset], epochs, f'Training Dataset: {dataset}')

# %%
del histories
gc.collect()
# Out:
# 28199

# %%
preds_dict = {
    'grapheme_root': [],
    'vowel_diacritic': [],
    'consonant_diacritic': []
}

# %%
components = ['consonant_diacritic', 'grapheme_root', 'vowel_diacritic']
target=[] # model predictions placeholder
row_id=[] # row_id place holder
for i in range(4):
    df_test_img = pd.read_parquet('/kaggle/input/bengaliai-cv19/test_image_data_{}.parquet'.format(i)) 
    df_test_img.set_index('image_id', inplace=True)

    X_test = resize(df_test_img, need_progress_bar=False)/255
    X_test = X_test.values.reshape(-1, IMG_SIZE, IMG_SIZE, N_CHANNELS)
    
    preds = model.predict(X_test)

    for i, p in enumerate(preds_dict):
        preds_dict[p] = np.argmax(preds[i], axis=1)

    for k,id in enumerate(df_test_img.index.values):  
        for i,comp in enumerate(components):
            id_sample=id+'_'+comp
            row_id.append(id_sample)
            target.append(preds_dict[comp][k])
    del df_test_img
    del X_test
    gc.collect()

df_sample = pd.DataFrame(
    {
        'row_id': row_id,
        'target':target
    },
    columns = ['row_id','target'] 
)
df_sample.to_csv('submission.csv',index=False)
df_sample.head()
# Out:
#                        row_id  target
# 0  Test_0_consonant_diacritic       0
# 1        Test_0_grapheme_root       3
# 2      Test_0_vowel_diacritic       0
# 3  Test_1_consonant_diacritic       0
# 4        Test_1_grapheme_root      93
