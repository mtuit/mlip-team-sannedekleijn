# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from tqdm.auto import tqdm
from glob import glob
import time, gc
import cv2

from tensorflow import keras
import matplotlib.image as mpimg
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model
from keras.models import clone_model
from keras.layers import Dense,Conv2D,Flatten,MaxPool2D,Dropout,BatchNormalization, Input, AveragePooling2D
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import PIL.Image as Image, PIL.ImageDraw as ImageDraw, PIL.ImageFont as ImageFont
from matplotlib import pyplot as plt
import seaborn as sns

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# Using TensorFlow backend.
# /kaggle/input/bengaliai-cv19/test_image_data_0.parquet
# /kaggle/input/bengaliai-cv19/sample_submission.csv
# /kaggle/input/bengaliai-cv19/test_image_data_3.parquet
# /kaggle/input/bengaliai-cv19/train_image_data_0.parquet
# /kaggle/input/bengaliai-cv19/test_image_data_1.parquet
# /kaggle/input/bengaliai-cv19/train_image_data_2.parquet
# /kaggle/input/bengaliai-cv19/train_image_data_3.parquet
# /kaggle/input/bengaliai-cv19/test_image_data_2.parquet
# /kaggle/input/bengaliai-cv19/train_image_data_1.parquet
# /kaggle/input/bengaliai-cv19/class_map.csv
# /kaggle/input/bengaliai-cv19/test.csv
# /kaggle/input/bengaliai-cv19/train.csv

# %%
train_df_ = pd.read_csv('/kaggle/input/bengaliai-cv19/train.csv')
test_df_ = pd.read_csv('/kaggle/input/bengaliai-cv19/test.csv')
class_map_df = pd.read_csv('/kaggle/input/bengaliai-cv19/class_map.csv')
sample_sub_df = pd.read_csv('/kaggle/input/bengaliai-cv19/sample_submission.csv')

# %%
train_df_.head()
# Out:
#   image_id  grapheme_root  vowel_diacritic  consonant_diacritic grapheme
# 0  Train_0             15                9                    5   ক্ট্রো
# 1  Train_1            159                0                    0        হ
# 2  Train_2             22                3                    5     খ্রী
# 3  Train_3             53                2                    2     র্টি
# 4  Train_4             71                9                    5     থ্রো

# %%
test_df_.head()
# Out:
#                        row_id image_id            component
# 0  Test_0_consonant_diacritic   Test_0  consonant_diacritic
# 1        Test_0_grapheme_root   Test_0        grapheme_root
# 2      Test_0_vowel_diacritic   Test_0      vowel_diacritic
# 3  Test_1_consonant_diacritic   Test_1  consonant_diacritic
# 4        Test_1_grapheme_root   Test_1        grapheme_root

# %%
sample_sub_df.head()
# Out:
#                        row_id  target
# 0  Test_0_consonant_diacritic       0
# 1        Test_0_grapheme_root       0
# 2      Test_0_vowel_diacritic       0
# 3  Test_1_consonant_diacritic       0
# 4        Test_1_grapheme_root       0

# %%
class_map_df.head()
# Out:
#   component_type  label component
# 0  grapheme_root      0         ং
# 1  grapheme_root      1         ঃ
# 2  grapheme_root      2         অ
# 3  grapheme_root      3         আ
# 4  grapheme_root      4         ই

# %%
print(f'Size of training data: {train_df_.shape}')
print(f'Size of test data: {test_df_.shape}')
print(f'Size of class map: {class_map_df.shape}')
# Out:
# Size of training data: (200840, 5)
# Size of test data: (36, 3)
# Size of class map: (186, 3)

# %% [markdown]
# ## Exploratory Data Analysis
# Exploratory data analysis (EDA) is an approach to analyzing data sets to summarize their main characteristics, often with visual methods.

# %%
HEIGHT = 236
WIDTH = 236

def get_n(df, field, n, top=True):
    top_graphemes = df.groupby([field]).size().reset_index(name='counts')['counts'].sort_values(ascending=not top)[:n]
    top_grapheme_roots = top_graphemes.index
    top_grapheme_counts = top_graphemes.values
    top_graphemes = class_map_df[class_map_df['component_type'] == field].reset_index().iloc[top_grapheme_roots]
    top_graphemes.drop(['component_type', 'label'], axis=1, inplace=True)
    top_graphemes.loc[:, 'count'] = top_grapheme_counts
    return top_graphemes

def image_from_char(char):
    image = Image.new('RGB', (WIDTH, HEIGHT))
    draw = ImageDraw.Draw(image)
    myfont = ImageFont.truetype('/kaggle/input/kalpurush-fonts/kalpurush-2.ttf', 120)
    w, h = draw.textsize(char, font=myfont)
    draw.text(((WIDTH - w) / 2,(HEIGHT - h) / 3), char, font=myfont)

    return image

# %% [markdown]
# ### Number of unique values

# %%
print(f'Number of unique grapheme roots: {train_df_["grapheme_root"].nunique()}')
print(f'Number of unique vowel diacritic: {train_df_["vowel_diacritic"].nunique()}')
print(f'Number of unique consonant diacritic: {train_df_["consonant_diacritic"].nunique()}')
# Out:
# Number of unique grapheme roots: 168
# Number of unique vowel diacritic: 11
# Number of unique consonant diacritic: 7

# %% [markdown]
# ### Most used top 10 Grapheme Roots in training set

# %%
top_10_roots = get_n(train_df_, 'grapheme_root', 10)
top_10_roots
# Out:
#      index component  count
# 72      72         দ   5736
# 64      64         ত   5596
# 13      13         ক   5420
# 107    107         ব   5321
# 23      23         গ   5149
# 96      96         প   4926
# 113    113         ভ   4395
# 147    147         স   4392
# 133    133         শ   4374
# 115    115         ম   4015

# %%
train_df_ = train_df_.drop(['grapheme'], axis=1, inplace=False)

# %%
train_df_[['grapheme_root', 'vowel_diacritic', 'consonant_diacritic']] = train_df_[['grapheme_root', 'vowel_diacritic', 'consonant_diacritic']].astype('uint8')

# %%
IMG_SIZE=64
N_CHANNELS=1

# %% [markdown]
# Let's apply some image processing (credits: [this kernel](https://www.kaggle.com/shawon10/bangla-graphemes-image-processing-deep-cnn)) while resizing the images, which will center crop the region of interest from the original images.

# %%
def resize(df, size=64, need_progress_bar=True):
    resized = {}
    resize_size=64
    if need_progress_bar:
        for i in tqdm(range(df.shape[0])):
            image=df.loc[df.index[i]].values.reshape(137,236)
            _, thresh = cv2.threshold(image, 30, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
            contours, _ = cv2.findContours(thresh,cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)[-2:]

            idx = 0 
            ls_xmin = []
            ls_ymin = []
            ls_xmax = []
            ls_ymax = []
            for cnt in contours:
                idx += 1
                x,y,w,h = cv2.boundingRect(cnt)
                ls_xmin.append(x)
                ls_ymin.append(y)
                ls_xmax.append(x + w)
                ls_ymax.append(y + h)
            xmin = min(ls_xmin)
            ymin = min(ls_ymin)
            xmax = max(ls_xmax)
            ymax = max(ls_ymax)

            roi = image[ymin:ymax,xmin:xmax]
            resized_roi = cv2.resize(roi, (resize_size, resize_size),interpolation=cv2.INTER_AREA)
            resized[df.index[i]] = resized_roi.reshape(-1)
    else:
        for i in range(df.shape[0]):
            #image = cv2.resize(df.loc[df.index[i]].values.reshape(137,236),(size,size),None,fx=0.5,fy=0.5,interpolation=cv2.INTER_AREA)
            image=df.loc[df.index[i]].values.reshape(137,236)
            _, thresh = cv2.threshold(image, 30, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
            contours, _ = cv2.findContours(thresh,cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)[-2:]

            idx = 0 
            ls_xmin = []
            ls_ymin = []
            ls_xmax = []
            ls_ymax = []
            for cnt in contours:
                idx += 1
                x,y,w,h = cv2.boundingRect(cnt)
                ls_xmin.append(x)
                ls_ymin.append(y)
                ls_xmax.append(x + w)
                ls_ymax.append(y + h)
            xmin = min(ls_xmin)
            ymin = min(ls_ymin)
            xmax = max(ls_xmax)
            ymax = max(ls_ymax)

            roi = image[ymin:ymax,xmin:xmax]
            resized_roi = cv2.resize(roi, (resize_size, resize_size),interpolation=cv2.INTER_AREA)
            resized[df.index[i]] = resized_roi.reshape(-1)
    resized = pd.DataFrame(resized).T
    return resized

# %%
def get_dummies(df):
    cols = []
    for col in df:
        cols.append(pd.get_dummies(df[col].astype(str)))
    return pd.concat(cols, axis=1)

# %% [markdown]
# ## Basic Model

# %%
inputs = Input(shape = (IMG_SIZE, IMG_SIZE, 1))

model = Conv2D(filters=32, kernel_size=(3, 3), padding='SAME', activation='relu', input_shape=(IMG_SIZE, IMG_SIZE, 1))(inputs)
model = Conv2D(filters=32, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=32, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=32, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = AveragePooling2D(pool_size=(2, 2))(model) #hier p pooling ipv max pool
#model = MaxPool2D(pool_size=(2, 2))(model)
model = Conv2D(filters=32, kernel_size=(5, 5), padding='SAME', activation='relu')(model)
model = Dropout(rate=0.3)(model)

model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = AveragePooling2D(pool_size=(2, 2))(model) #hier p pooling ipv max pool
#model = MaxPool2D(pool_size=(2, 2))(model)
model = Conv2D(filters=64, kernel_size=(5, 5), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = Dropout(rate=0.3)(model)

model = Conv2D(filters=128, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=128, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=128, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=128, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = AveragePooling2D(pool_size=(2, 2))(model) #hier p pooling ipv max pool
#model = MaxPool2D(pool_size=(2, 2))(model)
model = Conv2D(filters=128, kernel_size=(5, 5), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = Dropout(rate=0.3)(model)

model = Conv2D(filters=256, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=256, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=256, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=256, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = AveragePooling2D(pool_size=(2, 2))(model) #hier p pooling ipv max pool
#model = MaxPool2D(pool_size=(2, 2))(model)
model = Conv2D(filters=256, kernel_size=(5, 5), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = Dropout(rate=0.3)(model)

model = Flatten()(model)
model = Dense(1024, activation = "relu")(model)
model = Dropout(rate=0.3)(model)
dense = Dense(512, activation = "relu")(model)

head_root = Dense(168, activation = 'softmax')(dense)
head_vowel = Dense(11, activation = 'softmax')(dense)
head_consonant = Dense(7, activation = 'softmax')(dense)

model = Model(inputs=inputs, outputs=[head_root, head_vowel, head_consonant])

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 64, 64, 1)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 32)   320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 32)   9248        conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 32)   9248        conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 32)   9248        conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 64, 64, 32)   128         conv2d_4[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 32, 32, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 32)   25632       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 32, 32, 32)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 64)   18496       dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 64)   36928       conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 64)   36928       conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 64)   36928       conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 64)   256         conv2d_9[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 16, 16, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 64)   102464      average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 16, 16, 64)   256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 16, 16, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 128)  73856       dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 128)  147584      conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 128)  147584      conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 128)  147584      conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 128)  512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 8, 8, 128)    0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 128)    409728      average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 8, 8, 128)    512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 8, 8, 128)    0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 256)    295168      dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 8, 256)    590080      conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 8, 8, 256)    590080      conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 8, 8, 256)    590080      conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 8, 8, 256)    1024        conv2d_19[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 4, 4, 256)    0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 4, 4, 256)    1638656     average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 4, 4, 256)    1024        conv2d_20[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 4, 4, 256)    0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 4096)         0           dropout_4[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         4195328     flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 1024)         0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512)          524800      dropout_5[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 168)          86184       dense_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 11)           5643        dense_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 7)            3591        dense_2[0][0]
# ==================================================================================================
# Total params: 9,735,098
# Trainable params: 9,733,242
# Non-trainable params: 1,856
# __________________________________________________________________________________________________

# %% [markdown]
# Let's visualize the 3-tailed (3 output) CNN by plotting it.

# %%
from keras.utils import plot_model
plot_model(model, to_file='model.png')

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Set a learning rate annealer. Learning rate will be half after 3 epochs if accuracy is not increased
learning_rate_reduction_root = ReduceLROnPlateau(monitor='dense_3_accuracy', 
                                            patience=3, 
                                            verbose=1,
                                            factor=0.5, 
                                            min_lr=0.00001)
learning_rate_reduction_vowel = ReduceLROnPlateau(monitor='dense_4_accuracy', 
                                            patience=3, 
                                            verbose=1,
                                            factor=0.5, 
                                            min_lr=0.00001)
learning_rate_reduction_consonant = ReduceLROnPlateau(monitor='dense_5_accuracy', 
                                            patience=3, 
                                            verbose=1,
                                            factor=0.5, 
                                            min_lr=0.00001)

# %%
batch_size = 256
epochs = 30

# %%
class MultiOutputDataGenerator(keras.preprocessing.image.ImageDataGenerator):

    def flow(self,
             x,
             y=None,
             batch_size=32,
             shuffle=True,
             sample_weight=None,
             seed=None,
             save_to_dir=None,
             save_prefix='',
             save_format='png',
             subset=None):

        targets = None
        target_lengths = {}
        ordered_outputs = []
        for output, target in y.items():
            if targets is None:
                targets = target
            else:
                targets = np.concatenate((targets, target), axis=1)
            target_lengths[output] = target.shape[1]
            ordered_outputs.append(output)


        for flowx, flowy in super().flow(x, targets, batch_size=batch_size,
                                         shuffle=shuffle):
            target_dict = {}
            i = 0
            for output in ordered_outputs:
                target_length = target_lengths[output]
                target_dict[output] = flowy[:, i: i + target_length]
                i += target_length

            yield flowx, target_dict

# %%
HEIGHT = 137
WIDTH = 236

# %% [markdown]
# ### Training loop

# %%
histories = []
for i in range(4):
    train_df = pd.merge(pd.read_parquet(f'/kaggle/input/bengaliai-cv19/train_image_data_{i}.parquet'), train_df_, on='image_id').drop(['image_id'], axis=1)
    
    # Visualize few samples of current training dataset
    fig, ax = plt.subplots(nrows=3, ncols=4, figsize=(16, 8))
    count=0
    for row in ax:
        for col in row:
            col.imshow(resize(train_df.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic'], axis=1).iloc[[count]], need_progress_bar=False).values.reshape(-1).reshape(IMG_SIZE, IMG_SIZE).astype(np.float64))
            count += 1
    plt.show()
    
    X_train = train_df.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic'], axis=1)
    X_train = resize(X_train)/255
    
    # CNN takes images in shape `(batch_size, h, w, channels)`, so reshape the images
    X_train = X_train.values.reshape(-1, IMG_SIZE, IMG_SIZE, N_CHANNELS)
    
    Y_train_root = pd.get_dummies(train_df['grapheme_root']).values
    Y_train_vowel = pd.get_dummies(train_df['vowel_diacritic']).values
    Y_train_consonant = pd.get_dummies(train_df['consonant_diacritic']).values

    print(f'Training images: {X_train.shape}')
    print(f'Training labels root: {Y_train_root.shape}')
    print(f'Training labels vowel: {Y_train_vowel.shape}')
    print(f'Training labels consonants: {Y_train_consonant.shape}')

    # Divide the data into training and validation set
    x_train, x_test, y_train_root, y_test_root, y_train_vowel, y_test_vowel, y_train_consonant, y_test_consonant = train_test_split(X_train, Y_train_root, Y_train_vowel, Y_train_consonant, test_size=0.08, random_state=666)
    del train_df
    del X_train
    del Y_train_root, Y_train_vowel, Y_train_consonant

    # Data augmentation for creating more training data
    datagen = MultiOutputDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=8,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.15, # Randomly zoom image 
        width_shift_range=0.15,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.15,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images


    # This will just calculate parameters required to augment the given data. This won't perform any augmentations
    datagen.fit(x_train)

    # Fit the model
    history = model.fit_generator(datagen.flow(x_train, {'dense_3': y_train_root, 'dense_4': y_train_vowel, 'dense_5': y_train_consonant}, batch_size=batch_size),
                              epochs = epochs, validation_data = (x_test, [y_test_root, y_test_vowel, y_test_consonant]), 
                              steps_per_epoch=x_train.shape[0] // batch_size, 
                              callbacks=[learning_rate_reduction_root, learning_rate_reduction_vowel, learning_rate_reduction_consonant])

    histories.append(history)
    
    # Delete to reduce memory usage
    del x_train
    del x_test
    del y_train_root
    del y_test_root
    del y_train_vowel
    del y_test_vowel
    del y_train_consonant
    del y_test_consonant
    gc.collect()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=50210.0), HTML(value='')))
# Training images: (50210, 64, 64, 1)
# Training labels root: (50210, 168)
# Training labels vowel: (50210, 11)
# Training labels consonants: (50210, 7)
# Epoch 1/30
# 180/180 [==============================] - 46s 255ms/step - loss: 7.9403 - dense_3_loss: 4.7170 - dense_4_loss: 2.0164 - dense_5_loss: 1.2069 - dense_3_accuracy: 0.0309 - dense_4_accuracy: 0.2713 - dense_5_accuracy: 0.6188 - val_loss: 7.1319 - val_dense_3_loss: 4.4786 - val_dense_4_loss: 1.5632 - val_dense_5_loss: 1.0925 - val_dense_3_accuracy: 0.0515 - val_dense_4_accuracy: 0.4284 - val_dense_5_accuracy: 0.6126
# Epoch 2/30
# 180/180 [==============================] - 36s 198ms/step - loss: 6.6270 - dense_3_loss: 4.3475 - dense_4_loss: 1.2838 - dense_5_loss: 0.9957 - dense_3_accuracy: 0.0512 - dense_4_accuracy: 0.5425 - dense_5_accuracy: 0.6614 - val_loss: 6.1192 - val_dense_3_loss: 4.2186 - val_dense_4_loss: 1.0480 - val_dense_5_loss: 0.8588 - val_dense_3_accuracy: 0.0605 - val_dense_4_accuracy: 0.6251 - val_dense_5_accuracy: 0.7040
# Epoch 3/30
# 180/180 [==============================] - 37s 204ms/step - loss: 5.7336 - dense_3_loss: 3.9758 - dense_4_loss: 0.9502 - dense_5_loss: 0.8076 - dense_3_accuracy: 0.0783 - dense_4_accuracy: 0.6762 - dense_5_accuracy: 0.7162 - val_loss: 4.7424 - val_dense_3_loss: 3.5627 - val_dense_4_loss: 0.5939 - val_dense_5_loss: 0.5884 - val_dense_3_accuracy: 0.1267 - val_dense_4_accuracy: 0.7984 - val_dense_5_accuracy: 0.7839
# Epoch 4/30
# 180/180 [==============================] - 37s 203ms/step - loss: 4.9281 - dense_3_loss: 3.5457 - dense_4_loss: 0.7669 - dense_5_loss: 0.6155 - dense_3_accuracy: 0.1270 - dense_4_accuracy: 0.7446 - dense_5_accuracy: 0.7842 - val_loss: 3.7024 - val_dense_3_loss: 2.9101 - val_dense_4_loss: 0.4157 - val_dense_5_loss: 0.3793 - val_dense_3_accuracy: 0.2188 - val_dense_4_accuracy: 0.8661 - val_dense_5_accuracy: 0.8688
# Epoch 5/30
# 180/180 [==============================] - 36s 201ms/step - loss: 4.0893 - dense_3_loss: 2.9538 - dense_4_loss: 0.6526 - dense_5_loss: 0.4829 - dense_3_accuracy: 0.2189 - dense_4_accuracy: 0.7871 - dense_5_accuracy: 0.8377 - val_loss: 2.9203 - val_dense_3_loss: 2.1977 - val_dense_4_loss: 0.4146 - val_dense_5_loss: 0.3068 - val_dense_3_accuracy: 0.3694 - val_dense_4_accuracy: 0.8656 - val_dense_5_accuracy: 0.9017
# Epoch 6/30
# 180/180 [==============================] - 37s 205ms/step - loss: 3.3411 - dense_3_loss: 2.3520 - dense_4_loss: 0.5863 - dense_5_loss: 0.4028 - dense_3_accuracy: 0.3408 - dense_4_accuracy: 0.8111 - dense_5_accuracy: 0.8708 - val_loss: 2.1933 - val_dense_3_loss: 1.6159 - val_dense_4_loss: 0.3099 - val_dense_5_loss: 0.2675 - val_dense_3_accuracy: 0.4994 - val_dense_4_accuracy: 0.9012 - val_dense_5_accuracy: 0.9134
# Epoch 7/30
# 180/180 [==============================] - 36s 201ms/step - loss: 2.7474 - dense_3_loss: 1.8838 - dense_4_loss: 0.5119 - dense_5_loss: 0.3517 - dense_3_accuracy: 0.4570 - dense_4_accuracy: 0.8364 - dense_5_accuracy: 0.8876 - val_loss: 1.7565 - val_dense_3_loss: 1.2888 - val_dense_4_loss: 0.2715 - val_dense_5_loss: 0.1994 - val_dense_3_accuracy: 0.6057 - val_dense_4_accuracy: 0.9186 - val_dense_5_accuracy: 0.9315
# Epoch 8/30
# 180/180 [==============================] - 37s 206ms/step - loss: 2.3054 - dense_3_loss: 1.5428 - dense_4_loss: 0.4463 - dense_5_loss: 0.3163 - dense_3_accuracy: 0.5551 - dense_4_accuracy: 0.8593 - dense_5_accuracy: 0.8974 - val_loss: 1.4817 - val_dense_3_loss: 1.0360 - val_dense_4_loss: 0.2679 - val_dense_5_loss: 0.1821 - val_dense_3_accuracy: 0.6918 - val_dense_4_accuracy: 0.9178 - val_dense_5_accuracy: 0.9455
# Epoch 9/30
# 180/180 [==============================] - 37s 206ms/step - loss: 1.9830 - dense_3_loss: 1.2946 - dense_4_loss: 0.4069 - dense_5_loss: 0.2816 - dense_3_accuracy: 0.6246 - dense_4_accuracy: 0.8727 - dense_5_accuracy: 0.9113 - val_loss: 1.2859 - val_dense_3_loss: 0.8839 - val_dense_4_loss: 0.2342 - val_dense_5_loss: 0.1717 - val_dense_3_accuracy: 0.7366 - val_dense_4_accuracy: 0.9325 - val_dense_5_accuracy: 0.9515
# Epoch 10/30
# 180/180 [==============================] - 36s 201ms/step - loss: 1.7582 - dense_3_loss: 1.1232 - dense_4_loss: 0.3771 - dense_5_loss: 0.2579 - dense_3_accuracy: 0.6759 - dense_4_accuracy: 0.8846 - dense_5_accuracy: 0.9181 - val_loss: 1.1381 - val_dense_3_loss: 0.7839 - val_dense_4_loss: 0.1859 - val_dense_5_loss: 0.1678 - val_dense_3_accuracy: 0.7707 - val_dense_4_accuracy: 0.9465 - val_dense_5_accuracy: 0.9457
# Epoch 11/30
# 180/180 [==============================] - 37s 207ms/step - loss: 1.5734 - dense_3_loss: 0.9888 - dense_4_loss: 0.3485 - dense_5_loss: 0.2361 - dense_3_accuracy: 0.7150 - dense_4_accuracy: 0.8939 - dense_5_accuracy: 0.9257 - val_loss: 0.9474 - val_dense_3_loss: 0.6362 - val_dense_4_loss: 0.1752 - val_dense_5_loss: 0.1390 - val_dense_3_accuracy: 0.8218 - val_dense_4_accuracy: 0.9490 - val_dense_5_accuracy: 0.9602
# Epoch 12/30
# 180/180 [==============================] - 36s 203ms/step - loss: 1.4543 - dense_3_loss: 0.8957 - dense_4_loss: 0.3335 - dense_5_loss: 0.2251 - dense_3_accuracy: 0.7426 - dense_4_accuracy: 0.9001 - dense_5_accuracy: 0.9294 - val_loss: 0.8937 - val_dense_3_loss: 0.6025 - val_dense_4_loss: 0.1740 - val_dense_5_loss: 0.1207 - val_dense_3_accuracy: 0.8277 - val_dense_4_accuracy: 0.9507 - val_dense_5_accuracy: 0.9609
# Epoch 13/30
# 180/180 [==============================] - 37s 204ms/step - loss: 1.3326 - dense_3_loss: 0.8140 - dense_4_loss: 0.3123 - dense_5_loss: 0.2063 - dense_3_accuracy: 0.7674 - dense_4_accuracy: 0.9085 - dense_5_accuracy: 0.9357 - val_loss: 0.8040 - val_dense_3_loss: 0.5517 - val_dense_4_loss: 0.1428 - val_dense_5_loss: 0.1129 - val_dense_3_accuracy: 0.8442 - val_dense_4_accuracy: 0.9607 - val_dense_5_accuracy: 0.9654
# Epoch 14/30
# 180/180 [==============================] - 37s 205ms/step - loss: 1.2413 - dense_3_loss: 0.7483 - dense_4_loss: 0.2925 - dense_5_loss: 0.2006 - dense_3_accuracy: 0.7831 - dense_4_accuracy: 0.9115 - dense_5_accuracy: 0.9371 - val_loss: 0.7981 - val_dense_3_loss: 0.5396 - val_dense_4_loss: 0.1330 - val_dense_5_loss: 0.1272 - val_dense_3_accuracy: 0.8464 - val_dense_4_accuracy: 0.9602 - val_dense_5_accuracy: 0.9597
# Epoch 15/30
# 180/180 [==============================] - 36s 201ms/step - loss: 1.1531 - dense_3_loss: 0.6876 - dense_4_loss: 0.2797 - dense_5_loss: 0.1858 - dense_3_accuracy: 0.8009 - dense_4_accuracy: 0.9163 - dense_5_accuracy: 0.9421 - val_loss: 0.7451 - val_dense_3_loss: 0.5117 - val_dense_4_loss: 0.1303 - val_dense_5_loss: 0.1069 - val_dense_3_accuracy: 0.8593 - val_dense_4_accuracy: 0.9644 - val_dense_5_accuracy: 0.9671
# Epoch 16/30
# 180/180 [==============================] - 37s 204ms/step - loss: 1.1061 - dense_3_loss: 0.6540 - dense_4_loss: 0.2653 - dense_5_loss: 0.1869 - dense_3_accuracy: 0.8112 - dense_4_accuracy: 0.9221 - dense_5_accuracy: 0.9413 - val_loss: 0.7456 - val_dense_3_loss: 0.4874 - val_dense_4_loss: 0.1296 - val_dense_5_loss: 0.1311 - val_dense_3_accuracy: 0.8593 - val_dense_4_accuracy: 0.9664 - val_dense_5_accuracy: 0.9597
# Epoch 17/30
# 180/180 [==============================] - 37s 204ms/step - loss: 1.0329 - dense_3_loss: 0.6081 - dense_4_loss: 0.2487 - dense_5_loss: 0.1761 - dense_3_accuracy: 0.8232 - dense_4_accuracy: 0.9271 - dense_5_accuracy: 0.9456 - val_loss: 0.6604 - val_dense_3_loss: 0.4510 - val_dense_4_loss: 0.1170 - val_dense_5_loss: 0.0980 - val_dense_3_accuracy: 0.8701 - val_dense_4_accuracy: 0.9691 - val_dense_5_accuracy: 0.9741
# Epoch 18/30
# 180/180 [==============================] - 36s 200ms/step - loss: 1.0055 - dense_3_loss: 0.5857 - dense_4_loss: 0.2519 - dense_5_loss: 0.1678 - dense_3_accuracy: 0.8305 - dense_4_accuracy: 0.9268 - dense_5_accuracy: 0.9487 - val_loss: 0.6580 - val_dense_3_loss: 0.4466 - val_dense_4_loss: 0.1145 - val_dense_5_loss: 0.0970 - val_dense_3_accuracy: 0.8760 - val_dense_4_accuracy: 0.9699 - val_dense_5_accuracy: 0.9706
# Epoch 19/30
# 180/180 [==============================] - 37s 206ms/step - loss: 0.9500 - dense_3_loss: 0.5520 - dense_4_loss: 0.2390 - dense_5_loss: 0.1591 - dense_3_accuracy: 0.8380 - dense_4_accuracy: 0.9293 - dense_5_accuracy: 0.9510 - val_loss: 0.6317 - val_dense_3_loss: 0.4186 - val_dense_4_loss: 0.1165 - val_dense_5_loss: 0.0967 - val_dense_3_accuracy: 0.8855 - val_dense_4_accuracy: 0.9684 - val_dense_5_accuracy: 0.9736
# Epoch 20/30
# 180/180 [==============================] - 36s 201ms/step - loss: 0.9220 - dense_3_loss: 0.5344 - dense_4_loss: 0.2320 - dense_5_loss: 0.1556 - dense_3_accuracy: 0.8452 - dense_4_accuracy: 0.9316 - dense_5_accuracy: 0.9524 - val_loss: 0.6329 - val_dense_3_loss: 0.4284 - val_dense_4_loss: 0.1005 - val_dense_5_loss: 0.1050 - val_dense_3_accuracy: 0.8880 - val_dense_4_accuracy: 0.9721 - val_dense_5_accuracy: 0.9679
# Epoch 21/30
# 180/180 [==============================] - 37s 206ms/step - loss: 0.8942 - dense_3_loss: 0.5081 - dense_4_loss: 0.2324 - dense_5_loss: 0.1537 - dense_3_accuracy: 0.8521 - dense_4_accuracy: 0.9320 - dense_5_accuracy: 0.9525 - val_loss: 0.6176 - val_dense_3_loss: 0.4300 - val_dense_4_loss: 0.1007 - val_dense_5_loss: 0.0890 - val_dense_3_accuracy: 0.8875 - val_dense_4_accuracy: 0.9749 - val_dense_5_accuracy: 0.9749
# Epoch 22/30
# 180/180 [==============================] - 37s 205ms/step - loss: 0.8640 - dense_3_loss: 0.4912 - dense_4_loss: 0.2210 - dense_5_loss: 0.1519 - dense_3_accuracy: 0.8557 - dense_4_accuracy: 0.9352 - dense_5_accuracy: 0.9539 - val_loss: 0.6122 - val_dense_3_loss: 0.4160 - val_dense_4_loss: 0.1003 - val_dense_5_loss: 0.0973 - val_dense_3_accuracy: 0.8857 - val_dense_4_accuracy: 0.9734 - val_dense_5_accuracy: 0.9701
# Epoch 23/30
# 180/180 [==============================] - 36s 199ms/step - loss: 0.8310 - dense_3_loss: 0.4699 - dense_4_loss: 0.2161 - dense_5_loss: 0.1450 - dense_3_accuracy: 0.8619 - dense_4_accuracy: 0.9371 - dense_5_accuracy: 0.9549 - val_loss: 0.6032 - val_dense_3_loss: 0.3989 - val_dense_4_loss: 0.1095 - val_dense_5_loss: 0.0957 - val_dense_3_accuracy: 0.8942 - val_dense_4_accuracy: 0.9689 - val_dense_5_accuracy: 0.9721
# Epoch 24/30
# 180/180 [==============================] - 37s 205ms/step - loss: 0.7920 - dense_3_loss: 0.4457 - dense_4_loss: 0.2104 - dense_5_loss: 0.1360 - dense_3_accuracy: 0.8696 - dense_4_accuracy: 0.9387 - dense_5_accuracy: 0.9585 - val_loss: 0.5886 - val_dense_3_loss: 0.3911 - val_dense_4_loss: 0.1145 - val_dense_5_loss: 0.0853 - val_dense_3_accuracy: 0.8947 - val_dense_4_accuracy: 0.9689 - val_dense_5_accuracy: 0.9778
# Epoch 25/30
# 180/180 [==============================] - 36s 199ms/step - loss: 0.7763 - dense_3_loss: 0.4369 - dense_4_loss: 0.2037 - dense_5_loss: 0.1356 - dense_3_accuracy: 0.8739 - dense_4_accuracy: 0.9397 - dense_5_accuracy: 0.9580 - val_loss: 0.6004 - val_dense_3_loss: 0.4019 - val_dense_4_loss: 0.1042 - val_dense_5_loss: 0.0962 - val_dense_3_accuracy: 0.8952 - val_dense_4_accuracy: 0.9704 - val_dense_5_accuracy: 0.9694
# Epoch 26/30
# 180/180 [==============================] - 37s 204ms/step - loss: 0.7547 - dense_3_loss: 0.4168 - dense_4_loss: 0.2059 - dense_5_loss: 0.1320 - dense_3_accuracy: 0.8763 - dense_4_accuracy: 0.9402 - dense_5_accuracy: 0.9595 - val_loss: 0.5865 - val_dense_3_loss: 0.3828 - val_dense_4_loss: 0.1109 - val_dense_5_loss: 0.0952 - val_dense_3_accuracy: 0.9007 - val_dense_4_accuracy: 0.9716 - val_dense_5_accuracy: 0.9739
# Epoch 27/30
# 180/180 [==============================] - 37s 204ms/step - loss: 0.7326 - dense_3_loss: 0.4087 - dense_4_loss: 0.1935 - dense_5_loss: 0.1304 - dense_3_accuracy: 0.8785 - dense_4_accuracy: 0.9437 - dense_5_accuracy: 0.9600 - val_loss: 0.5666 - val_dense_3_loss: 0.3754 - val_dense_4_loss: 0.1071 - val_dense_5_loss: 0.0858 - val_dense_3_accuracy: 0.9014 - val_dense_4_accuracy: 0.9716 - val_dense_5_accuracy: 0.9749
# Epoch 28/30
# 180/180 [==============================] - 36s 201ms/step - loss: 0.7040 - dense_3_loss: 0.3896 - dense_4_loss: 0.1932 - dense_5_loss: 0.1212 - dense_3_accuracy: 0.8850 - dense_4_accuracy: 0.9428 - dense_5_accuracy: 0.9625 - val_loss: 0.5538 - val_dense_3_loss: 0.3667 - val_dense_4_loss: 0.1005 - val_dense_5_loss: 0.0894 - val_dense_3_accuracy: 0.9079 - val_dense_4_accuracy: 0.9744 - val_dense_5_accuracy: 0.9724
# Epoch 29/30
# 180/180 [==============================] - 37s 206ms/step - loss: 0.7062 - dense_3_loss: 0.3881 - dense_4_loss: 0.1917 - dense_5_loss: 0.1264 - dense_3_accuracy: 0.8852 - dense_4_accuracy: 0.9440 - dense_5_accuracy: 0.9607 - val_loss: 0.5412 - val_dense_3_loss: 0.3545 - val_dense_4_loss: 0.1076 - val_dense_5_loss: 0.0814 - val_dense_3_accuracy: 0.9057 - val_dense_4_accuracy: 0.9734 - val_dense_5_accuracy: 0.9761
# Epoch 30/30
# 180/180 [==============================] - 36s 200ms/step - loss: 0.6876 - dense_3_loss: 0.3828 - dense_4_loss: 0.1820 - dense_5_loss: 0.1227 - dense_3_accuracy: 0.8859 - dense_4_accuracy: 0.9466 - dense_5_accuracy: 0.9620 - val_loss: 0.5672 - val_dense_3_loss: 0.3838 - val_dense_4_loss: 0.0945 - val_dense_5_loss: 0.0918 - val_dense_3_accuracy: 0.9049 - val_dense_4_accuracy: 0.9741 - val_dense_5_accuracy: 0.9756
# HBox(children=(FloatProgress(value=0.0, max=50210.0), HTML(value='')))
# Training images: (50210, 64, 64, 1)
# Training labels root: (50210, 168)
# Training labels vowel: (50210, 11)
# Training labels consonants: (50210, 7)
# Epoch 1/30
# 180/180 [==============================] - 38s 211ms/step - loss: 0.9722 - dense_3_loss: 0.5701 - dense_4_loss: 0.2357 - dense_5_loss: 0.1664 - dense_3_accuracy: 0.8451 - dense_4_accuracy: 0.9324 - dense_5_accuracy: 0.9497 - val_loss: 0.5610 - val_dense_3_loss: 0.3431 - val_dense_4_loss: 0.1194 - val_dense_5_loss: 0.0979 - val_dense_3_accuracy: 0.9039 - val_dense_4_accuracy: 0.9689 - val_dense_5_accuracy: 0.9711
# Epoch 2/30
# 180/180 [==============================] - 36s 201ms/step - loss: 0.8851 - dense_3_loss: 0.5113 - dense_4_loss: 0.2181 - dense_5_loss: 0.1556 - dense_3_accuracy: 0.8586 - dense_4_accuracy: 0.9380 - dense_5_accuracy: 0.9534 - val_loss: 0.4904 - val_dense_3_loss: 0.3034 - val_dense_4_loss: 0.1119 - val_dense_5_loss: 0.0752 - val_dense_3_accuracy: 0.9174 - val_dense_4_accuracy: 0.9729 - val_dense_5_accuracy: 0.9793
# Epoch 3/30
# 180/180 [==============================] - 37s 206ms/step - loss: 0.8075 - dense_3_loss: 0.4594 - dense_4_loss: 0.2048 - dense_5_loss: 0.1433 - dense_3_accuracy: 0.8717 - dense_4_accuracy: 0.9413 - dense_5_accuracy: 0.9564 - val_loss: 0.4984 - val_dense_3_loss: 0.3104 - val_dense_4_loss: 0.1100 - val_dense_5_loss: 0.0791 - val_dense_3_accuracy: 0.9144 - val_dense_4_accuracy: 0.9704 - val_dense_5_accuracy: 0.9783
# Epoch 4/30
# 180/180 [==============================] - 37s 204ms/step - loss: 0.7650 - dense_3_loss: 0.4300 - dense_4_loss: 0.1957 - dense_5_loss: 0.1392 - dense_3_accuracy: 0.8760 - dense_4_accuracy: 0.9440 - dense_5_accuracy: 0.9584 - val_loss: 0.5062 - val_dense_3_loss: 0.3251 - val_dense_4_loss: 0.0918 - val_dense_5_loss: 0.0871 - val_dense_3_accuracy: 0.9106 - val_dense_4_accuracy: 0.9754 - val_dense_5_accuracy: 0.9756
# Epoch 5/30
# 180/180 [==============================] - 36s 200ms/step - loss: 0.7465 - dense_3_loss: 0.4164 - dense_4_loss: 0.1955 - dense_5_loss: 0.1346 - dense_3_accuracy: 0.8825 - dense_4_accuracy: 0.9436 - dense_5_accuracy: 0.9597 - val_loss: 0.4690 - val_dense_3_loss: 0.2968 - val_dense_4_loss: 0.0934 - val_dense_5_loss: 0.0767 - val_dense_3_accuracy: 0.9176 - val_dense_4_accuracy: 0.9751 - val_dense_5_accuracy: 0.9801
# Epoch 6/30
# 180/180 [==============================] - 37s 206ms/step - loss: 0.7184 - dense_3_loss: 0.3938 - dense_4_loss: 0.1936 - dense_5_loss: 0.1309 - dense_3_accuracy: 0.8856 - dense_4_accuracy: 0.9448 - dense_5_accuracy: 0.9609 - val_loss: 0.4773 - val_dense_3_loss: 0.2871 - val_dense_4_loss: 0.1052 - val_dense_5_loss: 0.0847 - val_dense_3_accuracy: 0.9196 - val_dense_4_accuracy: 0.9726 - val_dense_5_accuracy: 0.9764
# Epoch 7/30
# 180/180 [==============================] - 37s 204ms/step - loss: 0.6787 - dense_3_loss: 0.3766 - dense_4_loss: 0.1775 - dense_5_loss: 0.1245 - dense_3_accuracy: 0.8900 - dense_4_accuracy: 0.9494 - dense_5_accuracy: 0.9623 - val_loss: 0.4870 - val_dense_3_loss: 0.3021 - val_dense_4_loss: 0.0992 - val_dense_5_loss: 0.0846 - val_dense_3_accuracy: 0.9203 - val_dense_4_accuracy: 0.9756 - val_dense_5_accuracy: 0.9771
# Epoch 8/30
# 180/180 [==============================] - 36s 202ms/step - loss: 0.6540 - dense_3_loss: 0.3539 - dense_4_loss: 0.1794 - dense_5_loss: 0.1206 - dense_3_accuracy: 0.8964 - dense_4_accuracy: 0.9493 - dense_5_accuracy: 0.9632 - val_loss: 0.4675 - val_dense_3_loss: 0.2994 - val_dense_4_loss: 0.0904 - val_dense_5_loss: 0.0769 - val_dense_3_accuracy: 0.9186 - val_dense_4_accuracy: 0.9749 - val_dense_5_accuracy: 0.9776
# Epoch 9/30
# 180/180 [==============================] - 37s 206ms/step - loss: 0.6495 - dense_3_loss: 0.3551 - dense_4_loss: 0.1728 - dense_5_loss: 0.1215 - dense_3_accuracy: 0.8977 - dense_4_accuracy: 0.9492 - dense_5_accuracy: 0.9634 - val_loss: 0.4682 - val_dense_3_loss: 0.2903 - val_dense_4_loss: 0.1010 - val_dense_5_loss: 0.0762 - val_dense_3_accuracy: 0.9203 - val_dense_4_accuracy: 0.9726 - val_dense_5_accuracy: 0.9778
# Epoch 10/30
# 180/180 [==============================] - 36s 200ms/step - loss: 0.6312 - dense_3_loss: 0.3398 - dense_4_loss: 0.1717 - dense_5_loss: 0.1197 - dense_3_accuracy: 0.9008 - dense_4_accuracy: 0.9491 - dense_5_accuracy: 0.9643 - val_loss: 0.4669 - val_dense_3_loss: 0.2850 - val_dense_4_loss: 0.0951 - val_dense_5_loss: 0.0863 - val_dense_3_accuracy: 0.9233 - val_dense_4_accuracy: 0.9768 - val_dense_5_accuracy: 0.9778
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 11/30
# 180/180 [==============================] - 37s 206ms/step - loss: 0.5043 - dense_3_loss: 0.2671 - dense_4_loss: 0.1402 - dense_5_loss: 0.0969 - dense_3_accuracy: 0.9192 - dense_4_accuracy: 0.9590 - dense_5_accuracy: 0.9702 - val_loss: 0.4357 - val_dense_3_loss: 0.2563 - val_dense_4_loss: 0.1056 - val_dense_5_loss: 0.0735 - val_dense_3_accuracy: 0.9305 - val_dense_4_accuracy: 0.9709 - val_dense_5_accuracy: 0.9798
# Epoch 12/30
# 180/180 [==============================] - 37s 205ms/step - loss: 0.4665 - dense_3_loss: 0.2416 - dense_4_loss: 0.1362 - dense_5_loss: 0.0887 - dense_3_accuracy: 0.9277 - dense_4_accuracy: 0.9601 - dense_5_accuracy: 0.9731 - val_loss: 0.4284 - val_dense_3_loss: 0.2647 - val_dense_4_loss: 0.0910 - val_dense_5_loss: 0.0727 - val_dense_3_accuracy: 0.9308 - val_dense_4_accuracy: 0.9771 - val_dense_5_accuracy: 0.9831
# Epoch 13/30
# 180/180 [==============================] - 36s 202ms/step - loss: 0.4544 - dense_3_loss: 0.2355 - dense_4_loss: 0.1286 - dense_5_loss: 0.0903 - dense_3_accuracy: 0.9291 - dense_4_accuracy: 0.9631 - dense_5_accuracy: 0.9730 - val_loss: 0.4244 - val_dense_3_loss: 0.2654 - val_dense_4_loss: 0.0836 - val_dense_5_loss: 0.0744 - val_dense_3_accuracy: 0.9328 - val_dense_4_accuracy: 0.9764 - val_dense_5_accuracy: 0.9788
# Epoch 14/30
# 180/180 [==============================] - 37s 205ms/step - loss: 0.4393 - dense_3_loss: 0.2238 - dense_4_loss: 0.1277 - dense_5_loss: 0.0878 - dense_3_accuracy: 0.9316 - dense_4_accuracy: 0.9627 - dense_5_accuracy: 0.9740 - val_loss: 0.4042 - val_dense_3_loss: 0.2513 - val_dense_4_loss: 0.0824 - val_dense_5_loss: 0.0698 - val_dense_3_accuracy: 0.9355 - val_dense_4_accuracy: 0.9796 - val_dense_5_accuracy: 0.9813
# Epoch 15/30
# 119/180 [==================>...........] - ETA: 11s - loss: 0.4262 - dense_3_loss: 0.2192 - dense_4_loss: 0.1228 - dense_5_loss: 0.0842 - dense_3_accuracy: 0.9360 - dense_4_accuracy: 0.9632 - dense_5_accuracy: 0.9744
# HBox(children=(FloatProgress(value=0.0, max=50210.0), HTML(value='')))
# 180/180 [==============================] - 37s 207ms/step - loss: 0.4053 - dense_3_loss: 0.2148 - dense_4_loss: 0.1128 - dense_5_loss: 0.0777 - dense_3_accuracy: 0.9365 - dense_4_accuracy: 0.9666 - dense_5_accuracy: 0.9764 - val_loss: 0.3539 - val_dense_3_loss: 0.2174 - val_dense_4_loss: 0.0730 - val_dense_5_loss: 0.0668 - val_dense_3_accuracy: 0.9442 - val_dense_4_accuracy: 0.9813 - val_dense_5_accuracy: 0.9798
# Epoch 13/30
# 180/180 [==============================] - 37s 203ms/step - loss: 0.4091 - dense_3_loss: 0.2214 - dense_4_loss: 0.1115 - dense_5_loss: 0.0762 - dense_3_accuracy: 0.9333 - dense_4_accuracy: 0.9677 - dense_5_accuracy: 0.9766 - val_loss: 0.3357 - val_dense_3_loss: 0.2048 - val_dense_4_loss: 0.0656 - val_dense_5_loss: 0.0683 - val_dense_3_accuracy: 0.9480 - val_dense_4_accuracy: 0.9838 - val_dense_5_accuracy: 0.9808
# Epoch 14/30
# 180/180 [==============================] - 37s 208ms/step - loss: 0.3951 - dense_3_loss: 0.2111 - dense_4_loss: 0.1106 - dense_5_loss: 0.0734 - dense_3_accuracy: 0.9366 - dense_4_accuracy: 0.9681 - dense_5_accuracy: 0.9776 - val_loss: 0.3467 - val_dense_3_loss: 0.2094 - val_dense_4_loss: 0.0737 - val_dense_5_loss: 0.0662 - val_dense_3_accuracy: 0.9455 - val_dense_4_accuracy: 0.9806 - val_dense_5_accuracy: 0.9801
# Epoch 15/30
# 180/180 [==============================] - 35s 195ms/step - loss: 0.3274 - dense_3_loss: 0.1685 - dense_4_loss: 0.0962 - dense_5_loss: 0.0626 - dense_3_accuracy: 0.9473 - dense_4_accuracy: 0.9715 - dense_5_accuracy: 0.9810 - val_loss: 0.3388 - val_dense_3_loss: 0.2152 - val_dense_4_loss: 0.0631 - val_dense_5_loss: 0.0640 - val_dense_3_accuracy: 0.9480 - val_dense_4_accuracy: 0.9841 - val_dense_5_accuracy: 0.9831
# Epoch 27/30
# 180/180 [==============================] - 36s 200ms/step - loss: 0.3276 - dense_3_loss: 0.1661 - dense_4_loss: 0.0975 - dense_5_loss: 0.0641 - dense_3_accuracy: 0.9475 - dense_4_accuracy: 0.9706 - dense_5_accuracy: 0.9802 - val_loss: 0.3566 - val_dense_3_loss: 0.2226 - val_dense_4_loss: 0.0695 - val_dense_5_loss: 0.0690 - val_dense_3_accuracy: 0.9457 - val_dense_4_accuracy: 0.9826 - val_dense_5_accuracy: 0.9823
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 28/30
# 180/180 [==============================] - 35s 194ms/step - loss: 0.3094 - dense_3_loss: 0.1555 - dense_4_loss: 0.0910 - dense_5_loss: 0.0629 - dense_3_accuracy: 0.9506 - dense_4_accuracy: 0.9732 - dense_5_accuracy: 0.9809 - val_loss: 0.3433 - val_dense_3_loss: 0.2137 - val_dense_4_loss: 0.0673 - val_dense_5_loss: 0.0663 - val_dense_3_accuracy: 0.9472 - val_dense_4_accuracy: 0.9818 - val_dense_5_accuracy: 0.9828
# Epoch 29/30
# 180/180 [==============================] - 35s 195ms/step - loss: 0.5129 - dense_3_loss: 0.2964 - dense_4_loss: 0.1261 - dense_5_loss: 0.0904 - dense_3_accuracy: 0.9196 - dense_4_accuracy: 0.9645 - dense_5_accuracy: 0.9744 - val_loss: 0.3120 - val_dense_3_loss: 0.1960 - val_dense_4_loss: 0.0665 - val_dense_5_loss: 0.0484 - val_dense_3_accuracy: 0.9435 - val_dense_4_accuracy: 0.9831 - val_dense_5_accuracy: 0.9861
# Epoch 8/30
# 180/180 [==============================] - 36s 200ms/step - loss: 0.5047 - dense_3_loss: 0.2883 - dense_4_loss: 0.1248 - dense_5_loss: 0.0916 - dense_3_accuracy: 0.9211 - dense_4_accuracy: 0.9656 - dense_5_accuracy: 0.9736 - val_loss: 0.3114 - val_dense_3_loss: 0.1996 - val_dense_4_loss: 0.0636 - val_dense_5_loss: 0.0473 - val_dense_3_accuracy: 0.9430 - val_dense_4_accuracy: 0.9848 - val_dense_5_accuracy: 0.9858
# Epoch 9/30
# 180/180 [==============================] - 36s 201ms/step - loss: 0.4987 - dense_3_loss: 0.2838 - dense_4_loss: 0.1251 - dense_5_loss: 0.0898 - dense_3_accuracy: 0.9225 - dense_4_accuracy: 0.9648 - dense_5_accuracy: 0.9738 - val_loss: 0.3114 - val_dense_3_loss: 0.1969 - val_dense_4_loss: 0.0641 - val_dense_5_loss: 0.0492 - val_dense_3_accuracy: 0.9427 - val_dense_4_accuracy: 0.9848 - val_dense_5_accuracy: 0.9858
# Epoch 10/30
# 180/180 [==============================] - 37s 204ms/step - loss: 0.4717 - dense_3_loss: 0.2670 - dense_4_loss: 0.1218 - dense_5_loss: 0.0829 - dense_3_accuracy: 0.9260 - dense_4_accuracy: 0.9648 - dense_5_accuracy: 0.9756 - val_loss: 0.3062 - val_dense_3_loss: 0.1947 - val_dense_4_loss: 0.0627 - val_dense_5_loss: 0.0479 - val_dense_3_accuracy: 0.9437 - val_dense_4_accuracy: 0.9836 - val_dense_5_accuracy: 0.9853
# Epoch 22/30
# 180/180 [==============================] - 36s 199ms/step - loss: 0.4666 - dense_3_loss: 0.2598 - dense_4_loss: 0.1188 - dense_5_loss: 0.0879 - dense_3_accuracy: 0.9261 - dense_4_accuracy: 0.9659 - dense_5_accuracy: 0.9742 - val_loss: 0.3090 - val_dense_3_loss: 0.1986 - val_dense_4_loss: 0.0630 - val_dense_5_loss: 0.0463 - val_dense_3_accuracy: 0.9430 - val_dense_4_accuracy: 0.9841 - val_dense_5_accuracy: 0.9856
# Epoch 23/30
# 180/180 [==============================] - 37s 205ms/step - loss: 0.4682 - dense_3_loss: 0.2630 - dense_4_loss: 0.1193 - dense_5_loss: 0.0859 - dense_3_accuracy: 0.9272 - dense_4_accuracy: 0.9664 - dense_5_accuracy: 0.9749 - val_loss: 0.2980 - val_dense_3_loss: 0.1887 - val_dense_4_loss: 0.0621 - val_dense_5_loss: 0.0461 - val_dense_3_accuracy: 0.9482 - val_dense_4_accuracy: 0.9846 - val_dense_5_accuracy: 0.9866
# Epoch 24/30
# 180/180 [==============================] - 36s 202ms/step - loss: 0.4689 - dense_3_loss: 0.2633 - dense_4_loss: 0.1215 - dense_5_loss: 0.0842 - dense_3_accuracy: 0.9263 - dense_4_accuracy: 0.9655 - dense_5_accuracy: 0.9750 - val_loss: 0.3007 - val_dense_3_loss: 0.1914 - val_dense_4_loss: 0.0620 - val_dense_5_loss: 0.0462 - val_dense_3_accuracy: 0.9455 - val_dense_4_accuracy: 0.9846 - val_dense_5_accuracy: 0.9866
# Epoch 25/30
# 180/180 [==============================] - 36s 200ms/step - loss: 0.4591 - dense_3_loss: 0.2588 - dense_4_loss: 0.1163 - dense_5_loss: 0.0841 - dense_3_accuracy: 0.9267 - dense_4_accuracy: 0.9663 - dense_5_accuracy: 0.9744 - val_loss: 0.3045 - val_dense_3_loss: 0.1930 - val_dense_4_loss: 0.0629 - val_dense_5_loss: 0.0476 - val_dense_3_accuracy: 0.9460 - val_dense_4_accuracy: 0.9841 - val_dense_5_accuracy: 0.9863
# Epoch 26/30
# 180/180 [==============================] - 36s 202ms/step - loss: 0.4567 - dense_3_loss: 0.2559 - dense_4_loss: 0.1186 - dense_5_loss: 0.0822 - dense_3_accuracy: 0.9282 - dense_4_accuracy: 0.9664 - dense_5_accuracy: 0.9757 - val_loss: 0.3092 - val_dense_3_loss: 0.1944 - val_dense_4_loss: 0.0655 - val_dense_5_loss: 0.0480 - val_dense_3_accuracy: 0.9445 - val_dense_4_accuracy: 0.9836 - val_dense_5_accuracy: 0.9866
# Epoch 27/30
# 180/180 [==============================] - 36s 199ms/step - loss: 0.4603 - dense_3_loss: 0.2599 - dense_4_loss: 0.1153 - dense_5_loss: 0.0851 - dense_3_accuracy: 0.9260 - dense_4_accuracy: 0.9672 - dense_5_accuracy: 0.9755 - val_loss: 0.3016 - val_dense_3_loss: 0.1930 - val_dense_4_loss: 0.0609 - val_dense_5_loss: 0.0469 - val_dense_3_accuracy: 0.9452 - val_dense_4_accuracy: 0.9843 - val_dense_5_accuracy: 0.9863
# Epoch 28/30
# 180/180 [==============================] - 37s 205ms/step - loss: 0.4498 - dense_3_loss: 0.2551 - dense_4_loss: 0.1130 - dense_5_loss: 0.0817 - dense_3_accuracy: 0.9279 - dense_4_accuracy: 0.9674 - dense_5_accuracy: 0.9757 - val_loss: 0.3011 - val_dense_3_loss: 0.1920 - val_dense_4_loss: 0.0609 - val_dense_5_loss: 0.0471 - val_dense_3_accuracy: 0.9477 - val_dense_4_accuracy: 0.9853 - val_dense_5_accuracy: 0.9858
# Epoch 29/30
# 134/180 [=====================>........] - ETA: 8s - loss: 0.4557 - dense_3_loss: 0.2568 - dense_4_loss: 0.1180 - dense_5_loss: 0.0809 - dense_3_accuracy: 0.9267 - dense_4_accuracy: 0.9658 - dense_5_accuracy: 0.9756

# %%
# %matplotlib inline
def plot_loss(his, epoch, title):
    plt.style.use('ggplot')
    plt.figure()
    plt.plot(np.arange(0, epoch), his.history['loss'], label='train_loss')
    plt.plot(np.arange(0, epoch), his.history['dense_3_loss'], label='train_root_loss')
    plt.plot(np.arange(0, epoch), his.history['dense_4_loss'], label='train_vowel_loss')
    plt.plot(np.arange(0, epoch), his.history['dense_5_loss'], label='train_consonant_loss')
    
    plt.plot(np.arange(0, epoch), his.history['val_dense_3_loss'], label='val_train_root_loss')
    plt.plot(np.arange(0, epoch), his.history['val_dense_4_loss'], label='val_train_vowel_loss')
    plt.plot(np.arange(0, epoch), his.history['val_dense_5_loss'], label='val_train_consonant_loss')
    
    plt.title(title)
    plt.xlabel('Epoch #')
    plt.ylabel('Loss')
    plt.legend(loc='upper right')
    plt.show()

def plot_acc(his, epoch, title):
    plt.style.use('ggplot')
    plt.figure()
    plt.plot(np.arange(0, epoch), his.history['dense_3_accuracy'], label='train_root_acc')
    plt.plot(np.arange(0, epoch), his.history['dense_4_accuracy'], label='train_vowel_accuracy')
    plt.plot(np.arange(0, epoch), his.history['dense_5_accuracy'], label='train_consonant_accuracy')
    
    plt.plot(np.arange(0, epoch), his.history['val_dense_3_accuracy'], label='val_root_acc')
    plt.plot(np.arange(0, epoch), his.history['val_dense_4_accuracy'], label='val_vowel_accuracy')
    plt.plot(np.arange(0, epoch), his.history['val_dense_5_accuracy'], label='val_consonant_accuracy')
    plt.title(title)
    plt.xlabel('Epoch #')
    plt.ylabel('Accuracy')
    plt.legend(loc='upper right')
    plt.show()

# %%
for dataset in range(4):
    plot_loss(histories[dataset], epochs, f'Training Dataset: {dataset}')
    plot_acc(histories[dataset], epochs, f'Training Dataset: {dataset}')

# %%
del histories
gc.collect()
# Out:
# 27248

# %%
preds_dict = {
    'grapheme_root': [],
    'vowel_diacritic': [],
    'consonant_diacritic': []
}

# %%
components = ['consonant_diacritic', 'grapheme_root', 'vowel_diacritic']
target=[] # model predictions placeholder
row_id=[] # row_id place holder
for i in range(4):
    df_test_img = pd.read_parquet('/kaggle/input/bengaliai-cv19/test_image_data_{}.parquet'.format(i)) 
    df_test_img.set_index('image_id', inplace=True)

    X_test = resize(df_test_img, need_progress_bar=False)/255
    X_test = X_test.values.reshape(-1, IMG_SIZE, IMG_SIZE, N_CHANNELS)
    
    preds = model.predict(X_test)

    for i, p in enumerate(preds_dict):
        preds_dict[p] = np.argmax(preds[i], axis=1)

    for k,id in enumerate(df_test_img.index.values):  
        for i,comp in enumerate(components):
            id_sample=id+'_'+comp
            row_id.append(id_sample)
            target.append(preds_dict[comp][k])
    del df_test_img
    del X_test
    gc.collect()

df_sample = pd.DataFrame(
    {
        'row_id': row_id,
        'target':target
    },
    columns = ['row_id','target'] 
)
df_sample.to_csv('submission.csv',index=False)
df_sample.head()
# Out:
#                        row_id  target
# 0  Test_0_consonant_diacritic       0
# 1        Test_0_grapheme_root       3
# 2      Test_0_vowel_diacritic       0
# 3  Test_1_consonant_diacritic       0
# 4        Test_1_grapheme_root      93
