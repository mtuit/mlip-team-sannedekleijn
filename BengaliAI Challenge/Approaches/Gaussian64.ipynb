# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from tqdm.auto import tqdm
from glob import glob
import time, gc
import cv2

from tensorflow import keras
import matplotlib.image as mpimg
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model
from keras.models import clone_model
from keras.layers import Dense,Conv2D,Flatten,MaxPool2D,Dropout,BatchNormalization,Input
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import PIL.Image as Image, PIL.ImageDraw as ImageDraw, PIL.ImageFont as ImageFont
from matplotlib import pyplot as plt
import seaborn as sns
import scipy.signal
from scipy.signal import fftconvolve

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# Using TensorFlow backend.
# /kaggle/input/bengaliai-cv19/test_image_data_2.parquet
# /kaggle/input/bengaliai-cv19/test_image_data_3.parquet
# /kaggle/input/bengaliai-cv19/test_image_data_0.parquet
# /kaggle/input/bengaliai-cv19/train.csv
# /kaggle/input/bengaliai-cv19/test_image_data_1.parquet
# /kaggle/input/bengaliai-cv19/class_map.csv
# /kaggle/input/bengaliai-cv19/train_image_data_3.parquet
# /kaggle/input/bengaliai-cv19/train_image_data_2.parquet
# /kaggle/input/bengaliai-cv19/test.csv
# /kaggle/input/bengaliai-cv19/sample_submission.csv
# /kaggle/input/bengaliai-cv19/train_image_data_1.parquet
# /kaggle/input/bengaliai-cv19/train_image_data_0.parquet

# %%
train_df_ = pd.read_csv('/kaggle/input/bengaliai-cv19/train.csv')
test_df_ = pd.read_csv('/kaggle/input/bengaliai-cv19/test.csv')
class_map_df = pd.read_csv('/kaggle/input/bengaliai-cv19/class_map.csv')
sample_sub_df = pd.read_csv('/kaggle/input/bengaliai-cv19/sample_submission.csv')

# %%
train_df_.head()
# Out:
#   image_id  grapheme_root  vowel_diacritic  consonant_diacritic grapheme
# 0  Train_0             15                9                    5   ক্ট্রো
# 1  Train_1            159                0                    0        হ
# 2  Train_2             22                3                    5     খ্রী
# 3  Train_3             53                2                    2     র্টি
# 4  Train_4             71                9                    5     থ্রো

# %%
test_df_.head()
# Out:
#                        row_id image_id            component
# 0  Test_0_consonant_diacritic   Test_0  consonant_diacritic
# 1        Test_0_grapheme_root   Test_0        grapheme_root
# 2      Test_0_vowel_diacritic   Test_0      vowel_diacritic
# 3  Test_1_consonant_diacritic   Test_1  consonant_diacritic
# 4        Test_1_grapheme_root   Test_1        grapheme_root

# %%
sample_sub_df.head()
# Out:
#                        row_id  target
# 0  Test_0_consonant_diacritic       0
# 1        Test_0_grapheme_root       0
# 2      Test_0_vowel_diacritic       0
# 3  Test_1_consonant_diacritic       0
# 4        Test_1_grapheme_root       0

# %%
class_map_df.head()
# Out:
#   component_type  label component
# 0  grapheme_root      0         ং
# 1  grapheme_root      1         ঃ
# 2  grapheme_root      2         অ
# 3  grapheme_root      3         আ
# 4  grapheme_root      4         ই

# %%
print(f'Size of training data: {train_df_.shape}')
print(f'Size of test data: {test_df_.shape}')
print(f'Size of class map: {class_map_df.shape}')
# Out:
# Size of training data: (200840, 5)
# Size of test data: (36, 3)
# Size of class map: (186, 3)

# %% [markdown]
# ## Exploratory Data Analysis
# Exploratory data analysis (EDA) is an approach to analyzing data sets to summarize their main characteristics, often with visual methods.

# %%
HEIGHT = 236
WIDTH = 236

def get_n(df, field, n, top=True):
    top_graphemes = df.groupby([field]).size().reset_index(name='counts')['counts'].sort_values(ascending=not top)[:n]
    top_grapheme_roots = top_graphemes.index
    top_grapheme_counts = top_graphemes.values
    top_graphemes = class_map_df[class_map_df['component_type'] == field].reset_index().iloc[top_grapheme_roots]
    top_graphemes.drop(['component_type', 'label'], axis=1, inplace=True)
    top_graphemes.loc[:, 'count'] = top_grapheme_counts
    return top_graphemes

def image_from_char(char):
    image = Image.new('RGB', (WIDTH, HEIGHT))
    draw = ImageDraw.Draw(image)
    myfont = ImageFont.truetype('/kaggle/input/kalpurush-fonts/kalpurush-2.ttf', 120)
    w, h = draw.textsize(char, font=myfont)
    draw.text(((WIDTH - w) / 2,(HEIGHT - h) / 3), char, font=myfont)

    return image

# %% [markdown]
# ### Number of unique values

# %%
print(f'Number of unique grapheme roots: {train_df_["grapheme_root"].nunique()}')
print(f'Number of unique vowel diacritic: {train_df_["vowel_diacritic"].nunique()}')
print(f'Number of unique consonant diacritic: {train_df_["consonant_diacritic"].nunique()}')
# Out:
# Number of unique grapheme roots: 168
# Number of unique vowel diacritic: 11
# Number of unique consonant diacritic: 7

# %% [markdown]
# ### Most used top 10 Grapheme Roots in training set

# %%
top_10_roots = get_n(train_df_, 'grapheme_root', 10)
top_10_roots
# Out:
#      index component  count
# 72      72         দ   5736
# 64      64         ত   5596
# 13      13         ক   5420
# 107    107         ব   5321
# 23      23         গ   5149
# 96      96         প   4926
# 113    113         ভ   4395
# 147    147         স   4392
# 133    133         শ   4374
# 115    115         ম   4015

# %%
train_df_ = train_df_.drop(['grapheme'], axis=1, inplace=False)

# %%
train_df_[['grapheme_root', 'vowel_diacritic', 'consonant_diacritic']] = train_df_[['grapheme_root', 'vowel_diacritic', 'consonant_diacritic']].astype('uint8')

# %%
IMG_SIZE=64
N_CHANNELS=1

# %% [markdown]
# Let's apply some image processing (credits: [this kernel](https://www.kaggle.com/shawon10/bangla-graphemes-image-processing-deep-cnn)) while resizing the images, which will center crop the region of interest from the original images.

# %%
def resize(df, size=64, need_progress_bar=True):
    resized = {}
    resize_size=64
    if need_progress_bar:
        print("Resize images")
        for i in tqdm(range(df.shape[0])):
            image=df.loc[df.index[i]].values.reshape(137,236)
            _, thresh = cv2.threshold(image, 30, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
            contours, _ = cv2.findContours(thresh,cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)[-2:]

            idx = 0 
            ls_xmin = []
            ls_ymin = []
            ls_xmax = []
            ls_ymax = []
            for cnt in contours:
                idx += 1
                x,y,w,h = cv2.boundingRect(cnt)
                ls_xmin.append(x)
                ls_ymin.append(y)
                ls_xmax.append(x + w)
                ls_ymax.append(y + h)
            xmin = min(ls_xmin)
            ymin = min(ls_ymin)
            xmax = max(ls_xmax)
            ymax = max(ls_ymax)

            roi = image[ymin:ymax,xmin:xmax]
            resized_roi = cv2.resize(roi, (resize_size, resize_size),interpolation=cv2.INTER_AREA)
            resized[df.index[i]] = resized_roi.reshape(-1)
    else:
        print("Resize images")
        for i in range(df.shape[0]):
            #image = cv2.resize(df.loc[df.index[i]].values.reshape(137,236),(size,size),None,fx=0.5,fy=0.5,interpolation=cv2.INTER_AREA)
            image=df.loc[df.index[i]].values.reshape(137,236)
            _, thresh = cv2.threshold(image, 30, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
            contours, _ = cv2.findContours(thresh,cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)[-2:]

            idx = 0 
            ls_xmin = []
            ls_ymin = []
            ls_xmax = []
            ls_ymax = []
            for cnt in contours:
                idx += 1
                x,y,w,h = cv2.boundingRect(cnt)
                ls_xmin.append(x)
                ls_ymin.append(y)
                ls_xmax.append(x + w)
                ls_ymax.append(y + h)
            xmin = min(ls_xmin)
            ymin = min(ls_ymin)
            xmax = max(ls_xmax)
            ymax = max(ls_ymax)

            roi = image[ymin:ymax,xmin:xmax]
            resized_roi = cv2.resize(roi, (resize_size, resize_size),interpolation=cv2.INTER_AREA)
            resized[df.index[i]] = resized_roi.reshape(-1)
    resized = pd.DataFrame(resized).T
    return resized

# %%
def gaussian_2d(sigma_mm, voxel_size):
    """
    Paramaters
    ----------
    Input:
    sigma_mm: 
    voxel_size: voxel_size (in mm?)
    
    Output:
    kernel: kernel
    x : matrix of x coordinates of the filter
    y : matrix of y coordinates of the filter
    """
    # define the scaling of sigma: we chose to scale with 3 as the lecture 
    # slides mention that the gaussian function goes to zero approximately 
    # after 3*sigma.
    kernel_scale = sigma_mm*3

    # find the x and y coordinates of the filter. do this by going from the 
    # start to the end of the kernel and taking steps of voxel_size
    x = np.arange(-kernel_scale, kernel_scale, voxel_size[0])
    y = np.arange(-kernel_scale, kernel_scale, voxel_size[1])

    # create a grid for result visualisation
    grid_x, grid_y = np.meshgrid(x,y)

    # find the kernel based on the given formula
    kernel = 1/(2*np.pi*sigma_mm**2) * np.exp(-(grid_x**2+grid_y**2)/(2*sigma_mm**2))
    
    return kernel, x, y

# %%
def laplacian_of_gaussian(g):
    """
    A function to compute the Laplacian of Gaussian
    @param g:   The Gaussian
    """
    # get the second derivatives
    gxx = np.gradient(np.gradient(g,axis=0),axis=0)
    gyy = np.gradient(np.gradient(g,axis=1),axis=1)

    # find the laplacian of gaudian based on the given formula
    LoG = gxx + gyy

    return LoG,gxx,gyy

# %%
g,x,y = gaussian_2d(3.0, [1, 1])
LoG,gxx,gyy = laplacian_of_gaussian(g)

def gaussian(df):
    gaussianed = {}
    print("Convolve images with gaussian kernel")
    for i in tqdm(range(df.shape[0])):
        image= df.loc[df.index[i]].values.reshape(64,64)
        gaussianed[df.index[i]] = scipy.signal.fftconvolve(image, g, mode='same').reshape(-1)
    
    gaussianed = pd.DataFrame(gaussianed).T
    return gaussianed

# %%
def get_dummies(df):
    cols = []
    for col in df:
        cols.append(pd.get_dummies(df[col].astype(str)))
    return pd.concat(cols, axis=1)

# %% [markdown]
# ## Basic Model

# %%
inputs = Input(shape = (IMG_SIZE, IMG_SIZE, 1))

model = Conv2D(filters=32, kernel_size=(3, 3), padding='SAME', activation='relu', input_shape=(IMG_SIZE, IMG_SIZE, 1))(inputs)
model = Conv2D(filters=32, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=32, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=32, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Conv2D(filters=32, kernel_size=(5, 5), padding='SAME', activation='relu')(model)
model = Dropout(rate=0.3)(model)

model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Conv2D(filters=64, kernel_size=(5, 5), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = Dropout(rate=0.3)(model)

model = Conv2D(filters=128, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=128, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=128, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=128, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Conv2D(filters=128, kernel_size=(5, 5), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = Dropout(rate=0.3)(model)

model = Conv2D(filters=256, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=256, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=256, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=256, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Conv2D(filters=256, kernel_size=(5, 5), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = Dropout(rate=0.3)(model)

model = Flatten()(model)
model = Dense(1024, activation = "relu")(model)
model = Dropout(rate=0.3)(model)
dense = Dense(512, activation = "relu")(model)

head_root = Dense(168, activation = 'softmax')(dense)
head_vowel = Dense(11, activation = 'softmax')(dense)
head_consonant = Dense(7, activation = 'softmax')(dense)

model = Model(inputs=inputs, outputs=[head_root, head_vowel, head_consonant])

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 64, 64, 1)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 32)   320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 32)   9248        conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 32)   9248        conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 32)   9248        conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 64, 64, 32)   128         conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 32)   25632       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 32, 32, 32)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 64)   18496       dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 64)   36928       conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 64)   36928       conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 64)   36928       conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 64)   256         conv2d_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 64)   102464      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 16, 16, 64)   256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 16, 16, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 128)  73856       dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 128)  147584      conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 128)  147584      conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 128)  147584      conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 128)  512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 128)    0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 128)    409728      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 8, 8, 128)    512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 8, 8, 128)    0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 256)    295168      dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 8, 256)    590080      conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 8, 8, 256)    590080      conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 8, 8, 256)    590080      conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 8, 8, 256)    1024        conv2d_19[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 4, 4, 256)    0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 4, 4, 256)    1638656     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 4, 4, 256)    1024        conv2d_20[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 4, 4, 256)    0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 4096)         0           dropout_4[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         4195328     flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 1024)         0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512)          524800      dropout_5[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 168)          86184       dense_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 11)           5643        dense_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 7)            3591        dense_2[0][0]
# ==================================================================================================
# Total params: 9,735,098
# Trainable params: 9,733,242
# Non-trainable params: 1,856
# __________________________________________________________________________________________________

# %% [markdown]
# Let's visualize the 3-tailed (3 output) CNN by plotting it.

# %%
from keras.utils import plot_model
plot_model(model, to_file='model.png')

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Set a learning rate annealer. Learning rate will be half after 3 epochs if accuracy is not increased
learning_rate_reduction_root = ReduceLROnPlateau(monitor='dense_3_accuracy', 
                                            patience=3, 
                                            verbose=1,
                                            factor=0.5, 
                                            min_lr=0.00001)
learning_rate_reduction_vowel = ReduceLROnPlateau(monitor='dense_4_accuracy', 
                                            patience=3, 
                                            verbose=1,
                                            factor=0.5, 
                                            min_lr=0.00001)
learning_rate_reduction_consonant = ReduceLROnPlateau(monitor='dense_5_accuracy', 
                                            patience=3, 
                                            verbose=1,
                                            factor=0.5, 
                                            min_lr=0.00001)

# %%
batch_size = 256
epochs = 30

# %%
class MultiOutputDataGenerator(keras.preprocessing.image.ImageDataGenerator):

    def flow(self,
             x,
             y=None,
             batch_size=32,
             shuffle=True,
             sample_weight=None,
             seed=None,
             save_to_dir=None,
             save_prefix='',
             save_format='png',
             subset=None):

        targets = None
        target_lengths = {}
        ordered_outputs = []
        for output, target in y.items():
            if targets is None:
                targets = target
            else:
                targets = np.concatenate((targets, target), axis=1)
            target_lengths[output] = target.shape[1]
            ordered_outputs.append(output)


        for flowx, flowy in super().flow(x, targets, batch_size=batch_size,
                                         shuffle=shuffle):
            target_dict = {}
            i = 0
            for output in ordered_outputs:
                target_length = target_lengths[output]
                target_dict[output] = flowy[:, i: i + target_length]
                i += target_length

            yield flowx, target_dict

# %%
HEIGHT = 137
WIDTH = 236

# %% [markdown]
# ### Training loop

# %%
histories = []
for i in range(2): #hier heb ik 2 van gemaakt ipv 4
    train_df = pd.merge(pd.read_parquet(f'/kaggle/input/bengaliai-cv19/train_image_data_{i}.parquet'), train_df_, on='image_id').drop(['image_id'], axis=1)
    
    # Get training labels
    Y_train_root = pd.get_dummies(train_df['grapheme_root']).values
    Y_train_vowel = pd.get_dummies(train_df['vowel_diacritic']).values
    Y_train_consonant = pd.get_dummies(train_df['consonant_diacritic']).values
    
    # Add gaussian kernel labels
    Y_train_root = np.concatenate((Y_train_root, Y_train_root))
    Y_train_vowel = np.concatenate((Y_train_vowel, Y_train_vowel))
    Y_train_consonant = np.concatenate((Y_train_consonant, Y_train_consonant))

    # Visualize few samples of current training dataset
    #fig, ax = plt.subplots(nrows=3, ncols=4, figsize=(16, 8))
    #count=0
    #for row in ax:
    #    for col in row:
    #        col.imshow(resize(train_df.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic'], axis=1).iloc[[count]], need_progress_bar=False).values.reshape(-1).reshape(IMG_SIZE, IMG_SIZE).astype(np.float64))
    #        count += 1
    #plt.show()
   
    X_train = train_df.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic'], axis=1)
    
    # Resize images
    X_train = resize(X_train)/255
    
    # Add gaussian kernel to training data
    Gaus_X_train = gaussian(X_train)
    X_train = pd.concat([X_train, Gaus_X_train])
     
    # CNN takes images in shape `(batch_size, h, w, channels)`, so reshape the images
    X_train = X_train.values.reshape(-1, IMG_SIZE, IMG_SIZE, N_CHANNELS)
    

    print(f'Training images: {X_train.shape}')
    print(f'Training labels root: {Y_train_root.shape}')
    print(f'Training labels vowel: {Y_train_vowel.shape}')
    print(f'Training labels consonants: {Y_train_consonant.shape}')

    # Divide the data into training and validation set
    x_train, x_test, y_train_root, y_test_root, y_train_vowel, y_test_vowel, y_train_consonant, y_test_consonant = train_test_split(X_train, Y_train_root, Y_train_vowel, Y_train_consonant, test_size=0.08, random_state=666)
    del train_df
    del X_train
    del Y_train_root, Y_train_vowel, Y_train_consonant

    # Data augmentation for creating more training data
    datagen = MultiOutputDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=8,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.15, # Randomly zoom image 
        width_shift_range=0.15,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.15,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images


    # This will just calculate parameters required to augment the given data. This won't perform any augmentations
    datagen.fit(x_train)

    # Fit the model
    history = model.fit_generator(datagen.flow(x_train, {'dense_3': y_train_root, 'dense_4': y_train_vowel, 'dense_5': y_train_consonant}, batch_size=batch_size),
                              epochs = epochs, validation_data = (x_test, [y_test_root, y_test_vowel, y_test_consonant]), 
                              steps_per_epoch=x_train.shape[0] // batch_size, 
                              callbacks=[learning_rate_reduction_root, learning_rate_reduction_vowel, learning_rate_reduction_consonant])

    histories.append(history)
    
    # Delete to reduce memory usage
    del x_train
    del x_test
    del y_train_root
    del y_test_root
    del y_train_vowel
    del y_test_vowel
    del y_train_consonant
    del y_test_consonant
    gc.collect()
# Out:
# Resize images
# HBox(children=(FloatProgress(value=0.0, max=50210.0), HTML(value='')))
# Convolve images with gaussian kernel
# HBox(children=(FloatProgress(value=0.0, max=50210.0), HTML(value='')))
# Training images: (100420, 64, 64, 1)
# Training labels root: (100420, 168)
# Training labels vowel: (100420, 11)
# Training labels consonants: (100420, 7)
# Epoch 1/30
# 360/360 [==============================] - 83s 231ms/step - loss: 7.5172 - dense_3_loss: 4.6588 - dense_4_loss: 1.7366 - dense_5_loss: 1.1219 - dense_3_accuracy: 0.0331 - dense_4_accuracy: 0.3799 - dense_5_accuracy: 0.6292 - val_loss: 6.6466 - val_dense_3_loss: 4.4562 - val_dense_4_loss: 1.1955 - val_dense_5_loss: 0.9937 - val_dense_3_accuracy: 0.0373 - val_dense_4_accuracy: 0.5688 - val_dense_5_accuracy: 0.6531
# Epoch 2/30
# 360/360 [==============================] - 73s 202ms/step - loss: 6.1093 - dense_3_loss: 4.1753 - dense_4_loss: 1.0635 - dense_5_loss: 0.8706 - dense_3_accuracy: 0.0669 - dense_4_accuracy: 0.6322 - dense_5_accuracy: 0.7033 - val_loss: 4.6705 - val_dense_3_loss: 3.4546 - val_dense_4_loss: 0.6220 - val_dense_5_loss: 0.5970 - val_dense_3_accuracy: 0.1393 - val_dense_4_accuracy: 0.7984 - val_dense_5_accuracy: 0.7899
# Epoch 3/30
# 360/360 [==============================] - 71s 198ms/step - loss: 4.5444 - dense_3_loss: 3.2005 - dense_4_loss: 0.7315 - dense_5_loss: 0.6124 - dense_3_accuracy: 0.1850 - dense_4_accuracy: 0.7575 - dense_5_accuracy: 0.7883 - val_loss: 2.9023 - val_dense_3_loss: 2.1862 - val_dense_4_loss: 0.3749 - val_dense_5_loss: 0.3411 - val_dense_3_accuracy: 0.3683 - val_dense_4_accuracy: 0.8800 - val_dense_5_accuracy: 0.8811
# Epoch 4/30
# 360/360 [==============================] - 71s 198ms/step - loss: 3.1780 - dense_3_loss: 2.1708 - dense_4_loss: 0.5761 - dense_5_loss: 0.4311 - dense_3_accuracy: 0.3954 - dense_4_accuracy: 0.8148 - dense_5_accuracy: 0.8539 - val_loss: 1.8200 - val_dense_3_loss: 1.3032 - val_dense_4_loss: 0.2820 - val_dense_5_loss: 0.2342 - val_dense_3_accuracy: 0.6146 - val_dense_4_accuracy: 0.9142 - val_dense_5_accuracy: 0.9273
# Epoch 5/30
# 360/360 [==============================] - 72s 199ms/step - loss: 2.3793 - dense_3_loss: 1.5710 - dense_4_loss: 0.4666 - dense_5_loss: 0.3417 - dense_3_accuracy: 0.5548 - dense_4_accuracy: 0.8493 - dense_5_accuracy: 0.8875 - val_loss: 1.2978 - val_dense_3_loss: 0.9105 - val_dense_4_loss: 0.2141 - val_dense_5_loss: 0.1761 - val_dense_3_accuracy: 0.7283 - val_dense_4_accuracy: 0.9391 - val_dense_5_accuracy: 0.9466
# Epoch 6/30
# 360/360 [==============================] - 72s 199ms/step - loss: 1.8984 - dense_3_loss: 1.2139 - dense_4_loss: 0.3967 - dense_5_loss: 0.2877 - dense_3_accuracy: 0.6517 - dense_4_accuracy: 0.8757 - dense_5_accuracy: 0.9062 - val_loss: 1.0797 - val_dense_3_loss: 0.7121 - val_dense_4_loss: 0.2135 - val_dense_5_loss: 0.1553 - val_dense_3_accuracy: 0.7923 - val_dense_4_accuracy: 0.9390 - val_dense_5_accuracy: 0.9534
# Epoch 7/30
# 360/360 [==============================] - 71s 198ms/step - loss: 1.6024 - dense_3_loss: 1.0075 - dense_4_loss: 0.3444 - dense_5_loss: 0.2505 - dense_3_accuracy: 0.7124 - dense_4_accuracy: 0.8936 - dense_5_accuracy: 0.9203 - val_loss: 0.8351 - val_dense_3_loss: 0.5728 - val_dense_4_loss: 0.1340 - val_dense_5_loss: 0.1252 - val_dense_3_accuracy: 0.8348 - val_dense_4_accuracy: 0.9588 - val_dense_5_accuracy: 0.9590
# Epoch 8/30
# 360/360 [==============================] - 72s 200ms/step - loss: 1.4044 - dense_3_loss: 0.8640 - dense_4_loss: 0.3154 - dense_5_loss: 0.2249 - dense_3_accuracy: 0.7511 - dense_4_accuracy: 0.9034 - dense_5_accuracy: 0.9270 - val_loss: 0.7707 - val_dense_3_loss: 0.5064 - val_dense_4_loss: 0.1550 - val_dense_5_loss: 0.1124 - val_dense_3_accuracy: 0.8550 - val_dense_4_accuracy: 0.9584 - val_dense_5_accuracy: 0.9676
# Epoch 9/30
# 360/360 [==============================] - 73s 202ms/step - loss: 1.2607 - dense_3_loss: 0.7659 - dense_4_loss: 0.2887 - dense_5_loss: 0.2060 - dense_3_accuracy: 0.7792 - dense_4_accuracy: 0.9118 - dense_5_accuracy: 0.9350 - val_loss: 0.6614 - val_dense_3_loss: 0.4337 - val_dense_4_loss: 0.1174 - val_dense_5_loss: 0.1096 - val_dense_3_accuracy: 0.8699 - val_dense_4_accuracy: 0.9676 - val_dense_5_accuracy: 0.9686
# Epoch 10/30
# 360/360 [==============================] - 74s 206ms/step - loss: 1.1526 - dense_3_loss: 0.6922 - dense_4_loss: 0.2684 - dense_5_loss: 0.1920 - dense_3_accuracy: 0.7997 - dense_4_accuracy: 0.9190 - dense_5_accuracy: 0.9385 - val_loss: 0.6220 - val_dense_3_loss: 0.4062 - val_dense_4_loss: 0.1102 - val_dense_5_loss: 0.1047 - val_dense_3_accuracy: 0.8826 - val_dense_4_accuracy: 0.9717 - val_dense_5_accuracy: 0.9704
# Epoch 11/30
# 360/360 [==============================] - 73s 202ms/step - loss: 1.0623 - dense_3_loss: 0.6299 - dense_4_loss: 0.2529 - dense_5_loss: 0.1794 - dense_3_accuracy: 0.8180 - dense_4_accuracy: 0.9241 - dense_5_accuracy: 0.9424 - val_loss: 0.5775 - val_dense_3_loss: 0.3790 - val_dense_4_loss: 0.1010 - val_dense_5_loss: 0.0968 - val_dense_3_accuracy: 0.8872 - val_dense_4_accuracy: 0.9737 - val_dense_5_accuracy: 0.9724
# Epoch 12/30
# 360/360 [==============================] - 71s 198ms/step - loss: 0.9968 - dense_3_loss: 0.5904 - dense_4_loss: 0.2402 - dense_5_loss: 0.1662 - dense_3_accuracy: 0.8280 - dense_4_accuracy: 0.9281 - dense_5_accuracy: 0.9472 - val_loss: 0.5507 - val_dense_3_loss: 0.3419 - val_dense_4_loss: 0.1171 - val_dense_5_loss: 0.0883 - val_dense_3_accuracy: 0.8967 - val_dense_4_accuracy: 0.9698 - val_dense_5_accuracy: 0.9742
# Epoch 13/30
# 360/360 [==============================] - 71s 197ms/step - loss: 0.9401 - dense_3_loss: 0.5509 - dense_4_loss: 0.2279 - dense_5_loss: 0.1612 - dense_3_accuracy: 0.8400 - dense_4_accuracy: 0.9305 - dense_5_accuracy: 0.9487 - val_loss: 0.5105 - val_dense_3_loss: 0.3243 - val_dense_4_loss: 0.0934 - val_dense_5_loss: 0.0921 - val_dense_3_accuracy: 0.9054 - val_dense_4_accuracy: 0.9740 - val_dense_5_accuracy: 0.9722
# Epoch 14/30
# 360/360 [==============================] - 71s 197ms/step - loss: 0.8849 - dense_3_loss: 0.5178 - dense_4_loss: 0.2148 - dense_5_loss: 0.1524 - dense_3_accuracy: 0.8483 - dense_4_accuracy: 0.9348 - dense_5_accuracy: 0.9520 - val_loss: 0.4731 - val_dense_3_loss: 0.3111 - val_dense_4_loss: 0.0882 - val_dense_5_loss: 0.0736 - val_dense_3_accuracy: 0.9083 - val_dense_4_accuracy: 0.9755 - val_dense_5_accuracy: 0.9766
# Epoch 15/30
# 360/360 [==============================] - 72s 199ms/step - loss: 0.8476 - dense_3_loss: 0.4901 - dense_4_loss: 0.2132 - dense_5_loss: 0.1443 - dense_3_accuracy: 0.8563 - dense_4_accuracy: 0.9365 - dense_5_accuracy: 0.9537 - val_loss: 0.4972 - val_dense_3_loss: 0.2988 - val_dense_4_loss: 0.1199 - val_dense_5_loss: 0.0775 - val_dense_3_accuracy: 0.9106 - val_dense_4_accuracy: 0.9670 - val_dense_5_accuracy: 0.9768
# Epoch 16/30
# 360/360 [==============================] - 72s 199ms/step - loss: 0.8008 - dense_3_loss: 0.4631 - dense_4_loss: 0.1978 - dense_5_loss: 0.1399 - dense_3_accuracy: 0.8636 - dense_4_accuracy: 0.9404 - dense_5_accuracy: 0.9557 - val_loss: 0.4318 - val_dense_3_loss: 0.2823 - val_dense_4_loss: 0.0775 - val_dense_5_loss: 0.0713 - val_dense_3_accuracy: 0.9216 - val_dense_4_accuracy: 0.9783 - val_dense_5_accuracy: 0.9782
# Epoch 17/30
# 360/360 [==============================] - 71s 198ms/step - loss: 0.7594 - dense_3_loss: 0.4345 - dense_4_loss: 0.1921 - dense_5_loss: 0.1328 - dense_3_accuracy: 0.8720 - dense_4_accuracy: 0.9423 - dense_5_accuracy: 0.9581 - val_loss: 0.4317 - val_dense_3_loss: 0.2769 - val_dense_4_loss: 0.0812 - val_dense_5_loss: 0.0741 - val_dense_3_accuracy: 0.9190 - val_dense_4_accuracy: 0.9787 - val_dense_5_accuracy: 0.9768
# Epoch 18/30
# 360/360 [==============================] - 71s 198ms/step - loss: 0.7327 - dense_3_loss: 0.4199 - dense_4_loss: 0.1861 - dense_5_loss: 0.1268 - dense_3_accuracy: 0.8756 - dense_4_accuracy: 0.9441 - dense_5_accuracy: 0.9593 - val_loss: 0.4051 - val_dense_3_loss: 0.2614 - val_dense_4_loss: 0.0717 - val_dense_5_loss: 0.0685 - val_dense_3_accuracy: 0.9261 - val_dense_4_accuracy: 0.9793 - val_dense_5_accuracy: 0.9796
# Epoch 19/30
# 360/360 [==============================] - 71s 198ms/step - loss: 0.7006 - dense_3_loss: 0.3982 - dense_4_loss: 0.1801 - dense_5_loss: 0.1223 - dense_3_accuracy: 0.8828 - dense_4_accuracy: 0.9465 - dense_5_accuracy: 0.9608 - val_loss: 0.4350 - val_dense_3_loss: 0.2584 - val_dense_4_loss: 0.1030 - val_dense_5_loss: 0.0722 - val_dense_3_accuracy: 0.9239 - val_dense_4_accuracy: 0.9712 - val_dense_5_accuracy: 0.9761
# Epoch 20/30
# 360/360 [==============================] - 72s 199ms/step - loss: 0.6884 - dense_3_loss: 0.3900 - dense_4_loss: 0.1794 - dense_5_loss: 0.1190 - dense_3_accuracy: 0.8853 - dense_4_accuracy: 0.9460 - dense_5_accuracy: 0.9618 - val_loss: 0.3674 - val_dense_3_loss: 0.2356 - val_dense_4_loss: 0.0736 - val_dense_5_loss: 0.0603 - val_dense_3_accuracy: 0.9324 - val_dense_4_accuracy: 0.9808 - val_dense_5_accuracy: 0.9822
# Epoch 21/30
# 360/360 [==============================] - 72s 201ms/step - loss: 0.6554 - dense_3_loss: 0.3706 - dense_4_loss: 0.1685 - dense_5_loss: 0.1162 - dense_3_accuracy: 0.8908 - dense_4_accuracy: 0.9500 - dense_5_accuracy: 0.9630 - val_loss: 0.3463 - val_dense_3_loss: 0.2187 - val_dense_4_loss: 0.0684 - val_dense_5_loss: 0.0571 - val_dense_3_accuracy: 0.9340 - val_dense_4_accuracy: 0.9820 - val_dense_5_accuracy: 0.9817
# Epoch 22/30
# 360/360 [==============================] - 72s 200ms/step - loss: 0.6399 - dense_3_loss: 0.3606 - dense_4_loss: 0.1648 - dense_5_loss: 0.1144 - dense_3_accuracy: 0.8938 - dense_4_accuracy: 0.9504 - dense_5_accuracy: 0.9637 - val_loss: 0.3601 - val_dense_3_loss: 0.2288 - val_dense_4_loss: 0.0702 - val_dense_5_loss: 0.0610 - val_dense_3_accuracy: 0.9343 - val_dense_4_accuracy: 0.9820 - val_dense_5_accuracy: 0.9820
# Epoch 23/30
# 360/360 [==============================] - 72s 200ms/step - loss: 0.6107 - dense_3_loss: 0.3385 - dense_4_loss: 0.1606 - dense_5_loss: 0.1116 - dense_3_accuracy: 0.8994 - dense_4_accuracy: 0.9519 - dense_5_accuracy: 0.9653 - val_loss: 0.3448 - val_dense_3_loss: 0.2124 - val_dense_4_loss: 0.0720 - val_dense_5_loss: 0.0583 - val_dense_3_accuracy: 0.9373 - val_dense_4_accuracy: 0.9801 - val_dense_5_accuracy: 0.9827
# Epoch 24/30
#  76/360 [=====>........................] - ETA: 52s - loss: 0.6261 - dense_3_loss: 0.3443 - dense_4_loss: 0.1692 - dense_5_loss: 0.1126 - dense_3_accuracy: 0.8978 - dense_4_accuracy: 0.9511 - dense_5_accuracy: 0.9658Training images: (100420, 64, 64, 1)
# Training labels root: (100420, 168)
# Training labels vowel: (100420, 11)
# Training labels consonants: (100420, 7)
# Epoch 1/30
# 360/360 [==============================] - 73s 203ms/step - loss: 0.8354 - dense_3_loss: 0.4940 - dense_4_loss: 0.1975 - dense_5_loss: 0.1438 - dense_3_accuracy: 0.8660 - dense_4_accuracy: 0.9429 - dense_5_accuracy: 0.9561 - val_loss: 0.4074 - val_dense_3_loss: 0.2480 - val_dense_4_loss: 0.0929 - val_dense_5_loss: 0.0683 - val_dense_3_accuracy: 0.9300 - val_dense_4_accuracy: 0.9762 - val_dense_5_accuracy: 0.9803
# Epoch 2/30
# 360/360 [==============================] - 71s 196ms/step - loss: 0.7169 - dense_3_loss: 0.4116 - dense_4_loss: 0.1763 - dense_5_loss: 0.1290 - dense_3_accuracy: 0.8832 - dense_4_accuracy: 0.9489 - dense_5_accuracy: 0.9600 - val_loss: 0.3566 - val_dense_3_loss: 0.2155 - val_dense_4_loss: 0.0781 - val_dense_5_loss: 0.0648 - val_dense_3_accuracy: 0.9380 - val_dense_4_accuracy: 0.9813 - val_dense_5_accuracy: 0.9831
# Epoch 3/30
# 360/360 [==============================] - 71s 196ms/step - loss: 0.6522 - dense_3_loss: 0.3695 - dense_4_loss: 0.1648 - dense_5_loss: 0.1179 - dense_3_accuracy: 0.8933 - dense_4_accuracy: 0.9511 - dense_5_accuracy: 0.9635 - val_loss: 0.3238 - val_dense_3_loss: 0.1964 - val_dense_4_loss: 0.0711 - val_dense_5_loss: 0.0565 - val_dense_3_accuracy: 0.9435 - val_dense_4_accuracy: 0.9812 - val_dense_5_accuracy: 0.9822
# Epoch 4/30
# 360/360 [==============================] - 71s 198ms/step - loss: 0.6034 - dense_3_loss: 0.3385 - dense_4_loss: 0.1520 - dense_5_loss: 0.1130 - dense_3_accuracy: 0.9023 - dense_4_accuracy: 0.9553 - dense_5_accuracy: 0.9650 - val_loss: 0.3302 - val_dense_3_loss: 0.1932 - val_dense_4_loss: 0.0792 - val_dense_5_loss: 0.0581 - val_dense_3_accuracy: 0.9432 - val_dense_4_accuracy: 0.9795 - val_dense_5_accuracy: 0.9842
# Epoch 5/30
# 360/360 [==============================] - 71s 198ms/step - loss: 0.5777 - dense_3_loss: 0.3231 - dense_4_loss: 0.1481 - dense_5_loss: 0.1066 - dense_3_accuracy: 0.9047 - dense_4_accuracy: 0.9561 - dense_5_accuracy: 0.9664 - val_loss: 0.3083 - val_dense_3_loss: 0.1896 - val_dense_4_loss: 0.0682 - val_dense_5_loss: 0.0512 - val_dense_3_accuracy: 0.9466 - val_dense_4_accuracy: 0.9818 - val_dense_5_accuracy: 0.9847
# Epoch 6/30
# 360/360 [==============================] - 71s 196ms/step - loss: 0.4191 - dense_3_loss: 0.2238 - dense_4_loss: 0.1161 - dense_5_loss: 0.0792 - dense_3_accuracy: 0.9320 - dense_4_accuracy: 0.9649 - dense_5_accuracy: 0.9750 - val_loss: 0.2467 - val_dense_3_loss: 0.1489 - val_dense_4_loss: 0.0573 - val_dense_5_loss: 0.0430 - val_dense_3_accuracy: 0.9582 - val_dense_4_accuracy: 0.9849 - val_dense_5_accuracy: 0.9883
# Epoch 15/30
# 360/360 [==============================] - 71s 198ms/step - loss: 0.4190 - dense_3_loss: 0.2227 - dense_4_loss: 0.1169 - dense_5_loss: 0.0795 - dense_3_accuracy: 0.9330 - dense_4_accuracy: 0.9647 - dense_5_accuracy: 0.9755 - val_loss: 0.2369 - val_dense_3_loss: 0.1348 - val_dense_4_loss: 0.0677 - val_dense_5_loss: 0.0380 - val_dense_3_accuracy: 0.9623 - val_dense_4_accuracy: 0.9824 - val_dense_5_accuracy: 0.9894
# Epoch 16/30
# 360/360 [==============================] - 72s 200ms/step - loss: 0.3652 - dense_3_loss: 0.1937 - dense_4_loss: 0.1027 - dense_5_loss: 0.0688 - dense_3_accuracy: 0.9404 - dense_4_accuracy: 0.9689 - dense_5_accuracy: 0.9784 - val_loss: 0.1921 - val_dense_3_loss: 0.1156 - val_dense_4_loss: 0.0502 - val_dense_5_loss: 0.0272 - val_dense_3_accuracy: 0.9664 - val_dense_4_accuracy: 0.9859 - val_dense_5_accuracy: 0.9910
# Epoch 22/30
# 360/360 [==============================] - 71s 198ms/step - loss: 0.3609 - dense_3_loss: 0.1861 - dense_4_loss: 0.1067 - dense_5_loss: 0.0681 - dense_3_accuracy: 0.9434 - dense_4_accuracy: 0.9681 - dense_5_accuracy: 0.9786 - val_loss: 0.1933 - val_dense_3_loss: 0.1153 - val_dense_4_loss: 0.0471 - val_dense_5_loss: 0.0322 - val_dense_3_accuracy: 0.9661 - val_dense_4_accuracy: 0.9883 - val_dense_5_accuracy: 0.9902
# Epoch 23/30
#  98/360 [=======>......................] - ETA: 48s - loss: 0.3516 - dense_3_loss: 0.1768 - dense_4_loss: 0.1087 - dense_5_loss: 0.0661 - dense_3_accuracy: 0.9448 - dense_4_accuracy: 0.9673 - dense_5_accuracy: 0.9797

# %%
# %matplotlib inline
def plot_loss(his, epoch, title):
    plt.style.use('ggplot')
    plt.figure()
    plt.plot(np.arange(0, epoch), his.history['loss'], label='train_loss')
    plt.plot(np.arange(0, epoch), his.history['dense_3_loss'], label='train_root_loss')
    plt.plot(np.arange(0, epoch), his.history['dense_4_loss'], label='train_vowel_loss')
    plt.plot(np.arange(0, epoch), his.history['dense_5_loss'], label='train_consonant_loss')
    
    plt.plot(np.arange(0, epoch), his.history['val_dense_3_loss'], label='val_train_root_loss')
    plt.plot(np.arange(0, epoch), his.history['val_dense_4_loss'], label='val_train_vowel_loss')
    plt.plot(np.arange(0, epoch), his.history['val_dense_5_loss'], label='val_train_consonant_loss')
    
    plt.title(title)
    plt.xlabel('Epoch #')
    plt.ylabel('Loss')
    plt.legend(loc='upper right')
    plt.show()

def plot_acc(his, epoch, title):
    plt.style.use('ggplot')
    plt.figure()
    plt.plot(np.arange(0, epoch), his.history['dense_3_accuracy'], label='train_root_acc')
    plt.plot(np.arange(0, epoch), his.history['dense_4_accuracy'], label='train_vowel_accuracy')
    plt.plot(np.arange(0, epoch), his.history['dense_5_accuracy'], label='train_consonant_accuracy')
    
    plt.plot(np.arange(0, epoch), his.history['val_dense_3_accuracy'], label='val_root_acc')
    plt.plot(np.arange(0, epoch), his.history['val_dense_4_accuracy'], label='val_vowel_accuracy')
    plt.plot(np.arange(0, epoch), his.history['val_dense_5_accuracy'], label='val_consonant_accuracy')
    plt.title(title)
    plt.xlabel('Epoch #')
    plt.ylabel('Accuracy')
    plt.legend(loc='upper right')
    plt.show()

# %%
for dataset in range(4):
    plot_loss(histories[dataset], epochs, f'Training Dataset: {dataset}')
    plot_acc(histories[dataset], epochs, f'Training Dataset: {dataset}')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-29-ad4b0377e32f> in <module>
#       1 for dataset in range(4):
# ----> 2     plot_loss(histories[dataset], epochs, f'Training Dataset: {dataset}')
#       3     plot_acc(histories[dataset], epochs, f'Training Dataset: {dataset}')
#
# IndexError: list index out of range

# %%
del histories
gc.collect()
# Out:
# 13799

# %%
preds_dict = {
    'grapheme_root': [],
    'vowel_diacritic': [],
    'consonant_diacritic': []
}

# %%
components = ['consonant_diacritic', 'grapheme_root', 'vowel_diacritic']
target=[] # model predictions placeholder
row_id=[] # row_id place holder
for i in range(4):
    df_test_img = pd.read_parquet('/kaggle/input/bengaliai-cv19/test_image_data_{}.parquet'.format(i)) 
    df_test_img.set_index('image_id', inplace=True)

    X_test = resize(df_test_img, need_progress_bar=False)/255
    X_test = X_test.values.reshape(-1, IMG_SIZE, IMG_SIZE, N_CHANNELS)
    
    preds = model.predict(X_test)

    for i, p in enumerate(preds_dict):
        preds_dict[p] = np.argmax(preds[i], axis=1)

    for k,id in enumerate(df_test_img.index.values):  
        for i,comp in enumerate(components):
            id_sample=id+'_'+comp
            row_id.append(id_sample)
            target.append(preds_dict[comp][k])
    del df_test_img
    del X_test
    gc.collect()

df_sample = pd.DataFrame(
    {
        'row_id': row_id,
        'target':target
    },
    columns = ['row_id','target'] 
)
df_sample.to_csv('submission.csv',index=False)
df_sample.head()
# Out:
# Resize images
# Resize images
# Resize images
# Resize images
#                        row_id  target
# 0  Test_0_consonant_diacritic       0
# 1        Test_0_grapheme_root       3
# 2      Test_0_vowel_diacritic       0
# 3  Test_1_consonant_diacritic       0
# 4        Test_1_grapheme_root      93
