# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from tqdm.auto import tqdm
from glob import glob
import time, gc
import cv2

from tensorflow import keras
import matplotlib.image as mpimg
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model
from keras.models import clone_model
from keras.layers import Dense,Conv2D,Flatten,MaxPool2D,Dropout,BatchNormalization, Input
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import PIL.Image as Image, PIL.ImageDraw as ImageDraw, PIL.ImageFont as ImageFont
from matplotlib import pyplot as plt
import seaborn as sns

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# Using TensorFlow backend.
# /kaggle/input/bengaliai-cv19/test.csv
# /kaggle/input/bengaliai-cv19/train_image_data_3.parquet
# /kaggle/input/bengaliai-cv19/train_image_data_0.parquet
# /kaggle/input/bengaliai-cv19/sample_submission.csv
# /kaggle/input/bengaliai-cv19/train.csv
# /kaggle/input/bengaliai-cv19/class_map.csv
# /kaggle/input/bengaliai-cv19/train_image_data_1.parquet
# /kaggle/input/bengaliai-cv19/train_image_data_2.parquet
# /kaggle/input/bengaliai-cv19/test_image_data_2.parquet
# /kaggle/input/bengaliai-cv19/test_image_data_1.parquet
# /kaggle/input/bengaliai-cv19/test_image_data_3.parquet
# /kaggle/input/bengaliai-cv19/test_image_data_0.parquet

# %%
train_df_ = pd.read_csv('/kaggle/input/bengaliai-cv19/train.csv')
test_df_ = pd.read_csv('/kaggle/input/bengaliai-cv19/test.csv')
class_map_df = pd.read_csv('/kaggle/input/bengaliai-cv19/class_map.csv')
sample_sub_df = pd.read_csv('/kaggle/input/bengaliai-cv19/sample_submission.csv')

# %%
train_df_.head()
# Out:
#   image_id  grapheme_root  vowel_diacritic  consonant_diacritic grapheme
# 0  Train_0             15                9                    5   ক্ট্রো
# 1  Train_1            159                0                    0        হ
# 2  Train_2             22                3                    5     খ্রী
# 3  Train_3             53                2                    2     র্টি
# 4  Train_4             71                9                    5     থ্রো

# %%
test_df_.head()
# Out:
#                        row_id image_id            component
# 0  Test_0_consonant_diacritic   Test_0  consonant_diacritic
# 1        Test_0_grapheme_root   Test_0        grapheme_root
# 2      Test_0_vowel_diacritic   Test_0      vowel_diacritic
# 3  Test_1_consonant_diacritic   Test_1  consonant_diacritic
# 4        Test_1_grapheme_root   Test_1        grapheme_root

# %%
sample_sub_df.head()
# Out:
#                        row_id  target
# 0  Test_0_consonant_diacritic       0
# 1        Test_0_grapheme_root       0
# 2      Test_0_vowel_diacritic       0
# 3  Test_1_consonant_diacritic       0
# 4        Test_1_grapheme_root       0

# %%
class_map_df.head()
# Out:
#   component_type  label component
# 0  grapheme_root      0         ং
# 1  grapheme_root      1         ঃ
# 2  grapheme_root      2         অ
# 3  grapheme_root      3         আ
# 4  grapheme_root      4         ই

# %%
print(f'Size of training data: {train_df_.shape}')
print(f'Size of test data: {test_df_.shape}')
print(f'Size of class map: {class_map_df.shape}')
# Out:
# Size of training data: (200840, 5)
# Size of test data: (36, 3)
# Size of class map: (186, 3)

# %% [markdown]
# ## Exploratory Data Analysis
# Exploratory data analysis (EDA) is an approach to analyzing data sets to summarize their main characteristics, often with visual methods.

# %%
HEIGHT = 236
WIDTH = 236

def get_n(df, field, n, top=True):
    top_graphemes = df.groupby([field]).size().reset_index(name='counts')['counts'].sort_values(ascending=not top)[:n]
    top_grapheme_roots = top_graphemes.index
    top_grapheme_counts = top_graphemes.values
    top_graphemes = class_map_df[class_map_df['component_type'] == field].reset_index().iloc[top_grapheme_roots]
    top_graphemes.drop(['component_type', 'label'], axis=1, inplace=True)
    top_graphemes.loc[:, 'count'] = top_grapheme_counts
    return top_graphemes

def image_from_char(char):
    image = Image.new('RGB', (WIDTH, HEIGHT))
    draw = ImageDraw.Draw(image)
    myfont = ImageFont.truetype('/kaggle/input/kalpurush-fonts/kalpurush-2.ttf', 120)
    w, h = draw.textsize(char, font=myfont)
    draw.text(((WIDTH - w) / 2,(HEIGHT - h) / 3), char, font=myfont)

    return image

# %% [markdown]
# ### Number of unique values

# %%
print(f'Number of unique grapheme roots: {train_df_["grapheme_root"].nunique()}')
print(f'Number of unique vowel diacritic: {train_df_["vowel_diacritic"].nunique()}')
print(f'Number of unique consonant diacritic: {train_df_["consonant_diacritic"].nunique()}')
# Out:
# Number of unique grapheme roots: 168
# Number of unique vowel diacritic: 11
# Number of unique consonant diacritic: 7

# %% [markdown]
# ### Most used top 10 Grapheme Roots in training set

# %%
top_10_roots = get_n(train_df_, 'grapheme_root', 10)
top_10_roots
# Out:
#      index component  count
# 72      72         দ   5736
# 64      64         ত   5596
# 13      13         ক   5420
# 107    107         ব   5321
# 23      23         গ   5149
# 96      96         প   4926
# 113    113         ভ   4395
# 147    147         স   4392
# 133    133         শ   4374
# 115    115         ম   4015

# %%
train_df_ = train_df_.drop(['grapheme'], axis=1, inplace=False)

# %%
train_df_[['grapheme_root', 'vowel_diacritic', 'consonant_diacritic']] = train_df_[['grapheme_root', 'vowel_diacritic', 'consonant_diacritic']].astype('uint8')

# %%
IMG_SIZE=64
N_CHANNELS=1

# %% [markdown]
# Let's apply some image processing (credits: [this kernel](https://www.kaggle.com/shawon10/bangla-graphemes-image-processing-deep-cnn)) while resizing the images, which will center crop the region of interest from the original images.

# %%
HEIGHT = 137
WIDTH = 236

def resize(df, size=64):
    resized = {}
    data = 255 - df.iloc[:, :].values.reshape(-1, HEIGHT, WIDTH).astype(np.uint8)
    for i in tqdm(range(len(df))):
        #normalize each image by its max val
        #img = 255 - df.loc[df.index[i]].values.reshape(137,236)
        img = (data[i]*(255.0/data[i].max())).astype(np.uint8)
        img = crop_resize(img)
        resized[df.index[i]] = img.reshape(size*size)
    
    resized = pd.DataFrame(resized).T
    return resized

# %%
def bbox(img):
    rows = np.any(img, axis=1)
    cols = np.any(img, axis=0)
    rmin, rmax = np.where(rows)[0][[0, -1]]
    cmin, cmax = np.where(cols)[0][[0, -1]]
    return rmin, rmax, cmin, cmax

def crop_resize(img0, size=64, pad=16):
    #crop a box around pixels large than the threshold 
    #some images contain line at the sides
    ymin,ymax,xmin,xmax = bbox(img0[5:-5,5:-5] > 80)
    #cropping may cut too much, so we need to add it back
    xmin = xmin - 13 if (xmin > 13) else 0
    ymin = ymin - 10 if (ymin > 10) else 0
    xmax = xmax + 13 if (xmax < WIDTH - 13) else WIDTH
    ymax = ymax + 10 if (ymax < HEIGHT - 10) else HEIGHT
    img = img0[ymin:ymax,xmin:xmax]
    #remove lo intensity pixels as noise
    img[img < 28] = 0
    lx, ly = xmax-xmin,ymax-ymin
    l = max(lx,ly) + pad
    #make sure that the aspect ratio is kept in rescaling
    img = np.pad(img, [((l-ly)//2,), ((l-lx)//2,)], mode='constant')
    return cv2.resize(img,(size,size))

# %%
def get_dummies(df):
    cols = []
    for col in df:
        cols.append(pd.get_dummies(df[col].astype(str)))
    return pd.concat(cols, axis=1)

# %% [markdown]
# ## Basic Model

# %%
inputs = Input(shape = (IMG_SIZE, IMG_SIZE, 1))

model = Conv2D(filters=32, kernel_size=(3, 3), padding='SAME', activation='relu', input_shape=(IMG_SIZE, IMG_SIZE, 1))(inputs)
model = Conv2D(filters=32, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=32, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=32, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Conv2D(filters=32, kernel_size=(5, 5), padding='SAME', activation='relu')(model)
model = Dropout(rate=0.3)(model)

model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Conv2D(filters=64, kernel_size=(5, 5), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = Dropout(rate=0.3)(model)

model = Conv2D(filters=128, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=128, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=128, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=128, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Conv2D(filters=128, kernel_size=(5, 5), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = Dropout(rate=0.3)(model)

model = Conv2D(filters=256, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=256, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=256, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=256, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Conv2D(filters=256, kernel_size=(5, 5), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = Dropout(rate=0.3)(model)

model = Flatten()(model)
model = Dense(1024, activation = "relu")(model)
model = Dropout(rate=0.3)(model)
dense = Dense(512, activation = "relu")(model)

head_root = Dense(168, activation = 'softmax')(dense)
head_vowel = Dense(11, activation = 'softmax')(dense)
head_consonant = Dense(7, activation = 'softmax')(dense)

model = Model(inputs=inputs, outputs=[head_root, head_vowel, head_consonant])

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 64, 64, 1)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 32)   320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 32)   9248        conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 32)   9248        conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 32)   9248        conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 64, 64, 32)   128         conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 32)   25632       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 32, 32, 32)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 64)   18496       dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 64)   36928       conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 64)   36928       conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 64)   36928       conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 64)   256         conv2d_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 64)   102464      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 16, 16, 64)   256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 16, 16, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 128)  73856       dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 128)  147584      conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 128)  147584      conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 128)  147584      conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 128)  512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 128)    0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 128)    409728      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 8, 8, 128)    512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 8, 8, 128)    0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 256)    295168      dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 8, 256)    590080      conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 8, 8, 256)    590080      conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 8, 8, 256)    590080      conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 8, 8, 256)    1024        conv2d_19[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 4, 4, 256)    0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 4, 4, 256)    1638656     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 4, 4, 256)    1024        conv2d_20[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 4, 4, 256)    0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 4096)         0           dropout_4[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         4195328     flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 1024)         0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512)          524800      dropout_5[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 168)          86184       dense_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 11)           5643        dense_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 7)            3591        dense_2[0][0]
# ==================================================================================================
# Total params: 9,735,098
# Trainable params: 9,733,242
# Non-trainable params: 1,856
# __________________________________________________________________________________________________

# %% [markdown]
# Let's visualize the 3-tailed (3 output) CNN by plotting it.

# %%
from keras.utils import plot_model
plot_model(model, to_file='model.png')

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Set a learning rate annealer. Learning rate will be half after 3 epochs if accuracy is not increased
learning_rate_reduction_root = ReduceLROnPlateau(monitor='dense_3_accuracy', 
                                            patience=3, 
                                            verbose=1,
                                            factor=0.5, 
                                            min_lr=0.00001)
learning_rate_reduction_vowel = ReduceLROnPlateau(monitor='dense_4_accuracy', 
                                            patience=3, 
                                            verbose=1,
                                            factor=0.5, 
                                            min_lr=0.00001)
learning_rate_reduction_consonant = ReduceLROnPlateau(monitor='dense_5_accuracy', 
                                            patience=3, 
                                            verbose=1,
                                            factor=0.5, 
                                            min_lr=0.00001)

# %%
batch_size = 256
epochs = 30

# %%
class MultiOutputDataGenerator(keras.preprocessing.image.ImageDataGenerator):

    def flow(self,
             x,
             y=None,
             batch_size=32,
             shuffle=True,
             sample_weight=None,
             seed=None,
             save_to_dir=None,
             save_prefix='',
             save_format='png',
             subset=None):

        targets = None
        target_lengths = {}
        ordered_outputs = []
        for output, target in y.items():
            if targets is None:
                targets = target
            else:
                targets = np.concatenate((targets, target), axis=1)
            target_lengths[output] = target.shape[1]
            ordered_outputs.append(output)


        for flowx, flowy in super().flow(x, targets, batch_size=batch_size,
                                         shuffle=shuffle):
            target_dict = {}
            i = 0
            for output in ordered_outputs:
                target_length = target_lengths[output]
                target_dict[output] = flowy[:, i: i + target_length]
                i += target_length

            yield flowx, target_dict

# %% [markdown]
# ### Training loop

# %%
histories = []
for i in range(4):
    train_df = pd.merge(pd.read_parquet(f'/kaggle/input/bengaliai-cv19/train_image_data_{i}.parquet'), train_df_, on='image_id').drop(['image_id'], axis=1)
    
    # Visualize few samples of current training dataset
    fig, ax = plt.subplots(nrows=3, ncols=4, figsize=(16, 8))
    count=0
    for row in ax:
        for col in row:
            col.imshow(resize(train_df.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic'], axis=1).iloc[[count]]).values.reshape(-1).reshape(IMG_SIZE, IMG_SIZE).astype(np.float64))
            count += 1
    plt.show()
    
    X_train = train_df.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic'], axis=1)
    X_train = resize(X_train)/255
    
    # CNN takes images in shape `(batch_size, h, w, channels)`, so reshape the images
    X_train = X_train.values.reshape(-1, IMG_SIZE, IMG_SIZE, N_CHANNELS)
    
    Y_train_root = pd.get_dummies(train_df['grapheme_root']).values
    Y_train_vowel = pd.get_dummies(train_df['vowel_diacritic']).values
    Y_train_consonant = pd.get_dummies(train_df['consonant_diacritic']).values

    print(f'Training images: {X_train.shape}')
    print(f'Training labels root: {Y_train_root.shape}')
    print(f'Training labels vowel: {Y_train_vowel.shape}')
    print(f'Training labels consonants: {Y_train_consonant.shape}')

    # Divide the data into training and validation set
    x_train, x_test, y_train_root, y_test_root, y_train_vowel, y_test_vowel, y_train_consonant, y_test_consonant = train_test_split(X_train, Y_train_root, Y_train_vowel, Y_train_consonant, test_size=0.08, random_state=666)
    del train_df
    del X_train
    del Y_train_root, Y_train_vowel, Y_train_consonant

    # Data augmentation for creating more training data
    datagen = MultiOutputDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=8,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.15, # Randomly zoom image 
        width_shift_range=0.15,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.15,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images


    # This will just calculate parameters required to augment the given data. This won't perform any augmentations
    datagen.fit(x_train)

    # Fit the model
    history = model.fit_generator(datagen.flow(x_train, {'dense_3': y_train_root, 'dense_4': y_train_vowel, 'dense_5': y_train_consonant}, batch_size=batch_size),
                              epochs = epochs, validation_data = (x_test, [y_test_root, y_test_vowel, y_test_consonant]), 
                              steps_per_epoch=x_train.shape[0] // batch_size, 
                              callbacks=[learning_rate_reduction_root, learning_rate_reduction_vowel, learning_rate_reduction_consonant])

    histories.append(history)
    
    # Delete to reduce memory usage
    del x_train
    del x_test
    del y_train_root
    del y_test_root
    del y_train_vowel
    del y_test_vowel
    del y_train_consonant
    del y_test_consonant
    gc.collect()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=50210.0), HTML(value='')))
# Training images: (50210, 64, 64, 1)
# Training labels root: (50210, 168)
# Training labels vowel: (50210, 11)
# Training labels consonants: (50210, 7)
# Epoch 1/30
# 180/180 [==============================] - 44s 247ms/step - loss: 7.6954 - dense_3_loss: 4.7636 - dense_4_loss: 1.7146 - dense_5_loss: 1.2173 - dense_3_accuracy: 0.0281 - dense_4_accuracy: 0.3769 - dense_5_accuracy: 0.6233 - val_loss: 6.6784 - val_dense_3_loss: 4.6372 - val_dense_4_loss: 1.0200 - val_dense_5_loss: 1.0222 - val_dense_3_accuracy: 0.0324 - val_dense_4_accuracy: 0.6266 - val_dense_5_accuracy: 0.6580
# Epoch 2/30
# 180/180 [==============================] - 36s 198ms/step - loss: 6.3353 - dense_3_loss: 4.5220 - dense_4_loss: 0.8839 - dense_5_loss: 0.9294 - dense_3_accuracy: 0.0367 - dense_4_accuracy: 0.6931 - dense_5_accuracy: 0.6760 - val_loss: 5.6347 - val_dense_3_loss: 4.2473 - val_dense_4_loss: 0.6229 - val_dense_5_loss: 0.7639 - val_dense_3_accuracy: 0.0515 - val_dense_4_accuracy: 0.7762 - val_dense_5_accuracy: 0.7329
# Epoch 3/30
# 180/180 [==============================] - 36s 200ms/step - loss: 5.5373 - dense_3_loss: 4.1652 - dense_4_loss: 0.6772 - dense_5_loss: 0.6949 - dense_3_accuracy: 0.0568 - dense_4_accuracy: 0.7680 - dense_5_accuracy: 0.7537 - val_loss: 4.7566 - val_dense_3_loss: 3.7888 - val_dense_4_loss: 0.4821 - val_dense_5_loss: 0.4884 - val_dense_3_accuracy: 0.0876 - val_dense_4_accuracy: 0.8332 - val_dense_5_accuracy: 0.8362
# Epoch 4/30
# 180/180 [==============================] - 35s 194ms/step - loss: 4.8100 - dense_3_loss: 3.7249 - dense_4_loss: 0.5744 - dense_5_loss: 0.5108 - dense_3_accuracy: 0.0933 - dense_4_accuracy: 0.8073 - dense_5_accuracy: 0.8277 - val_loss: 3.9589 - val_dense_3_loss: 3.2496 - val_dense_4_loss: 0.3802 - val_dense_5_loss: 0.3313 - val_dense_3_accuracy: 0.1536 - val_dense_4_accuracy: 0.8730 - val_dense_5_accuracy: 0.8982
# Epoch 5/30
# 180/180 [==============================] - 36s 199ms/step - loss: 4.1374 - dense_3_loss: 3.2299 - dense_4_loss: 0.4971 - dense_5_loss: 0.4104 - dense_3_accuracy: 0.1546 - dense_4_accuracy: 0.8344 - dense_5_accuracy: 0.8672 - val_loss: 3.2166 - val_dense_3_loss: 2.6096 - val_dense_4_loss: 0.3356 - val_dense_5_loss: 0.2717 - val_dense_3_accuracy: 0.2512 - val_dense_4_accuracy: 0.8925 - val_dense_5_accuracy: 0.9176
# Epoch 6/30
# 180/180 [==============================] - 35s 194ms/step - loss: 3.4356 - dense_3_loss: 2.6613 - dense_4_loss: 0.4272 - dense_5_loss: 0.3471 - dense_3_accuracy: 0.2533 - dense_4_accuracy: 0.8597 - dense_5_accuracy: 0.8909 - val_loss: 2.5328 - val_dense_3_loss: 2.0545 - val_dense_4_loss: 0.2760 - val_dense_5_loss: 0.2023 - val_dense_3_accuracy: 0.3742 - val_dense_4_accuracy: 0.9121 - val_dense_5_accuracy: 0.9412
# Epoch 7/30
# 180/180 [==============================] - 36s 199ms/step - loss: 2.9408 - dense_3_loss: 2.2334 - dense_4_loss: 0.3993 - dense_5_loss: 0.3082 - dense_3_accuracy: 0.3499 - dense_4_accuracy: 0.8701 - dense_5_accuracy: 0.9024 - val_loss: 2.0915 - val_dense_3_loss: 1.6584 - val_dense_4_loss: 0.2481 - val_dense_5_loss: 0.1854 - val_dense_3_accuracy: 0.4887 - val_dense_4_accuracy: 0.9188 - val_dense_5_accuracy: 0.9412
# Epoch 8/30
# 180/180 [==============================] - 35s 197ms/step - loss: 2.4628 - dense_3_loss: 1.8382 - dense_4_loss: 0.3525 - dense_5_loss: 0.2721 - dense_3_accuracy: 0.4489 - dense_4_accuracy: 0.8862 - dense_5_accuracy: 0.9148 - val_loss: 1.6699 - val_dense_3_loss: 1.2900 - val_dense_4_loss: 0.2103 - val_dense_5_loss: 0.1691 - val_dense_3_accuracy: 0.5940 - val_dense_4_accuracy: 0.9320 - val_dense_5_accuracy: 0.9485
# Epoch 9/30
# 180/180 [==============================] - 35s 194ms/step - loss: 2.1388 - dense_3_loss: 1.5721 - dense_4_loss: 0.3209 - dense_5_loss: 0.2459 - dense_3_accuracy: 0.5245 - dense_4_accuracy: 0.8995 - dense_5_accuracy: 0.9227 - val_loss: 1.5418 - val_dense_3_loss: 1.2010 - val_dense_4_loss: 0.1900 - val_dense_5_loss: 0.1525 - val_dense_3_accuracy: 0.6360 - val_dense_4_accuracy: 0.9425 - val_dense_5_accuracy: 0.9564
# Epoch 10/30
# 180/180 [==============================] - 36s 201ms/step - loss: 1.8959 - dense_3_loss: 1.3742 - dense_4_loss: 0.2910 - dense_5_loss: 0.2307 - dense_3_accuracy: 0.5856 - dense_4_accuracy: 0.9095 - dense_5_accuracy: 0.9298 - val_loss: 1.3492 - val_dense_3_loss: 1.0316 - val_dense_4_loss: 0.1802 - val_dense_5_loss: 0.1387 - val_dense_3_accuracy: 0.6766 - val_dense_4_accuracy: 0.9457 - val_dense_5_accuracy: 0.9599
# Epoch 11/30
# 180/180 [==============================] - 35s 193ms/step - loss: 1.6717 - dense_3_loss: 1.2028 - dense_4_loss: 0.2626 - dense_5_loss: 0.2063 - dense_3_accuracy: 0.6365 - dense_4_accuracy: 0.9195 - dense_5_accuracy: 0.9375 - val_loss: 1.0856 - val_dense_3_loss: 0.7987 - val_dense_4_loss: 0.1608 - val_dense_5_loss: 0.1282 - val_dense_3_accuracy: 0.7558 - val_dense_4_accuracy: 0.9539 - val_dense_5_accuracy: 0.9642
# Epoch 12/30
# 180/180 [==============================] - 36s 199ms/step - loss: 1.4924 - dense_3_loss: 1.0492 - dense_4_loss: 0.2436 - dense_5_loss: 0.1996 - dense_3_accuracy: 0.6830 - dense_4_accuracy: 0.9259 - dense_5_accuracy: 0.9392 - val_loss: 1.0331 - val_dense_3_loss: 0.7591 - val_dense_4_loss: 0.1474 - val_dense_5_loss: 0.1285 - val_dense_3_accuracy: 0.7847 - val_dense_4_accuracy: 0.9604 - val_dense_5_accuracy: 0.9609
# Epoch 13/30
# 180/180 [==============================] - 35s 196ms/step - loss: 1.3452 - dense_3_loss: 0.9417 - dense_4_loss: 0.2232 - dense_5_loss: 0.1804 - dense_3_accuracy: 0.7176 - dense_4_accuracy: 0.9331 - dense_5_accuracy: 0.9456 - val_loss: 0.9110 - val_dense_3_loss: 0.6583 - val_dense_4_loss: 0.1278 - val_dense_5_loss: 0.1289 - val_dense_3_accuracy: 0.8066 - val_dense_4_accuracy: 0.9699 - val_dense_5_accuracy: 0.9642
# Epoch 14/30
# 180/180 [==============================] - 35s 196ms/step - loss: 1.2141 - dense_3_loss: 0.8456 - dense_4_loss: 0.2024 - dense_5_loss: 0.1661 - dense_3_accuracy: 0.7492 - dense_4_accuracy: 0.9400 - dense_5_accuracy: 0.9503 - val_loss: 0.8140 - val_dense_3_loss: 0.5719 - val_dense_4_loss: 0.1183 - val_dense_5_loss: 0.1243 - val_dense_3_accuracy: 0.8245 - val_dense_4_accuracy: 0.9684 - val_dense_5_accuracy: 0.9681
# Epoch 15/30
# 180/180 [==============================] - 36s 200ms/step - loss: 1.1276 - dense_3_loss: 0.7719 - dense_4_loss: 0.1922 - dense_5_loss: 0.1635 - dense_3_accuracy: 0.7694 - dense_4_accuracy: 0.9431 - dense_5_accuracy: 0.9508 - val_loss: 0.7789 - val_dense_3_loss: 0.5400 - val_dense_4_loss: 0.1332 - val_dense_5_loss: 0.1081 - val_dense_3_accuracy: 0.8439 - val_dense_4_accuracy: 0.9661 - val_dense_5_accuracy: 0.9691
# Epoch 16/30
# 180/180 [==============================] - 35s 193ms/step - loss: 1.0343 - dense_3_loss: 0.6984 - dense_4_loss: 0.1874 - dense_5_loss: 0.1485 - dense_3_accuracy: 0.7929 - dense_4_accuracy: 0.9449 - dense_5_accuracy: 0.9552 - val_loss: 0.7030 - val_dense_3_loss: 0.4896 - val_dense_4_loss: 0.1082 - val_dense_5_loss: 0.1077 - val_dense_3_accuracy: 0.8603 - val_dense_4_accuracy: 0.9736 - val_dense_5_accuracy: 0.9721
# Epoch 17/30
# 180/180 [==============================] - 36s 198ms/step - loss: 0.9637 - dense_3_loss: 0.6489 - dense_4_loss: 0.1725 - dense_5_loss: 0.1423 - dense_3_accuracy: 0.8106 - dense_4_accuracy: 0.9498 - dense_5_accuracy: 0.9576 - val_loss: 0.7384 - val_dense_3_loss: 0.4950 - val_dense_4_loss: 0.1199 - val_dense_5_loss: 0.1232 - val_dense_3_accuracy: 0.8584 - val_dense_4_accuracy: 0.9681 - val_dense_5_accuracy: 0.9669
# Epoch 18/30
# 180/180 [==============================] - 35s 193ms/step - loss: 0.9195 - dense_3_loss: 0.6136 - dense_4_loss: 0.1694 - dense_5_loss: 0.1365 - dense_3_accuracy: 0.8194 - dense_4_accuracy: 0.9524 - dense_5_accuracy: 0.9593 - val_loss: 0.6679 - val_dense_3_loss: 0.4644 - val_dense_4_loss: 0.1118 - val_dense_5_loss: 0.0927 - val_dense_3_accuracy: 0.8696 - val_dense_4_accuracy: 0.9714 - val_dense_5_accuracy: 0.9741
# Epoch 19/30
# 180/180 [==============================] - 36s 197ms/step - loss: 0.8465 - dense_3_loss: 0.5656 - dense_4_loss: 0.1539 - dense_5_loss: 0.1271 - dense_3_accuracy: 0.8329 - dense_4_accuracy: 0.9557 - dense_5_accuracy: 0.9623 - val_loss: 0.6589 - val_dense_3_loss: 0.4514 - val_dense_4_loss: 0.1133 - val_dense_5_loss: 0.0950 - val_dense_3_accuracy: 0.8763 - val_dense_4_accuracy: 0.9701 - val_dense_5_accuracy: 0.9761
# Epoch 20/30
# 180/180 [==============================] - 35s 197ms/step - loss: 0.8133 - dense_3_loss: 0.5378 - dense_4_loss: 0.1529 - dense_5_loss: 0.1227 - dense_3_accuracy: 0.8428 - dense_4_accuracy: 0.9570 - dense_5_accuracy: 0.9623 - val_loss: 0.6295 - val_dense_3_loss: 0.4252 - val_dense_4_loss: 0.1086 - val_dense_5_loss: 0.0978 - val_dense_3_accuracy: 0.8805 - val_dense_4_accuracy: 0.9746 - val_dense_5_accuracy: 0.9734
# Epoch 21/30
# 180/180 [==============================] - 35s 192ms/step - loss: 0.7793 - dense_3_loss: 0.5088 - dense_4_loss: 0.1496 - dense_5_loss: 0.1209 - dense_3_accuracy: 0.8495 - dense_4_accuracy: 0.9573 - dense_5_accuracy: 0.9639 - val_loss: 0.5998 - val_dense_3_loss: 0.4109 - val_dense_4_loss: 0.0989 - val_dense_5_loss: 0.0918 - val_dense_3_accuracy: 0.8857 - val_dense_4_accuracy: 0.9726 - val_dense_5_accuracy: 0.9744
# Epoch 22/30
# 180/180 [==============================] - 35s 197ms/step - loss: 0.7503 - dense_3_loss: 0.4919 - dense_4_loss: 0.1380 - dense_5_loss: 0.1204 - dense_3_accuracy: 0.8554 - dense_4_accuracy: 0.9608 - dense_5_accuracy: 0.9647 - val_loss: 0.5885 - val_dense_3_loss: 0.4026 - val_dense_4_loss: 0.0991 - val_dense_5_loss: 0.0868 - val_dense_3_accuracy: 0.8907 - val_dense_4_accuracy: 0.9754 - val_dense_5_accuracy: 0.9756
# Epoch 23/30
# 180/180 [==============================] - 35s 192ms/step - loss: 0.6956 - dense_3_loss: 0.4602 - dense_4_loss: 0.1285 - dense_5_loss: 0.1069 - dense_3_accuracy: 0.8640 - dense_4_accuracy: 0.9634 - dense_5_accuracy: 0.9669 - val_loss: 0.6102 - val_dense_3_loss: 0.4040 - val_dense_4_loss: 0.1085 - val_dense_5_loss: 0.0971 - val_dense_3_accuracy: 0.8865 - val_dense_4_accuracy: 0.9744 - val_dense_5_accuracy: 0.9736
# Epoch 24/30
# 180/180 [==============================] - 35s 197ms/step - loss: 0.6870 - dense_3_loss: 0.4453 - dense_4_loss: 0.1314 - dense_5_loss: 0.1103 - dense_3_accuracy: 0.8691 - dense_4_accuracy: 0.9633 - dense_5_accuracy: 0.9665 - val_loss: 0.5762 - val_dense_3_loss: 0.3951 - val_dense_4_loss: 0.0906 - val_dense_5_loss: 0.0887 - val_dense_3_accuracy: 0.9007 - val_dense_4_accuracy: 0.9768 - val_dense_5_accuracy: 0.9754
# Epoch 25/30
# 180/180 [==============================] - 35s 196ms/step - loss: 0.6675 - dense_3_loss: 0.4325 - dense_4_loss: 0.1282 - dense_5_loss: 0.1068 - dense_3_accuracy: 0.8728 - dense_4_accuracy: 0.9644 - dense_5_accuracy: 0.9688 - val_loss: 0.5720 - val_dense_3_loss: 0.3840 - val_dense_4_loss: 0.0970 - val_dense_5_loss: 0.0905 - val_dense_3_accuracy: 0.8979 - val_dense_4_accuracy: 0.9766 - val_dense_5_accuracy: 0.9759
# Epoch 26/30
# 180/180 [==============================] - 35s 195ms/step - loss: 0.6281 - dense_3_loss: 0.4082 - dense_4_loss: 0.1199 - dense_5_loss: 0.1001 - dense_3_accuracy: 0.8790 - dense_4_accuracy: 0.9659 - dense_5_accuracy: 0.9704 - val_loss: 0.5531 - val_dense_3_loss: 0.3667 - val_dense_4_loss: 0.1027 - val_dense_5_loss: 0.0846 - val_dense_3_accuracy: 0.9037 - val_dense_4_accuracy: 0.9759 - val_dense_5_accuracy: 0.9781
# Epoch 27/30
# 180/180 [==============================] - 36s 198ms/step - loss: 0.6158 - dense_3_loss: 0.3965 - dense_4_loss: 0.1190 - dense_5_loss: 0.1004 - dense_3_accuracy: 0.8818 - dense_4_accuracy: 0.9662 - dense_5_accuracy: 0.9706 - val_loss: 0.5354 - val_dense_3_loss: 0.3591 - val_dense_4_loss: 0.0926 - val_dense_5_loss: 0.0834 - val_dense_3_accuracy: 0.9061 - val_dense_4_accuracy: 0.9768 - val_dense_5_accuracy: 0.9759
# Epoch 28/30
# 180/180 [==============================] - 35s 194ms/step - loss: 0.5887 - dense_3_loss: 0.3787 - dense_4_loss: 0.1160 - dense_5_loss: 0.0940 - dense_3_accuracy: 0.8888 - dense_4_accuracy: 0.9672 - dense_5_accuracy: 0.9717 - val_loss: 0.5522 - val_dense_3_loss: 0.3646 - val_dense_4_loss: 0.1027 - val_dense_5_loss: 0.0858 - val_dense_3_accuracy: 0.9089 - val_dense_4_accuracy: 0.9759 - val_dense_5_accuracy: 0.9778
# Epoch 29/30
# 180/180 [==============================] - 36s 198ms/step - loss: 0.5705 - dense_3_loss: 0.3653 - dense_4_loss: 0.1134 - dense_5_loss: 0.0917 - dense_3_accuracy: 0.8913 - dense_4_accuracy: 0.9691 - dense_5_accuracy: 0.9722 - val_loss: 0.5348 - val_dense_3_loss: 0.3518 - val_dense_4_loss: 0.1001 - val_dense_5_loss: 0.0839 - val_dense_3_accuracy: 0.9076 - val_dense_4_accuracy: 0.9759 - val_dense_5_accuracy: 0.9761
# Epoch 30/30
# 180/180 [==============================] - 35s 195ms/step - loss: 0.5522 - dense_3_loss: 0.3556 - dense_4_loss: 0.1079 - dense_5_loss: 0.0887 - dense_3_accuracy: 0.8953 - dense_4_accuracy: 0.9702 - dense_5_accuracy: 0.9736 - val_loss: 0.5408 - val_dense_3_loss: 0.3541 - val_dense_4_loss: 0.1002 - val_dense_5_loss: 0.0872 - val_dense_3_accuracy: 0.9094 - val_dense_4_accuracy: 0.9771 - val_dense_5_accuracy: 0.9768
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=50210.0), HTML(value='')))
# Training images: (50210, 64, 64, 1)
# Training labels root: (50210, 168)
# Training labels vowel: (50210, 11)
# Training labels consonants: (50210, 7)
# Epoch 1/30
# 180/180 [==============================] - 36s 201ms/step - loss: 0.8278 - dense_3_loss: 0.5342 - dense_4_loss: 0.1588 - dense_5_loss: 0.1347 - dense_3_accuracy: 0.8556 - dense_4_accuracy: 0.9585 - dense_5_accuracy: 0.9620 - val_loss: 0.5693 - val_dense_3_loss: 0.3683 - val_dense_4_loss: 0.1020 - val_dense_5_loss: 0.0991 - val_dense_3_accuracy: 0.8949 - val_dense_4_accuracy: 0.9734 - val_dense_5_accuracy: 0.9731
# Epoch 2/30
# 180/180 [==============================] - 35s 195ms/step - loss: 0.7151 - dense_3_loss: 0.4562 - dense_4_loss: 0.1410 - dense_5_loss: 0.1178 - dense_3_accuracy: 0.8738 - dense_4_accuracy: 0.9629 - dense_5_accuracy: 0.9653 - val_loss: 0.5268 - val_dense_3_loss: 0.3351 - val_dense_4_loss: 0.1000 - val_dense_5_loss: 0.0896 - val_dense_3_accuracy: 0.9039 - val_dense_4_accuracy: 0.9744 - val_dense_5_accuracy: 0.9756
# Epoch 3/30
# 180/180 [==============================] - 36s 198ms/step - loss: 0.6586 - dense_3_loss: 0.4176 - dense_4_loss: 0.1296 - dense_5_loss: 0.1114 - dense_3_accuracy: 0.8816 - dense_4_accuracy: 0.9648 - dense_5_accuracy: 0.9678 - val_loss: 0.4890 - val_dense_3_loss: 0.3090 - val_dense_4_loss: 0.0959 - val_dense_5_loss: 0.0825 - val_dense_3_accuracy: 0.9166 - val_dense_4_accuracy: 0.9759 - val_dense_5_accuracy: 0.9764
# Epoch 4/30
# 180/180 [==============================] - 35s 193ms/step - loss: 0.6233 - dense_3_loss: 0.4031 - dense_4_loss: 0.1190 - dense_5_loss: 0.1013 - dense_3_accuracy: 0.8858 - dense_4_accuracy: 0.9669 - dense_5_accuracy: 0.9703 - val_loss: 0.4714 - val_dense_3_loss: 0.3010 - val_dense_4_loss: 0.0886 - val_dense_5_loss: 0.0817 - val_dense_3_accuracy: 0.9156 - val_dense_4_accuracy: 0.9764 - val_dense_5_accuracy: 0.9759
# Epoch 5/30
# 180/180 [==============================] - 35s 197ms/step - loss: 0.6080 - dense_3_loss: 0.3847 - dense_4_loss: 0.1239 - dense_5_loss: 0.0994 - dense_3_accuracy: 0.8903 - dense_4_accuracy: 0.9665 - dense_5_accuracy: 0.9708 - val_loss: 0.4809 - val_dense_3_loss: 0.2971 - val_dense_4_loss: 0.0932 - val_dense_5_loss: 0.0902 - val_dense_3_accuracy: 0.9188 - val_dense_4_accuracy: 0.9761 - val_dense_5_accuracy: 0.9773
# Epoch 6/30
# 180/180 [==============================] - 35s 192ms/step - loss: 0.5683 - dense_3_loss: 0.3573 - dense_4_loss: 0.1128 - dense_5_loss: 0.0981 - dense_3_accuracy: 0.8960 - dense_4_accuracy: 0.9690 - dense_5_accuracy: 0.9711 - val_loss: 0.4731 - val_dense_3_loss: 0.3017 - val_dense_4_loss: 0.0856 - val_dense_5_loss: 0.0861 - val_dense_3_accuracy: 0.9144 - val_dense_4_accuracy: 0.9778 - val_dense_5_accuracy: 0.9773
# Epoch 7/30
# 180/180 [==============================] - 35s 197ms/step - loss: 0.5426 - dense_3_loss: 0.3439 - dense_4_loss: 0.1050 - dense_5_loss: 0.0937 - dense_3_accuracy: 0.9005 - dense_4_accuracy: 0.9705 - dense_5_accuracy: 0.9723 - val_loss: 0.5487 - val_dense_3_loss: 0.3484 - val_dense_4_loss: 0.0987 - val_dense_5_loss: 0.1008 - val_dense_3_accuracy: 0.9052 - val_dense_4_accuracy: 0.9754 - val_dense_5_accuracy: 0.9719
# Epoch 8/30
# 180/180 [==============================] - 36s 198ms/step - loss: 0.5279 - dense_3_loss: 0.3280 - dense_4_loss: 0.1081 - dense_5_loss: 0.0918 - dense_3_accuracy: 0.9041 - dense_4_accuracy: 0.9709 - dense_5_accuracy: 0.9728 - val_loss: 0.5465 - val_dense_3_loss: 0.3473 - val_dense_4_loss: 0.1029 - val_dense_5_loss: 0.0972 - val_dense_3_accuracy: 0.9071 - val_dense_4_accuracy: 0.9736 - val_dense_5_accuracy: 0.9726
# Epoch 9/30
# 180/180 [==============================] - 35s 195ms/step - loss: 0.5060 - dense_3_loss: 0.3183 - dense_4_loss: 0.1020 - dense_5_loss: 0.0857 - dense_3_accuracy: 0.9074 - dense_4_accuracy: 0.9726 - dense_5_accuracy: 0.9744 - val_loss: 0.4827 - val_dense_3_loss: 0.2941 - val_dense_4_loss: 0.0953 - val_dense_5_loss: 0.0903 - val_dense_3_accuracy: 0.9223 - val_dense_4_accuracy: 0.9771 - val_dense_5_accuracy: 0.9759
# Epoch 10/30
# 180/180 [==============================] - 36s 201ms/step - loss: 0.3916 - dense_3_loss: 0.2374 - dense_4_loss: 0.0854 - dense_5_loss: 0.0688 - dense_3_accuracy: 0.9286 - dense_4_accuracy: 0.9768 - dense_5_accuracy: 0.9798 - val_loss: 0.4533 - val_dense_3_loss: 0.2805 - val_dense_4_loss: 0.0859 - val_dense_5_loss: 0.0861 - val_dense_3_accuracy: 0.9256 - val_dense_4_accuracy: 0.9803 - val_dense_5_accuracy: 0.9768
# Epoch 21/30
# 180/180 [==============================] - 35s 195ms/step - loss: 0.3858 - dense_3_loss: 0.2348 - dense_4_loss: 0.0843 - dense_5_loss: 0.0667 - dense_3_accuracy: 0.9297 - dense_4_accuracy: 0.9770 - dense_5_accuracy: 0.9799 - val_loss: 0.4544 - val_dense_3_loss: 0.2844 - val_dense_4_loss: 0.0834 - val_dense_5_loss: 0.0857 - val_dense_3_accuracy: 0.9248 - val_dense_4_accuracy: 0.9788 - val_dense_5_accuracy: 0.9778
# Epoch 22/30
# 180/180 [==============================] - 36s 201ms/step - loss: 0.3766 - dense_3_loss: 0.2290 - dense_4_loss: 0.0809 - dense_5_loss: 0.0668 - dense_3_accuracy: 0.9313 - dense_4_accuracy: 0.9774 - dense_5_accuracy: 0.9803 - val_loss: 0.4600 - val_dense_3_loss: 0.2865 - val_dense_4_loss: 0.0878 - val_dense_5_loss: 0.0845 - val_dense_3_accuracy: 0.9283 - val_dense_4_accuracy: 0.9781 - val_dense_5_accuracy: 0.9771
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 23/30
# 180/180 [==============================] - 36s 198ms/step - loss: 0.2806 - dense_3_loss: 0.1699 - dense_4_loss: 0.0604 - dense_5_loss: 0.0503 - dense_3_accuracy: 0.9471 - dense_4_accuracy: 0.9834 - dense_5_accuracy: 0.9843 - val_loss: 0.4368 - val_dense_3_loss: 0.2587 - val_dense_4_loss: 0.0862 - val_dense_5_loss: 0.0905 - val_dense_3_accuracy: 0.9363 - val_dense_4_accuracy: 0.9798 - val_dense_5_accuracy: 0.9781
# Epoch 24/30
# 180/180 [==============================] - 35s 197ms/step - loss: 0.2502 - dense_3_loss: 0.1509 - dense_4_loss: 0.0556 - dense_5_loss: 0.0437 - dense_3_accuracy: 0.9542 - dense_4_accuracy: 0.9852 - dense_5_accuracy: 0.9872 - val_loss: 0.4133 - val_dense_3_loss: 0.2535 - val_dense_4_loss: 0.0813 - val_dense_5_loss: 0.0798 - val_dense_3_accuracy: 0.9375 - val_dense_4_accuracy: 0.9808 - val_dense_5_accuracy: 0.9791
# Epoch 25/30
# 180/180 [==============================] - 36s 200ms/step - loss: 0.2431 - dense_3_loss: 0.1469 - dense_4_loss: 0.0527 - dense_5_loss: 0.0435 - dense_3_accuracy: 0.9545 - dense_4_accuracy: 0.9851 - dense_5_accuracy: 0.9867 - val_loss: 0.4366 - val_dense_3_loss: 0.2737 - val_dense_4_loss: 0.0827 - val_dense_5_loss: 0.0833 - val_dense_3_accuracy: 0.9313 - val_dense_4_accuracy: 0.9811 - val_dense_5_accuracy: 0.9798
# Epoch 26/30
# 180/180 [==============================] - 35s 196ms/step - loss: 0.2399 - dense_3_loss: 0.1437 - dense_4_loss: 0.0528 - dense_5_loss: 0.0434 - dense_3_accuracy: 0.9540 - dense_4_accuracy: 0.9858 - dense_5_accuracy: 0.9868 - val_loss: 0.4206 - val_dense_3_loss: 0.2588 - val_dense_4_loss: 0.0874 - val_dense_5_loss: 0.0761 - val_dense_3_accuracy: 0.9355 - val_dense_4_accuracy: 0.9801 - val_dense_5_accuracy: 0.9806
# Epoch 27/30
# 180/180 [==============================] - 36s 199ms/step - loss: 0.2338 - dense_3_loss: 0.1390 - dense_4_loss: 0.0522 - dense_5_loss: 0.0426 - dense_3_accuracy: 0.9567 - dense_4_accuracy: 0.9855 - dense_5_accuracy: 0.9868 - val_loss: 0.4443 - val_dense_3_loss: 0.2857 - val_dense_4_loss: 0.0838 - val_dense_5_loss: 0.0774 - val_dense_3_accuracy: 0.9315 - val_dense_4_accuracy: 0.9793 - val_dense_5_accuracy: 0.9788
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 28/30
# 180/180 [==============================] - 36s 201ms/step - loss: 0.2248 - dense_3_loss: 0.1379 - dense_4_loss: 0.0465 - dense_5_loss: 0.0405 - dense_3_accuracy: 0.9570 - dense_4_accuracy: 0.9874 - dense_5_accuracy: 0.9878 - val_loss: 0.3644 - val_dense_3_loss: 0.2374 - val_dense_4_loss: 0.0588 - val_dense_5_loss: 0.0707 - val_dense_3_accuracy: 0.9477 - val_dense_4_accuracy: 0.9863 - val_dense_5_accuracy: 0.9833
# Epoch 17/30
# 180/180 [==============================] - 35s 197ms/step - loss: 0.2167 - dense_3_loss: 0.1314 - dense_4_loss: 0.0456 - dense_5_loss: 0.0397 - dense_3_accuracy: 0.9590 - dense_4_accuracy: 0.9874 - dense_5_accuracy: 0.9885 - val_loss: 0.3645 - val_dense_3_loss: 0.2322 - val_dense_4_loss: 0.0618 - val_dense_5_loss: 0.0714 - val_dense_3_accuracy: 0.9465 - val_dense_4_accuracy: 0.9858 - val_dense_5_accuracy: 0.9831
# Epoch 18/30
# 180/180 [==============================] - 36s 200ms/step - loss: 0.2121 - dense_3_loss: 0.1288 - dense_4_loss: 0.0459 - dense_5_loss: 0.0375 - dense_3_accuracy: 0.9596 - dense_4_accuracy: 0.9873 - dense_5_accuracy: 0.9887 - val_loss: 0.3533 - val_dense_3_loss: 0.2289 - val_dense_4_loss: 0.0567 - val_dense_5_loss: 0.0698 - val_dense_3_accuracy: 0.9512 - val_dense_4_accuracy: 0.9863 - val_dense_5_accuracy: 0.9838
# Epoch 19/30
# 180/180 [==============================] - 36s 200ms/step - loss: 0.2092 - dense_3_loss: 0.1285 - dense_4_loss: 0.0430 - dense_5_loss: 0.0377 - dense_3_accuracy: 0.9595 - dense_4_accuracy: 0.9884 - dense_5_accuracy: 0.9886 - val_loss: 0.3548 - val_dense_3_loss: 0.2314 - val_dense_4_loss: 0.0553 - val_dense_5_loss: 0.0698 - val_dense_3_accuracy: 0.9497 - val_dense_4_accuracy: 0.9861 - val_dense_5_accuracy: 0.9823
# Epoch 20/30
# 180/180 [==============================] - 36s 199ms/step - loss: 0.1986 - dense_3_loss: 0.1216 - dense_4_loss: 0.0413 - dense_5_loss: 0.0357 - dense_3_accuracy: 0.9619 - dense_4_accuracy: 0.9889 - dense_5_accuracy: 0.9894 - val_loss: 0.3475 - val_dense_3_loss: 0.2223 - val_dense_4_loss: 0.0574 - val_dense_5_loss: 0.0703 - val_dense_3_accuracy: 0.9492 - val_dense_4_accuracy: 0.9888 - val_dense_5_accuracy: 0.9823
# Epoch 21/30
# 180/180 [==============================] - 36s 201ms/step - loss: 0.2030 - dense_3_loss: 0.1216 - dense_4_loss: 0.0459 - dense_5_loss: 0.0356 - dense_3_accuracy: 0.9612 - dense_4_accuracy: 0.9876 - dense_5_accuracy: 0.9891 - val_loss: 0.3643 - val_dense_3_loss: 0.2324 - val_dense_4_loss: 0.0600 - val_dense_5_loss: 0.0743 - val_dense_3_accuracy: 0.9500 - val_dense_4_accuracy: 0.9863 - val_dense_5_accuracy: 0.9816
# Epoch 22/30
# 180/180 [==============================] - 35s 197ms/step - loss: 0.1969 - dense_3_loss: 0.1186 - dense_4_loss: 0.0429 - dense_5_loss: 0.0355 - dense_3_accuracy: 0.9626 - dense_4_accuracy: 0.9879 - dense_5_accuracy: 0.9892 - val_loss: 0.3577 - val_dense_3_loss: 0.2341 - val_dense_4_loss: 0.0592 - val_dense_5_loss: 0.0670 - val_dense_3_accuracy: 0.9500 - val_dense_4_accuracy: 0.9861 - val_dense_5_accuracy: 0.9826
# Epoch 23/30
# 180/180 [==============================] - 36s 202ms/step - loss: 0.1963 - dense_3_loss: 0.1190 - dense_4_loss: 0.0428 - dense_5_loss: 0.0345 - dense_3_accuracy: 0.9624 - dense_4_accuracy: 0.9875 - dense_5_accuracy: 0.9898 - val_loss: 0.3657 - val_dense_3_loss: 0.2325 - val_dense_4_loss: 0.0605 - val_dense_5_loss: 0.0748 - val_dense_3_accuracy: 0.9490 - val_dense_4_accuracy: 0.9866 - val_dense_5_accuracy: 0.9823
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 24/30
# 180/180 [==============================] - 36s 201ms/step - loss: 0.1863 - dense_3_loss: 0.1116 - dense_4_loss: 0.0408 - dense_5_loss: 0.0338 - dense_3_accuracy: 0.9639 - dense_4_accuracy: 0.9888 - dense_5_accuracy: 0.9894 - val_loss: 0.3541 - val_dense_3_loss: 0.2293 - val_dense_4_loss: 0.0564 - val_dense_5_loss: 0.0704 - val_dense_3_accuracy: 0.9502 - val_dense_4_accuracy: 0.9876 - val_dense_5_accuracy: 0.9836
# Epoch 25/30
# 180/180 [==============================] - 36s 198ms/step - loss: 0.1791 - dense_3_loss: 0.1079 - dense_4_loss: 0.0394 - dense_5_loss: 0.0318 - dense_3_accuracy: 0.9655 - dense_4_accuracy: 0.9887 - dense_5_accuracy: 0.9904 - val_loss: 0.3641 - val_dense_3_loss: 0.2371 - val_dense_4_loss: 0.0583 - val_dense_5_loss: 0.0711 - val_dense_3_accuracy: 0.9492 - val_dense_4_accuracy: 0.9873 - val_dense_5_accuracy: 0.9841
# Epoch 26/30
# 180/180 [==============================] - 36s 200ms/step - loss: 0.1757 - dense_3_loss: 0.1054 - dense_4_loss: 0.0382 - dense_5_loss: 0.0321 - dense_3_accuracy: 0.9666 - dense_4_accuracy: 0.9895 - dense_5_accuracy: 0.9902 - val_loss: 0.3677 - val_dense_3_loss: 0.2355 - val_dense_4_loss: 0.0614 - val_dense_5_loss: 0.0728 - val_dense_3_accuracy: 0.9517 - val_dense_4_accuracy: 0.9876 - val_dense_5_accuracy: 0.9841
# Epoch 27/30
# 180/180 [==============================] - 36s 197ms/step - loss: 0.3443 - dense_3_loss: 0.2153 - dense_4_loss: 0.0678 - dense_5_loss: 0.0612 - dense_3_accuracy: 0.9411 - dense_4_accuracy: 0.9822 - dense_5_accuracy: 0.9832 - val_loss: 0.3143 - val_dense_3_loss: 0.2020 - val_dense_4_loss: 0.0667 - val_dense_5_loss: 0.0458 - val_dense_3_accuracy: 0.9470 - val_dense_4_accuracy: 0.9851 - val_dense_5_accuracy: 0.9881
# Epoch 25/30
# 180/180 [==============================] - 37s 204ms/step - loss: 0.3348 - dense_3_loss: 0.2083 - dense_4_loss: 0.0686 - dense_5_loss: 0.0578 - dense_3_accuracy: 0.9424 - dense_4_accuracy: 0.9825 - dense_5_accuracy: 0.9843 - val_loss: 0.3138 - val_dense_3_loss: 0.1997 - val_dense_4_loss: 0.0676 - val_dense_5_loss: 0.0467 - val_dense_3_accuracy: 0.9460 - val_dense_4_accuracy: 0.9848 - val_dense_5_accuracy: 0.9871
# Epoch 26/30
# 180/180 [==============================] - 36s 200ms/step - loss: 0.3324 - dense_3_loss: 0.2087 - dense_4_loss: 0.0684 - dense_5_loss: 0.0553 - dense_3_accuracy: 0.9423 - dense_4_accuracy: 0.9825 - dense_5_accuracy: 0.9842 - val_loss: 0.3131 - val_dense_3_loss: 0.1996 - val_dense_4_loss: 0.0662 - val_dense_5_loss: 0.0475 - val_dense_3_accuracy: 0.9475 - val_dense_4_accuracy: 0.9851 - val_dense_5_accuracy: 0.9861
# Epoch 27/30
# 137/180 [=====================>........] - ETA: 8s - loss: 0.3232 - dense_3_loss: 0.2029 - dense_4_loss: 0.0651 - dense_5_loss: 0.0552 - dense_3_accuracy: 0.9428 - dense_4_accuracy: 0.9825 - dense_5_accuracy: 0.9847

# %%
# %matplotlib inline
def plot_loss(his, epoch, title):
    plt.style.use('ggplot')
    plt.figure()
    plt.plot(np.arange(0, epoch), his.history['loss'], label='train_loss')
    plt.plot(np.arange(0, epoch), his.history['dense_3_loss'], label='train_root_loss')
    plt.plot(np.arange(0, epoch), his.history['dense_4_loss'], label='train_vowel_loss')
    plt.plot(np.arange(0, epoch), his.history['dense_5_loss'], label='train_consonant_loss')
    
    plt.plot(np.arange(0, epoch), his.history['val_dense_3_loss'], label='val_train_root_loss')
    plt.plot(np.arange(0, epoch), his.history['val_dense_4_loss'], label='val_train_vowel_loss')
    plt.plot(np.arange(0, epoch), his.history['val_dense_5_loss'], label='val_train_consonant_loss')
    
    plt.title(title)
    plt.xlabel('Epoch #')
    plt.ylabel('Loss')
    plt.legend(loc='upper right')
    plt.show()

def plot_acc(his, epoch, title):
    plt.style.use('ggplot')
    plt.figure()
    plt.plot(np.arange(0, epoch), his.history['dense_3_accuracy'], label='train_root_acc')
    plt.plot(np.arange(0, epoch), his.history['dense_4_accuracy'], label='train_vowel_accuracy')
    plt.plot(np.arange(0, epoch), his.history['dense_5_accuracy'], label='train_consonant_accuracy')
    
    plt.plot(np.arange(0, epoch), his.history['val_dense_3_accuracy'], label='val_root_acc')
    plt.plot(np.arange(0, epoch), his.history['val_dense_4_accuracy'], label='val_vowel_accuracy')
    plt.plot(np.arange(0, epoch), his.history['val_dense_5_accuracy'], label='val_consonant_accuracy')
    plt.title(title)
    plt.xlabel('Epoch #')
    plt.ylabel('Accuracy')
    plt.legend(loc='upper right')
    plt.show()

# %%
for dataset in range(4):
    plot_loss(histories[dataset], epochs, f'Training Dataset: {dataset}')
    plot_acc(histories[dataset], epochs, f'Training Dataset: {dataset}')

# %%
del histories
gc.collect()
# Out:
# 27614

# %%
preds_dict = {
    'grapheme_root': [],
    'vowel_diacritic': [],
    'consonant_diacritic': []
}

# %%
components = ['consonant_diacritic', 'grapheme_root', 'vowel_diacritic']
target=[] # model predictions placeholder
row_id=[] # row_id place holder
for i in range(4):
    df_test_img = pd.read_parquet('/kaggle/input/bengaliai-cv19/test_image_data_{}.parquet'.format(i)) 
    df_test_img.set_index('image_id', inplace=True)

    X_test = resize(df_test_img)/255
    X_test = X_test.values.reshape(-1, IMG_SIZE, IMG_SIZE, N_CHANNELS)
    
    preds = model.predict(X_test)

    for i, p in enumerate(preds_dict):
        preds_dict[p] = np.argmax(preds[i], axis=1)

    for k,id in enumerate(df_test_img.index.values):  
        for i,comp in enumerate(components):
            id_sample=id+'_'+comp
            row_id.append(id_sample)
            target.append(preds_dict[comp][k])
    del df_test_img
    del X_test
    gc.collect()

df_sample = pd.DataFrame(
    {
        'row_id': row_id,
        'target':target
    },
    columns = ['row_id','target'] 
)
df_sample.to_csv('submission.csv',index=False)
df_sample.head()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
#                        row_id  target
# 0  Test_0_consonant_diacritic       0
# 1        Test_0_grapheme_root       3
# 2      Test_0_vowel_diacritic       0
# 3  Test_1_consonant_diacritic       0
# 4        Test_1_grapheme_root      93
